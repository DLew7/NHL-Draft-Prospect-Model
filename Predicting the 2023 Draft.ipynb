# %% [markdown]
# # Evaluating Draft Prospects
# #### By Dan Lewitzky

# %% [markdown]
# ## Installing and running the scraper

# %%
#! pip install TopDownHockey_Scraper

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import statistics as s

# %%
import TopDownHockey_Scraper.TopDownHockey_EliteProspects_Scraper as tdhepscrape
# Out:
# Welcome to the TopDownHockey EliteProspects Scraper, built by Patrick Bacon.
# This scraper is built strictly for personal use. For commercial or professional use, please look into the EliteProspects API.
# If you enjoy the scraper and would like to support my work, feel free to follow me on Twitter @TopDownHockey. Have fun!

# %% [markdown]
# ## Collecting Data From Each Junior League
# - Bio Information (draft year, age, height/weight)
# - Skater Data (points, goals, assists, games played)

# %% [markdown]
# ## 2017-18 Full Skaters

# %%
DY0_23 = pd.read_csv("DY0_23_11.csv", encoding='latin1')

# %%
DY0_23[DY0_23['playername']=='Gabe Perreault']
# Out:
#     season_DY0         dob  height  weight      playername position   NHLeDY0  \
# 156  2022-2023  2005-05-07     180     165  Gabe Perreault       RW  0.237236
#
#      NHLGeDY0
# 156  0.090016

# %%
DYn1_23 = pd.read_csv("DYn1_23_11.csv", encoding='latin1')

# %%
DYn1_23[DYn1_23['playername']=='Gabe Perreault']
# Out:
#      season_DYn1         dob height weight      playername position  NHLeDYn1  \
# 2539   2021-2022  2005-05-07    180    165  Gabe Perreault       RW  0.093249
#
#       NHLGeDYn1  team_successDYn1
# 2539   0.032637          0.935267

# %%
DY0_22 = pd.read_csv("DY0_22_9.csv", encoding='latin1')

# %%
DYn1_22 = pd.read_csv("DYn1_22_9.csv", encoding='latin1')

# %%
Final21 = pd.merge(DY0_22, DYn1_22, on =['playername','dob'])

# %%
DY0_21 = pd.read_csv("DY0_21_8.csv", encoding='latin1')

# %%
DYn1_21 = pd.read_csv("DYn1_21_6.csv", encoding='latin1')

# %%
Final20 = pd.merge(DY0_21, DYn1_21, on =['playername','dob'])

# %%
DY0_20 = pd.read_csv("DY0_20_6.csv",encoding='latin1')

# %%
DYn1_20 = pd.read_csv("DYn1_20_8.csv", encoding='latin1')

# %%
Finalll = pd.merge(DY0_20, DYn1_20, on =['playername','dob'])

# %%
DYn1____ = DYn1_22.append(DYn1_21, ignore_index = True)

# %%
DYn1___ = DYn1____.append(DYn1_20, ignore_index = True)

# %%
DY____ = DY0_22.append(DY0_21, ignore_index = True)

# %%
DY___ = DY____.append(DY0_20, ignore_index = True)

# %%
DY0_19 = pd.read_csv("DY0_19_5.csv")

# %%
DYn1_19 = pd.read_csv("DYn1_19_5.csv")

# %%
DYn1__ = DYn1___.append(DYn1_19, ignore_index = True)

# %%
DY__ = DY___.append(DY0_19, ignore_index = True)

# %%
Finall = pd.merge(DY__, DYn1__, on =['playername','dob'])

# %%
DY0_18 = pd.read_csv("DY0_18_5.csv")

# %% [markdown]
# # Full Juniors dataset 2016-17
# - "ohl", "whl", "ncaa", "ushl", "ajhl", "qmjhl", "shl", "hockeyallsvenskan", "j20 nationell", "liiga", "del", "khl", "mhl"
# - **Not including extraliga

# %%
DYn1_18 = pd.read_csv("DYn1_18_5.csv")

# %%
DY0_17 = pd.read_csv("DY0_17_5.csv")

# %% [markdown]
# # 2015-16 Full Skaters Data
# - "ohl", "whl", "ncaa", "ushl", "ajhl", "qmjhl", "shl", "hockeyallsvenskan", "j20 nationell", "liiga", "del", "khl", "mhl"

# %%
DYn1_17 = pd.read_csv("DYn1_17_5.csv")

# %%
DY0_16 = pd.read_csv("DY0_16_6.csv")

# %%
#Finall = pd.merge(DY0_19, DYn1_19, on =['playername','dob'])

# %%
DYn1_ = DYn1__.append(DYn1_18, ignore_index = True)

# %%
DY_ = DY__.append(DY0_18, ignore_index = True)

# %%
Final = pd.merge(DY_, DYn1_, on =['playername','dob'])

# %%
DYn1 = DYn1_.append(DYn1_17, ignore_index = True)

# %%
DY = DY_.append(DY0_17, ignore_index = True)

# %%
Final0 = pd.merge(DY, DYn1, on =['playername','dob'])

# %%
DY0 = DY.append(DY0_16, ignore_index = True)

# %% [markdown]
# ## DY0 is now for 2016 draftees

# %%
#DY0 = DY0_16 # Was : DY0_17.append(DY0_16, ignore_index = True)

# %%
#DY0.head()

# %%
## DYn1 = DYn1_18.append(DYn1_17, ignore_index = True)
## Wouldnt work because dont have a matching DY0_18 dataset for DYn1_18

# %%
# Final1 = pd.merge(DY0, DYn1, on ='playername')

# %% [markdown]
# # 2014-15 Skaters Data

# %%
DYn1_16 = pd.read_csv("DYn1_16_5.csv")

# %%
DY0_15 = pd.read_csv("DY0_15_5.csv")

# %%
DYn1_0 = DYn1.append(DYn1_16, ignore_index = True)

# %% [markdown]
# ## Making a Test Set using 2017 with each players' DY0 and DY-1 seasons
# - Players drafted in 2017 will be the ones I'm trying to predict and won't be including in training the model

# %%
Test17 = pd.merge(DY0_23, DYn1_23, on =['playername','dob']) # Was not there before

# %%
Test17.head()
# Out:
#   season_DY0         dob  height_x  weight_x        playername position_x  \
# 0  2022-2023  2003-01-22       180       174  Luke Mittelstadt          D
# 1  2022-2023  2003-01-27       185       190       Justin Gill          C
# 2  2022-2023  2003-02-18       180       187      Brett Hyland       LW/C
# 3  2022-2023  2003-02-18       198       216   Milton Oscarson       C/RW
# 4  2022-2023  2003-02-26       180       185        Ty Mueller          F
#
#     NHLeDY0  NHLGeDY0 season_DYn1 height_y weight_y position_y  NHLeDYn1  \
# 0  0.130248  0.022770   2021-2022      180      174          D  0.134020
# 1  0.166837  0.078933   2021-2022      185      187          C  0.085702
# 2  0.136053  0.075263   2021-2022      180      187       LW/C  0.058793
# 3  0.065633  0.033680   2021-2022      198      216       C/RW  0.102271
# 4  0.134468  0.064545   2021-2022      180      185          F  0.104825
#
#    NHLGeDYn1  team_successDYn1
# 0   0.046298          0.913627
# ...

# %%
Test17.loc[Test17['playername'] == "Connor Bedard"]
# Out:
#     season_DY0         dob  height_x  weight_x     playername position_x  \
# 143  2022-2023  2005-07-17       178       185  Connor Bedard          C
#
#       NHLeDY0  NHLGeDY0 season_DYn1 height_y weight_y position_y  NHLeDYn1  \
# 143  0.406843   0.18496   2021-2022      178      185          C  0.214843
#
#      NHLGeDYn1  team_successDYn1
# 143   0.116037          0.864626

# %%
Test17 = Test17.dropna()

# %%
Test17 = Test17.drop(columns = ['position_y','height_y','weight_y'])

# %%
Test17["position_x"].value_counts()
# Out:
# D        52
# C        32
# F        18
# RW       16
# LW       11
# LW/C      4
# C/RW      4
# C/LW      4
# RW/C      3
# LW/RW     2
# C/W       2
# RW/LW     1
# Name: position_x, dtype: int64

# %% [markdown]
# ## Converting positions just to forwards, defense, goalies

# %%
pos = []
for i in Test17['position_x']:
    if i == "D":
        pos.append("D")
    elif i == "C":
        pos.append("F")
    elif i == "LW":
        pos.append("F")
    elif i == "RW":
        pos.append("F")
    elif i == "C/LW":
        pos.append("F")
    elif i == "LW/RW":
        pos.append("F")
    elif i == "RW/LW":
        pos.append("F")
    elif i == "C/RW":
        pos.append("F")
    elif i == "RW/C":
        pos.append("F")
    elif i == "C/W":
        pos.append("F")
    elif i == "LW/C":
        pos.append("F")
    elif i == "W/C":
        pos.append("F")
    elif i == "D/LW":
        pos.append("D")
    elif i == "F":
        pos.append("F")
    elif i == "D/C":
        pos.append("D")
    else:
        pos.append(None)
Test17["position"] = pos

# %%
Test17["position"].value_counts()
# Out:
# F    97
# D    52
# Name: position, dtype: int64

# %%
Test17 = Test17.drop(columns = 'position_x')

# %%
Test17.head()
# Out:
#   season_DY0         dob  height_x  weight_x        playername   NHLeDY0  \
# 0  2022-2023  2003-01-22       180       174  Luke Mittelstadt  0.130248
# 1  2022-2023  2003-01-27       185       190       Justin Gill  0.166837
# 2  2022-2023  2003-02-18       180       187      Brett Hyland  0.136053
# 3  2022-2023  2003-02-18       198       216   Milton Oscarson  0.065633
# 4  2022-2023  2003-02-26       180       185        Ty Mueller  0.134468
#
#    NHLGeDY0 season_DYn1  NHLeDYn1  NHLGeDYn1  team_successDYn1 position
# 0  0.022770   2021-2022  0.134020   0.046298          0.913627        D
# 1  0.078933   2021-2022  0.085702   0.037262          0.864152        F
# 2  0.075263   2021-2022  0.058793   0.026356          1.050876        F
# 3  0.033680   2021-2022  0.102271   0.035310          0.872598        F
# 4  0.064545   2021-2022  0.104825   0.064508          0.875647        F

# %%
Test17['season_DY0'] = Test17['season_DY0'].str.split('-', n = 1, expand = False)

Test17['season_DY0'] = Test17['season_DY0'].str[0]

Test17['season_DYn1'] = Test17['season_DYn1'].str.split('-', n = 1, expand = False)

Test17['season_DYn1'] = Test17['season_DYn1'].str[0]

Test17.head()
# Out:
#   season_DY0         dob  height_x  weight_x        playername   NHLeDY0  \
# 0       2022  2003-01-22       180       174  Luke Mittelstadt  0.130248
# 1       2022  2003-01-27       185       190       Justin Gill  0.166837
# 2       2022  2003-02-18       180       187      Brett Hyland  0.136053
# 3       2022  2003-02-18       198       216   Milton Oscarson  0.065633
# 4       2022  2003-02-26       180       185        Ty Mueller  0.134468
#
#    NHLGeDY0 season_DYn1  NHLeDYn1  NHLGeDYn1  team_successDYn1 position
# 0  0.022770        2021  0.134020   0.046298          0.913627        D
# 1  0.078933        2021  0.085702   0.037262          0.864152        F
# 2  0.075263        2021  0.058793   0.026356          1.050876        F
# 3  0.033680        2021  0.102271   0.035310          0.872598        F
# 4  0.064545        2021  0.104825   0.064508          0.875647        F

# %%
Test17['season_DY0'] = Test17['season_DY0'] + "-1-1"

Test17['season_DYn1'] = Test17['season_DYn1'] + "-1-1"

# %% [markdown]
# ## Fixing date of birth to get age instead

# %%
## Fixing DOB

from datetime import datetime

from dateutil import relativedelta

Test17['season_DY0'] = pd.to_datetime(Test17['season_DY0'], format="%Y-%m-%d")

Test17['dob'] = pd.to_datetime(Test17['dob'], format="%Y-%m-%d")

#Final3.head()

Test17["age_DY0"] = (Test17["season_DY0"] - Test17["dob"]).dt.days

Test17["age_DY0"] = round(Test17["age_DY0"] / 365, 3)

Test17['season_DYn1'] = pd.to_datetime(Test17['season_DYn1'], format="%Y-%m-%d")

Test17["age_DYn1"] = (Test17["season_DYn1"] - Test17["dob"]).dt.days

Test17["age_DYn1"] = round(Test17["age_DYn1"] / 365, 3)

Test17.head()
# Out:
#   season_DY0        dob  height_x  weight_x        playername   NHLeDY0  \
# 0 2022-01-01 2003-01-22       180       174  Luke Mittelstadt  0.130248
# 1 2022-01-01 2003-01-27       185       190       Justin Gill  0.166837
# 2 2022-01-01 2003-02-18       180       187      Brett Hyland  0.136053
# 3 2022-01-01 2003-02-18       198       216   Milton Oscarson  0.065633
# 4 2022-01-01 2003-02-26       180       185        Ty Mueller  0.134468
#
#    NHLGeDY0 season_DYn1  NHLeDYn1  NHLGeDYn1  team_successDYn1 position  \
# 0  0.022770  2021-01-01  0.134020   0.046298          0.913627        D
# 1  0.078933  2021-01-01  0.085702   0.037262          0.864152        F
# 2  0.075263  2021-01-01  0.058793   0.026356          1.050876        F
# 3  0.033680  2021-01-01  0.102271   0.035310          0.872598        F
# 4  0.064545  2021-01-01  0.104825   0.064508          0.875647        F
#
#    age_DY0  age_DYn1
# 0   18.956    17.956
# 1   18.942    17.942
# 2   18.882    17.882
# ...

# %%
Test17.loc[Test17['playername'] == "Elias Pettersson"]
# Out:
# Empty DataFrame
# Columns: [season_DY0, dob, height_x, weight_x, playername, NHLeDY0, NHLGeDY0, season_DYn1, NHLeDYn1, NHLGeDYn1, team_successDYn1, position, age_DY0, age_DYn1]
# Index: []

# %%
Test17 = Test17.drop(columns = ['season_DY0','dob','season_DYn1'])

Test17["NHLeDelta"] = Test17["NHLeDY0"] - Test17["NHLeDYn1"]

Test17["NHLGeDelta"] = Test17["NHLGeDY0"] - Test17["NHLGeDYn1"]


## Splitting into forwards and defensemen

Test17D = Test17.loc[Test17['position'] =='D']

Test17D = Test17D.drop(columns = 'position')

Test17F = Test17.loc[Test17['position'] =='F']

Test17F = Test17F.drop(columns = 'position')

Test17F.head()
# Out:
#    height_x  weight_x       playername   NHLeDY0  NHLGeDY0  NHLeDYn1  \
# 1       185       190      Justin Gill  0.166837  0.078933  0.085702
# 2       180       187     Brett Hyland  0.136053  0.075263  0.058793
# 3       198       216  Milton Oscarson  0.065633  0.033680  0.102271
# 4       180       185       Ty Mueller  0.134468  0.064545  0.104825
# 6       178       176      Jack Harvey  0.127937  0.069155  0.090278
#
#    NHLGeDYn1  team_successDYn1  age_DY0  age_DYn1  NHLeDelta  NHLGeDelta
# 1   0.037262          0.864152   18.942    17.942   0.081135    0.041672
# 2   0.026356          1.050876   18.882    17.882   0.077260    0.048908
# 3   0.035310          0.872598   18.882    17.882  -0.036637   -0.001630
# 4   0.064508          0.875647   18.860    17.860   0.029643    0.000037
# 6   0.047903          0.843313   18.770    17.770   0.037659    0.021252

# %%
Test17F.head(20)
# Out:
#     height_x  weight_x         playername   NHLeDY0  NHLGeDY0  NHLeDYn1  \
# 1        185       190        Justin Gill  0.166837  0.078933  0.085702
# 2        180       187       Brett Hyland  0.136053  0.075263  0.058793
# 3        198       216    Milton Oscarson  0.065633  0.033680  0.102271
# 4        180       185         Ty Mueller  0.134468  0.064545  0.104825
# 6        178       176        Jack Harvey  0.127937  0.069155  0.090278
# 7        180       174       Matt Copponi  0.143336  0.069197  0.069668
# 8        181       190  Stanislav Yarovoy  0.199883  0.103321  0.082166
# 10       180       185         Sam Harris  0.107191  0.057424  0.066634
# 11       187       192    Michael Emerson  0.114337  0.053595  0.022211
# 12       178       174       Austin Roest  0.158053  0.064842  0.067074
# 17       193       205    Casper NÃ¤ssÃ©n  0.085663  0.049256  0.009624
# 18       195       214           Samu Bau  0.063615  0.020977  0.043435
# ...

# %% [markdown]
# ## Made age into a number that increases with younger age, so it's backwards
# - Younger age is clearly better for players in the model

# %%
AgeDY0 = 1 / (Test17F['age_DY0']) # -0.043 was the best

Test17F['age0new'] = AgeDY0

# %%
Test17F.tail(50)
# Out:
#      height_x  weight_x              playername   NHLeDY0  NHLGeDY0  NHLeDYn1  \
# 67        180       194            Oliver Moore  0.133416  0.053393  0.095634
# 68        184       159              Kalan Lind  0.124407  0.045239  0.077039
# 69        183       183          Ethan Gauthier  0.127533  0.055449  0.076014
# 70        185       205            Tyler Peddle  0.078149  0.045746  0.068218
# 72        189       198       Yegor Rimashevsky  0.117199  0.058599  0.075526
# 75        178       174         Andrew Cristall  0.194559  0.077965  0.139887
# 78        193       196            Matthew Wood  0.201180  0.081054  0.116528
# 81        185       194            Colby Barlow  0.177974  0.106276  0.121552
# 82        184       181       Mikhail Ye. Ilyin  0.109505  0.013897  0.055773
# 83        195       203              Daniil But  0.128595  0.080610  0.125205
# 84        183       168  Oscar Fisker MÃ¸lgaard  0.105744  0.043189  0.036956
# ...

# %% [markdown]
# ## Test17F will be the 2017 test set for forwards

# %%
Test17F = Test17F.drop(columns = ['age_DY0','age_DYn1','weight_x'])

# %%
Test17F[Test17F['playername']=="Gabe Perreault"]
# Out:
#      height_x      playername   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 120       180  Gabe Perreault  0.237236  0.090016  0.093249   0.032637
#
#      team_successDYn1  NHLeDelta  NHLGeDelta   age0new
# 120          0.935267   0.143987    0.057379  0.060002

# %%
#PS2018 = pd.merge(Test17F,PS2017F, on=['playername'])

# %%
#PS2018 = PS2018.drop(columns=['playername','NHLeDY0','NHLGeDY0','team_successDY0','NHLeDYn1','NHLGeDYn1','team_successDYn1','NHLeDelta','NHLGeDelta','age0new'])

# %%
#PS2018

# %%
#PS2017F2

# %%
#Test17D = Test17.loc[Test17['position'] =='D']

#Test17D = Test17D.drop(columns = 'position')

# %%
AgeDY0 = 1 / (Test17D['age_DY0']) # -0.043 was the best

Test17D['age0new'] = AgeDY0

# %%
Test17D = Test17D.drop(columns = ['age_DY0','age_DYn1','weight_x'])

# %%
Test17D.head()
# Out:
#     height_x              playername   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 0        180        Luke Mittelstadt  0.130248  0.022770  0.134020   0.046298
# 5        185           Jeremy Hanzel  0.132490  0.035883  0.094889   0.020128
# 9        191  Charles-Alexis Legault  0.053281  0.011840  0.039488   0.013163
# 13       190          Rasmus Larsson  0.118038  0.055547  0.000000   0.000000
# 14       188        Dennis Good Bogg  0.121215  0.017316  0.030074   0.007450
#
#     team_successDYn1  NHLeDelta  NHLGeDelta   age0new
# 0           0.913627  -0.003772   -0.023528  0.052754
# 5           0.845354   0.037602    0.015755  0.053028
# 9           0.784031   0.013793   -0.001322  0.054535
# 13          1.175042   0.118038    0.055547  0.055844
# 14          0.993434   0.091141    0.009867  0.056032

# %%
Test17D = Test17D.reset_index()

# %%
Test17D = Test17D.drop(columns = 'index')

# %%
Test17D[Test17D['playername']=='Tom Willander']
# Out:
#     height_x     playername   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 25       186  Tom Willander  0.127163  0.030082       0.0        0.0
#
#     team_successDYn1  NHLeDelta  NHLGeDelta   age0new
# 25          0.980231   0.127163    0.030082  0.059158

# %%
Test17[Test17['height_x']== 181]
# Out:
#      height_x  weight_x          playername   NHLeDY0  NHLGeDY0  NHLeDYn1  \
# 8         181       190   Stanislav Yarovoy  0.199883  0.103321  0.082166
# 127       181       185       Otto Stenberg  0.155487  0.065442  0.090442
# 148       181       172  Felix Unger SÃ¶rum  0.132447  0.027936  0.044912
#
#      NHLGeDYn1  team_successDYn1 position  age_DY0  age_DYn1  NHLeDelta  \
# 8     0.034858          0.883584        F   18.364    17.364   0.117718
# 127   0.046556          0.958005        F   16.605    15.605   0.065045
# 148   0.032080          1.033004        F   16.310    15.310   0.087535
#
#      NHLGeDelta
# 8      0.068463
# 127    0.018885
# 148   -0.004144

# %% [markdown]
# ## 2013-14 Skater Data

# %%
DYn1_15 = pd.read_csv("DYn1_15_5.csv")

# %%
DY0_14 = pd.read_csv("DY0_14_5.csv")

# %% [markdown]
# ## DYn1 is the first junior year for players drafted in 2016

# %%
# DY0 = DY0_17.append(DY0_16, ignore_index = True)

# DY0.head()

#DYn1 = DYn1_16 # Was : DYn1_17.append(DYn1_16, ignore_index = True)

# %%
DYn1_0Dups = DYn1_0[DYn1_0.duplicated()]

# %%
DYn1_0Dups.head()
# Out:
# Empty DataFrame
# Columns: [season_DYn1, dob, height, weight, playername, position, NHLeDYn1, NHLGeDYn1, team_successDYn1]
# Index: []

# %%
DY0Dups = DY0[DY0.duplicated()]

# %%
DY0Dups.head()
# Out:
# Empty DataFrame
# Columns: [season_DY0, dob, height, weight, playername, position, NHLeDY0, NHLGeDY0, team_successDY0]
# Index: []

# %%
# DYn1 = DYn1.drop_duplicates(subset=['team', 'playername', 'gp', 'ppg'])

# %%
DY0
# Out:
#      season_DY0         dob  height  weight        playername position  \
# 0     2021-2022  2001-01-27     181     192     Lucas Edmonds    RW/LW
# 1     2021-2022  2002-01-12     183     187     Petteri Nurmi        D
# 2     2021-2022  2002-02-09     173     170  MiguÃ«l Tourigny        D
# 3     2021-2022  2002-02-10     188     190    Daylan Kuefler       LW
# 4     2021-2022  2002-02-18     180     170    Aidan Thompson        C
# ...         ...         ...     ...     ...               ...      ...
# 1302  2015-2016  1998-08-29     191     229     Josh Anderson        D
# 1303  2015-2016  1998-08-31     191     209    Jacob Moverare        D
# 1304  2015-2016  1998-09-01     195     225      Otto Koivula     LW/C
# 1305  2015-2016  1998-09-04     186     176     Linus Högberg        D
# 1306  2015-2016  1998-09-07     191     205      Nick Caamano    RW/LW
#
#        NHLeDY0  NHLGeDY0  team_successDY0
# 0     0.253563  0.076293         0.874386
# ...

# %%
Final1 = pd.merge(DY0, DYn1_0, on =['playername','dob'])

# %%
Final1
# Out:
#      season_DY0         dob  height_x  weight_x        playername position_x  \
# 0     2021-2022  2001-01-27       181       192     Lucas Edmonds      RW/LW
# 1     2021-2022  2002-01-12       183       187     Petteri Nurmi          D
# 2     2021-2022  2002-02-09       173       170  MiguÃ«l Tourigny          D
# 3     2021-2022  2002-02-10       188       190    Daylan Kuefler         LW
# 4     2021-2022  2002-02-18       180       170    Aidan Thompson          C
# ...         ...         ...       ...       ...               ...        ...
# 1108  2015-2016  1998-08-29       191       229     Josh Anderson          D
# 1109  2015-2016  1998-08-31       191       209    Jacob Moverare          D
# 1110  2015-2016  1998-09-01       195       225      Otto Koivula       LW/C
# 1111  2015-2016  1998-09-04       186       176     Linus Högberg          D
# 1112  2015-2016  1998-09-07       191       205      Nick Caamano      RW/LW
#
# ...

# %%
Final1.loc[Final1.duplicated(subset=['playername']), :]
# Out:
#     season_DY0         dob  height_x  weight_x   playername position_x  \
# 600  2018-2019  2001-05-14       180       176  Jack Hughes          C
#
#       NHLeDY0  NHLGeDY0  team_successDY0 season_DYn1  height_y  weight_y  \
# 600  0.271624  0.080227         0.841677   2017-2018       180       176
#
#     position_y  NHLeDYn1  NHLGeDYn1  team_successDYn1
# 600          C  0.234772   0.085891          0.866627

# %%
Final1[Final1['playername'] == 'Jake Bean']
# Out:
#      season_DY0         dob  height_x  weight_x playername position_x  \
# 1088  2015-2016  1998-06-09       185       176  Jake Bean          D
#
#        NHLeDY0  NHLGeDY0  team_successDY0 season_DYn1  height_y  weight_y  \
# 1088  0.193826  0.072685         0.951404   2014-2015       185       176
#
#      position_y  NHLeDYn1  NHLGeDYn1  team_successDYn1
# 1088          D  0.152416   0.019541          0.825102

# %%
#Final1.tail()

# %%
#Final1[Final1.playername == "Sebastian Aho"]

# %%
#Final1.describe()

# %%
#DY0.describe()

# %%
#list(Final1.columns)

# %% [markdown]
# ## Final2 is now the datasets with players drafted in 15 and 16, which will be used to train the model

# %%
DY0_2 = DY0.append(DY0_15, ignore_index = True)

# %%
#DY0_2.head()

# %%
DYn1_2 = DYn1_0.append(DYn1_15, ignore_index = True)

# %%
# DYn1 = DYn1.drop_duplicates(subset=['team', 'playername', 'gp', 'ppg'])

Final2 = pd.merge(DY0_2, DYn1_2, on =['playername','dob'])

# %%
Final2.loc[Final2.duplicated(subset=['playername']), :]
# Out:
#      season_DY0         dob  height_x  weight_x     playername position_x  \
# 600   2018-2019  2001-05-14       180       176    Jack Hughes          C
# 1267  2014-2015  1997-07-26       183       176  Sebastian Aho       C/LW
#
#        NHLeDY0  NHLGeDY0  team_successDY0 season_DYn1  height_y  weight_y  \
# 600   0.271624  0.080227         0.841677   2017-2018       180       176
# 1267  0.171808  0.035473         1.208593   2013-2014       183       176
#
#      position_y  NHLeDYn1  NHLGeDYn1  team_successDYn1
# 600           C  0.234772   0.085891          0.866627
# 1267       C/LW  0.131642   0.053659          0.807405

# %%
#Final2.head()

# %%
#print(Final2.isnull().any())

# %%
Final2.describe()
# Out:
#           height_x     weight_x      NHLeDY0     NHLGeDY0  team_successDY0  \
# count  1278.000000  1278.000000  1278.000000  1278.000000      1278.000000
# mean    185.309859   191.211268     0.120179     0.045143         0.954687
# std       5.736671    15.263259     0.055200     0.029125         0.157819
# min     168.000000   150.000000     0.000000     0.000000         0.000000
# 25%     181.250000   181.000000     0.082707     0.024345         0.855883
# 50%     185.000000   190.000000     0.112793     0.041383         0.950296
# 75%     188.000000   201.000000     0.149231     0.060820         1.035622
# max     205.000000   247.000000     0.557058     0.285112         2.256617
#
#           height_y     weight_y     NHLeDYn1    NHLGeDYn1  team_successDYn1
# count  1278.000000  1278.000000  1278.000000  1278.000000       1278.000000
# mean    185.299687   191.117371     0.070699     0.025836          0.997462
# ...

# %%
DY0_2.describe()
# Out:
#             height       weight      NHLeDY0     NHLGeDY0  team_successDY0
# count  1489.000000  1489.000000  1489.000000  1489.000000      1489.000000
# mean    185.376091   190.707186     0.116050     0.043553         0.958608
# std       5.762515    15.493589     0.054988     0.028875         0.166229
# min     168.000000   141.000000     0.000000     0.000000         0.000000
# 25%     181.000000   181.000000     0.079652     0.023026         0.855814
# 50%     185.000000   190.000000     0.110342     0.039880         0.950755
# 75%     189.000000   201.000000     0.145702     0.058935         1.037494
# max     205.000000   247.000000     0.557058     0.285112         2.600000

# %%
DYn1_2.describe()
# Out:
#             height       weight     NHLeDYn1    NHLGeDYn1  team_successDYn1
# count  1301.000000  1301.000000  1301.000000  1301.000000       1301.000000
# mean    185.317448   191.141430     0.070190     0.025600          0.997259
# std       5.742547    15.352624     0.045411     0.022161          0.266973
# min     168.000000   150.000000     0.000000     0.000000          0.000000
# 25%     181.000000   181.000000     0.037776     0.009726          0.870057
# 50%     185.000000   190.000000     0.063055     0.021383          0.978144
# 75%     188.000000   201.000000     0.093991     0.035675          1.068610
# max     205.000000   247.000000     0.336000     0.216000          6.668603

# %%
Final2 = Final2.dropna()

# %%
Final2.describe()
# Out:
#           height_x     weight_x      NHLeDY0     NHLGeDY0  team_successDY0  \
# count  1278.000000  1278.000000  1278.000000  1278.000000      1278.000000
# mean    185.309859   191.211268     0.120179     0.045143         0.954687
# std       5.736671    15.263259     0.055200     0.029125         0.157819
# min     168.000000   150.000000     0.000000     0.000000         0.000000
# 25%     181.250000   181.000000     0.082707     0.024345         0.855883
# 50%     185.000000   190.000000     0.112793     0.041383         0.950296
# 75%     188.000000   201.000000     0.149231     0.060820         1.035622
# max     205.000000   247.000000     0.557058     0.285112         2.256617
#
#           height_y     weight_y     NHLeDYn1    NHLGeDYn1  team_successDYn1
# count  1278.000000  1278.000000  1278.000000  1278.000000       1278.000000
# mean    185.299687   191.117371     0.070699     0.025836          0.997462
# ...

# %%
Final2 = Final2.drop(columns=['height_y','weight_y'])

# %%
Final2
# Out:
#      season_DY0         dob  height_x  weight_x          playername  \
# 0     2021-2022  2001-01-27       181       192       Lucas Edmonds
# 1     2021-2022  2002-01-12       183       187       Petteri Nurmi
# 2     2021-2022  2002-02-09       173       170    MiguÃ«l Tourigny
# 3     2021-2022  2002-02-10       188       190      Daylan Kuefler
# 4     2021-2022  2002-02-18       180       170      Aidan Thompson
# ...         ...         ...       ...       ...                 ...
# 1273  2014-2015  1997-08-24       188       187  Parker Wotherspoon
# 1274  2014-2015  1997-08-28       185       172         Lukas Jasek
# 1275  2014-2015  1997-09-08       185       209           Nick Boka
# 1276  2014-2015  1997-09-10       183       185          Troy Terry
# 1277  2014-2015  1997-09-15       193       212          Liam Dunda
#
#      position_x   NHLeDY0  NHLGeDY0  team_successDY0 season_DYn1 position_y  \
# ...

# %%
#Final2.head()

# %%
print(Final2.nunique())
# Out:
# season_DY0             8
# dob                 1020
# height_x              35
# weight_x              43
# playername          1276
# position_x            17
# NHLeDY0             1264
# NHLGeDY0            1228
# team_successDY0      996
# season_DYn1            8
# position_y            17
# NHLeDYn1            1202
# NHLGeDYn1           1099
# team_successDYn1     895
# dtype: int64

# %%
print(Final1.nunique())
# Out:
# season_DY0             7
# dob                  890
# height_x              35
# weight_x              42
# playername          1112
# position_x            17
# NHLeDY0             1101
# NHLGeDY0            1070
# team_successDY0      872
# season_DYn1            7
# height_y              35
# weight_y              42
# position_y            17
# NHLeDYn1            1047
# NHLGeDYn1            957
# team_successDYn1     782
# dtype: int64

# %% [markdown]
# # 2012-13 Skater Data

# %%
DYn1_14 = pd.read_csv("DYn1_14_5.csv")

# %%
DY0_13 = pd.read_csv("DY0_13_5.csv")

# %% [markdown]
# ## Combining DY0 and DYn1 Datasets - now includes 2014,15,16

# %%
DY0_3 = DY0_2.append(DY0_14, ignore_index = True)

# %%
DY0_3.head()
# Out:
#   season_DY0         dob  height  weight        playername position   NHLeDY0  \
# 0  2021-2022  2001-01-27     181     192     Lucas Edmonds    RW/LW  0.253563
# 1  2021-2022  2002-01-12     183     187     Petteri Nurmi        D  0.044052
# 2  2021-2022  2002-02-09     173     170  MiguÃ«l Tourigny        D  0.243123
# 3  2021-2022  2002-02-10     188     190    Daylan Kuefler       LW  0.112253
# 4  2021-2022  2002-02-18     180     170    Aidan Thompson        C  0.164331
#
#    NHLGeDY0  team_successDY0
# 0  0.076293         0.874386
# 1  0.009049         1.026830
# 2  0.094210         1.000000
# 3  0.072298         0.798226
# 4  0.048097         0.941925

# %%
DYn1_3 = DYn1_2.append(DYn1_14, ignore_index = True)

# %%
# DYn1 = DYn1.drop_duplicates(subset=['team', 'playername', 'gp', 'ppg'])

Final33 = pd.merge(DY0_3, DYn1_3, on =['playername','dob'])

# %%
Final33.loc[Final33.duplicated(subset=['playername']), :]
# Out:
#      season_DY0         dob  height_x  weight_x     playername position_x  \
# 600   2018-2019  2001-05-14       180       176    Jack Hughes          C
# 1267  2014-2015  1997-07-26       183       176  Sebastian Aho       C/LW
#
#        NHLeDY0  NHLGeDY0  team_successDY0 season_DYn1  height_y  weight_y  \
# 600   0.271624  0.080227         0.841677   2017-2018       180       176
# 1267  0.171808  0.035473         1.208593   2013-2014       183       176
#
#      position_y  NHLeDYn1  NHLGeDYn1  team_successDYn1
# 600           C  0.234772   0.085891          0.866627
# 1267       C/LW  0.131642   0.053659          0.807405

# %% [markdown]
# ## Adding in 2005-2011 (starting with Drafted11)

# %% [markdown]
# ### 2011 skater and Bio Info

# %%
DYn1_13 = pd.read_csv("DYn1_13_5.csv")

# %%
DY0_12 = pd.read_csv("DY0_12_5.csv")

# %% [markdown]
# ## Combining DY0 and DYn1 Datasets - now includes 13, 2014,15,16

# %%
DY0_4 = DY0_3.append(DY0_13, ignore_index = True)

# %%
DY0_4.head()
# Out:
#   season_DY0         dob  height  weight        playername position   NHLeDY0  \
# 0  2021-2022  2001-01-27     181     192     Lucas Edmonds    RW/LW  0.253563
# 1  2021-2022  2002-01-12     183     187     Petteri Nurmi        D  0.044052
# 2  2021-2022  2002-02-09     173     170  MiguÃ«l Tourigny        D  0.243123
# 3  2021-2022  2002-02-10     188     190    Daylan Kuefler       LW  0.112253
# 4  2021-2022  2002-02-18     180     170    Aidan Thompson        C  0.164331
#
#    NHLGeDY0  team_successDY0
# 0  0.076293         0.874386
# 1  0.009049         1.026830
# 2  0.094210         1.000000
# 3  0.072298         0.798226
# 4  0.048097         0.941925

# %%
DYn1_4 = DYn1_3.append(DYn1_13, ignore_index = True)

# %%
# DYn1 = DYn1.drop_duplicates(subset=['team', 'playername', 'gp', 'ppg'])

Final4 = pd.merge(DY0_4, DYn1_4, on =['playername','dob'])

# %%
Final4.loc[Final4.duplicated(subset=['playername']), :]
# Out:
#      season_DY0         dob  height_x  weight_x     playername position_x  \
# 600   2018-2019  2001-05-14       180       176    Jack Hughes          C
# 1267  2014-2015  1997-07-26       183       176  Sebastian Aho       C/LW
#
#        NHLeDY0  NHLGeDY0  team_successDY0 season_DYn1  height_y  weight_y  \
# 600   0.271624  0.080227         0.841677   2017-2018       180       176
# 1267  0.171808  0.035473         1.208593   2013-2014       183       176
#
#      position_y  NHLeDYn1  NHLGeDYn1  team_successDYn1
# 600           C  0.234772   0.085891          0.866627
# 1267       C/LW  0.131642   0.053659          0.807405

# %% [markdown]
# ## 2010 Skater and BIO Info

# %%
DYn1_12 = pd.read_csv("DYn1_12_5.csv")

# %%
DY0_11 = pd.read_csv("DY0_11_5.csv")

# %% [markdown]
# ## Combining DY0 and DYn1 Datasets - now includes 13, 2014,15,16

# %%
DY0_5 = DY0_4.append(DY0_12, ignore_index = True)

# %%
DY0_5.head()
# Out:
#   season_DY0         dob  height  weight        playername position   NHLeDY0  \
# 0  2021-2022  2001-01-27     181     192     Lucas Edmonds    RW/LW  0.253563
# 1  2021-2022  2002-01-12     183     187     Petteri Nurmi        D  0.044052
# 2  2021-2022  2002-02-09     173     170  MiguÃ«l Tourigny        D  0.243123
# 3  2021-2022  2002-02-10     188     190    Daylan Kuefler       LW  0.112253
# 4  2021-2022  2002-02-18     180     170    Aidan Thompson        C  0.164331
#
#    NHLGeDY0  team_successDY0
# 0  0.076293         0.874386
# 1  0.009049         1.026830
# 2  0.094210         1.000000
# 3  0.072298         0.798226
# 4  0.048097         0.941925

# %%
DYn1_5 = DYn1_4.append(DYn1_12, ignore_index = True)

# %%
# DYn1 = DYn1.drop_duplicates(subset=['team', 'playername', 'gp', 'ppg'])

Final5 = pd.merge(DY0_5, DYn1_5, on =['playername','dob'])

# %%
Final5.loc[Final5.duplicated(subset=['playername']), :]
# Out:
#      season_DY0         dob  height_x  weight_x     playername position_x  \
# 600   2018-2019  2001-05-14       180       176    Jack Hughes          C
# 1267  2014-2015  1997-07-26       183       176  Sebastian Aho       C/LW
#
#        NHLeDY0  NHLGeDY0  team_successDY0 season_DYn1  height_y  weight_y  \
# 600   0.271624  0.080227         0.841677   2017-2018       180       176
# 1267  0.171808  0.035473         1.208593   2013-2014       183       176
#
#      position_y  NHLeDYn1  NHLGeDYn1  team_successDYn1
# 600           C  0.234772   0.085891          0.866627
# 1267       C/LW  0.131642   0.053659          0.807405

# %% [markdown]
# ## 2009 Skater and BIO Info

# %%
DYn1_11 = pd.read_csv("DYn1_11_5.csv")

# %%
DY0_10 = pd.read_csv("DY0_10_5.csv")

# %% [markdown]
# ## Combining DY0 and DYn1 Datasets - now includes 13, 2014,15,16

# %%
DY0_6 = DY0_5.append(DY0_11, ignore_index = True)

# %%
DY0_6.head()
# Out:
#   season_DY0         dob  height  weight        playername position   NHLeDY0  \
# 0  2021-2022  2001-01-27     181     192     Lucas Edmonds    RW/LW  0.253563
# 1  2021-2022  2002-01-12     183     187     Petteri Nurmi        D  0.044052
# 2  2021-2022  2002-02-09     173     170  MiguÃ«l Tourigny        D  0.243123
# 3  2021-2022  2002-02-10     188     190    Daylan Kuefler       LW  0.112253
# 4  2021-2022  2002-02-18     180     170    Aidan Thompson        C  0.164331
#
#    NHLGeDY0  team_successDY0
# 0  0.076293         0.874386
# 1  0.009049         1.026830
# 2  0.094210         1.000000
# 3  0.072298         0.798226
# 4  0.048097         0.941925

# %%
DYn1_6 = DYn1_5.append(DYn1_11, ignore_index = True)

# %%
# DYn1 = DYn1.drop_duplicates(subset=['team', 'playername', 'gp', 'ppg'])

Final6 = pd.merge(DY0_6, DYn1_6, on =['playername','dob'])

# %%
Final6.loc[Final6.duplicated(subset=['playername']), :]
# Out:
#      season_DY0         dob  height_x  weight_x     playername position_x  \
# 600   2018-2019  2001-05-14       180       176    Jack Hughes          C
# 1267  2014-2015  1997-07-26       183       176  Sebastian Aho       C/LW
#
#        NHLeDY0  NHLGeDY0  team_successDY0 season_DYn1  height_y  weight_y  \
# 600   0.271624  0.080227         0.841677   2017-2018       180       176
# 1267  0.171808  0.035473         1.208593   2013-2014       183       176
#
#      position_y  NHLeDYn1  NHLGeDYn1  team_successDYn1
# 600           C  0.234772   0.085891          0.866627
# 1267       C/LW  0.131642   0.053659          0.807405

# %% [markdown]
# ## 2008 Skater and BIO Info

# %%
DYn1_10 = pd.read_csv("DYn1_10_5.csv")

# %%
DY0_09 = pd.read_csv("DY0_09_5.csv")

# %%
DY0_09[DY0_09['NHLeDY0']>.27]
# Out:
#    season_DY0         dob position  height  weight        playername  \
# 39  2008-2009  1990-09-20        C     185     212      John Tavares
# 43  2008-2009  1990-09-29     C/RW     175     174  Jordan Schroeder
# 75  2008-2009  1991-01-03        D     178     181        Ryan Ellis
#
#      NHLeDY0  NHLGeDY0  team_successDY0
# 39  0.301492  0.165453         0.913160
# 43  0.289767  0.081819         0.825822
# 75  0.314384  0.071362         0.707897

# %%
DY0_09
# Out:
#     season_DY0         dob position  height  weight               playername  \
# 0    2008-2009  1989-02-25        D     180     196          David Kolomatis
# 1    2008-2009  1989-03-04       RW     188     203             Matt Kennedy
# 2    2008-2009  1989-03-22       RW     186     225              Kyle Neuber
# 3    2008-2009  1989-03-24        D     197     205         Oliver Lauridsen
# 4    2008-2009  1989-03-28       RW     185     201           Maxime Legault
# ..         ...         ...      ...     ...     ...                      ...
# 166  2008-2009  1991-08-25        C     188     187                 Cam Reid
# 167  2008-2009  1991-09-02     RW/C     180     198         Garrett Mitchell
# 168  2008-2009  1991-09-08        D     183     192         Gleason Fournier
# 169  2008-2009  1991-09-13        D     185     196  Charles-Olivier Roussel
# 170  2008-2009  1991-09-14        D     190     196             Curtis Gedig
#
#       NHLeDY0  NHLGeDY0  team_successDY0
# ...

# %% [markdown]
# ## Combining DY0 and DYn1 Datasets - now includes 13, 2014,15,16

# %%
DY0_7 = DY0_6.append(DY0_10, ignore_index = True)

# %%
DY0_7.head()
# Out:
#   season_DY0         dob  height  weight        playername position   NHLeDY0  \
# 0  2021-2022  2001-01-27     181     192     Lucas Edmonds    RW/LW  0.253563
# 1  2021-2022  2002-01-12     183     187     Petteri Nurmi        D  0.044052
# 2  2021-2022  2002-02-09     173     170  MiguÃ«l Tourigny        D  0.243123
# 3  2021-2022  2002-02-10     188     190    Daylan Kuefler       LW  0.112253
# 4  2021-2022  2002-02-18     180     170    Aidan Thompson        C  0.164331
#
#    NHLGeDY0  team_successDY0
# 0  0.076293         0.874386
# 1  0.009049         1.026830
# 2  0.094210         1.000000
# 3  0.072298         0.798226
# 4  0.048097         0.941925

# %%
DYn1_7 = DYn1_6.append(DYn1_10, ignore_index = True)

# %%
# DYn1 = DYn1.drop_duplicates(subset=['team', 'playername', 'gp', 'ppg'])

Final7 = pd.merge(DY0_7, DYn1_7, on =['playername','dob'])

# %%
Final7.loc[Final7.duplicated(subset=['playername']), :]
# Out:
#      season_DY0         dob  height_x  weight_x     playername position_x  \
# 600   2018-2019  2001-05-14       180       176    Jack Hughes          C
# 1267  2014-2015  1997-07-26       183       176  Sebastian Aho       C/LW
#
#        NHLeDY0  NHLGeDY0  team_successDY0 season_DYn1  height_y  weight_y  \
# 600   0.271624  0.080227         0.841677   2017-2018       180       176
# 1267  0.171808  0.035473         1.208593   2013-2014       183       176
#
#      position_y  NHLeDYn1  NHLGeDYn1  team_successDYn1
# 600           C  0.234772   0.085891          0.866627
# 1267       C/LW  0.131642   0.053659          0.807405

# %% [markdown]
# ## 2007 Skater and BIO Info

# %%
DYn1_09 = pd.read_csv("DYn1_09_5.csv")

# %%
DY0_08 = pd.read_csv("DY0_08_5.csv")

# %% [markdown]
# ## Combining DY0 and DYn1 Datasets - now includes 13, 2014,15,16

# %%
DY0_8 = DY0_7.append(DY0_09, ignore_index = True)

# %%
DY0_8.head()
# Out:
#   season_DY0         dob  height  weight        playername position   NHLeDY0  \
# 0  2021-2022  2001-01-27     181     192     Lucas Edmonds    RW/LW  0.253563
# 1  2021-2022  2002-01-12     183     187     Petteri Nurmi        D  0.044052
# 2  2021-2022  2002-02-09     173     170  MiguÃ«l Tourigny        D  0.243123
# 3  2021-2022  2002-02-10     188     190    Daylan Kuefler       LW  0.112253
# 4  2021-2022  2002-02-18     180     170    Aidan Thompson        C  0.164331
#
#    NHLGeDY0  team_successDY0
# 0  0.076293         0.874386
# 1  0.009049         1.026830
# 2  0.094210         1.000000
# 3  0.072298         0.798226
# 4  0.048097         0.941925

# %%
DYn1_8 = DYn1_7.append(DYn1_09, ignore_index = True)

# %%
# DYn1 = DYn1.drop_duplicates(subset=['team', 'playername', 'gp', 'ppg'])

Final8 = pd.merge(DY0_8, DYn1_8, on =['playername','dob'])

# %%
Final8.loc[Final8.duplicated(subset=['playername']), :]
# Out:
#      season_DY0         dob  height_x  weight_x     playername position_x  \
# 600   2018-2019  2001-05-14       180       176    Jack Hughes          C
# 1267  2014-2015  1997-07-26       183       176  Sebastian Aho       C/LW
# 2099  2008-2009  1991-02-07       185       216  Ryan O'Reilly          C
#
#        NHLeDY0  NHLGeDY0  team_successDY0 season_DYn1  height_y  weight_y  \
# 600   0.271624  0.080227         0.841677   2017-2018       180       176
# 1267  0.171808  0.035473         1.208593   2013-2014       183       176
# 2099  0.118137  0.031003         0.958279   2007-2008       185       216
#
#      position_y  NHLeDYn1  NHLGeDYn1  team_successDYn1
# 600           C  0.234772   0.085891          0.866627
# 1267       C/LW  0.131642   0.053659          0.807405
# 2099          C  0.101005   0.036906          1.137864

# %% [markdown]
# ## 2006 Skater and BIO Info

# %%
DYn1_08 = pd.read_csv("DYn1_08_5.csv")

# %%
DY0_07 = pd.read_csv("DY0_07_5.csv")

# %% [markdown]
# ## Combining DY0 and DYn1 Datasets - now includes 13, 2014,15,16

# %%
DY0_9 = DY0_8.append(DY0_08, ignore_index = True)

# %%
DY0_9.head()
# Out:
#   season_DY0         dob  height  weight        playername position   NHLeDY0  \
# 0  2021-2022  2001-01-27     181     192     Lucas Edmonds    RW/LW  0.253563
# 1  2021-2022  2002-01-12     183     187     Petteri Nurmi        D  0.044052
# 2  2021-2022  2002-02-09     173     170  MiguÃ«l Tourigny        D  0.243123
# 3  2021-2022  2002-02-10     188     190    Daylan Kuefler       LW  0.112253
# 4  2021-2022  2002-02-18     180     170    Aidan Thompson        C  0.164331
#
#    NHLGeDY0  team_successDY0
# 0  0.076293         0.874386
# 1  0.009049         1.026830
# 2  0.094210         1.000000
# 3  0.072298         0.798226
# 4  0.048097         0.941925

# %%
DYn1_9 = DYn1_8.append(DYn1_08, ignore_index = True)

# %%
# DYn1 = DYn1.drop_duplicates(subset=['team', 'playername', 'gp', 'ppg'])

Final9 = pd.merge(DY0_9, DYn1_9, on =['playername','dob'])

# %%
Final9.loc[Final9.duplicated(subset=['playername']), :]
# Out:
#      season_DY0         dob  height_x  weight_x     playername position_x  \
# 600   2018-2019  2001-05-14       180       176    Jack Hughes          C
# 1267  2014-2015  1997-07-26       183       176  Sebastian Aho       C/LW
# 2099  2008-2009  1991-02-07       185       216  Ryan O'Reilly          C
#
#        NHLeDY0  NHLGeDY0  team_successDY0 season_DYn1  height_y  weight_y  \
# 600   0.271624  0.080227         0.841677   2017-2018       180       176
# 1267  0.171808  0.035473         1.208593   2013-2014       183       176
# 2099  0.118137  0.031003         0.958279   2007-2008       185       216
#
#      position_y  NHLeDYn1  NHLGeDYn1  team_successDYn1
# 600           C  0.234772   0.085891          0.866627
# 1267       C/LW  0.131642   0.053659          0.807405
# 2099          C  0.101005   0.036906          1.137864

# %% [markdown]
# ## 2005 Skater and BIO Info

# %%
DYn1_07 = pd.read_csv("DYn1_07_5.csv")

# %%
DY0_06 = pd.read_csv("DY0_06_5.csv")

# %% [markdown]
# ## Combining DY0 and DYn1 Datasets - now includes 13, 2014,15,16

# %%
DY0_10 = DY0_9.append(DY0_07, ignore_index = True)

# %%
DY0_10.head()
# Out:
#   season_DY0         dob  height  weight        playername position   NHLeDY0  \
# 0  2021-2022  2001-01-27     181     192     Lucas Edmonds    RW/LW  0.253563
# 1  2021-2022  2002-01-12     183     187     Petteri Nurmi        D  0.044052
# 2  2021-2022  2002-02-09     173     170  MiguÃ«l Tourigny        D  0.243123
# 3  2021-2022  2002-02-10     188     190    Daylan Kuefler       LW  0.112253
# 4  2021-2022  2002-02-18     180     170    Aidan Thompson        C  0.164331
#
#    NHLGeDY0  team_successDY0
# 0  0.076293         0.874386
# 1  0.009049         1.026830
# 2  0.094210         1.000000
# 3  0.072298         0.798226
# 4  0.048097         0.941925

# %%
DYn1_10 = DYn1_9.append(DYn1_07, ignore_index = True)

# %%
# DYn1 = DYn1.drop_duplicates(subset=['team', 'playername', 'gp', 'ppg'])

Final10 = pd.merge(DY0_10, DYn1_10, on =['playername','dob'])

# %%
Final10.loc[Final10.duplicated(subset=['playername']), :]
# Out:
#      season_DY0         dob  height_x  weight_x     playername position_x  \
# 600   2018-2019  2001-05-14       180       176    Jack Hughes          C
# 1267  2014-2015  1997-07-26       183       176  Sebastian Aho       C/LW
# 2099  2008-2009  1991-02-07       185       216  Ryan O'Reilly          C
#
#        NHLeDY0  NHLGeDY0  team_successDY0 season_DYn1  height_y  weight_y  \
# 600   0.271624  0.080227         0.841677   2017-2018       180       176
# 1267  0.171808  0.035473         1.208593   2013-2014       183       176
# 2099  0.118137  0.031003         0.958279   2007-2008       185       216
#
#      position_y  NHLeDYn1  NHLGeDYn1  team_successDYn1
# 600           C  0.234772   0.085891          0.866627
# 1267       C/LW  0.131642   0.053659          0.807405
# 2099          C  0.101005   0.036906          1.137864

# %%
Final10 = Final10.drop([156])

# %%
#Final10.head()

# %%
Final10.describe()
# Out:
#           height_x     weight_x      NHLeDY0     NHLGeDY0  team_successDY0  \
# count  2449.000000  2449.000000  2448.000000  2448.000000      2448.000000
# mean    185.686811   195.168232     0.113615     0.042738         0.958534
# std       5.560305    15.709613     0.056396     0.028369         0.153860
# min     168.000000   150.000000     0.000000     0.000000         0.000000
# 25%     182.000000   185.000000     0.075951     0.021937         0.860995
# 50%     185.000000   194.000000     0.107452     0.038844         0.950206
# 75%     189.000000   205.000000     0.144341     0.058307         1.032080
# max     205.000000   258.000000     0.560401     0.285112         2.256617
#
#           height_y     weight_y     NHLeDYn1    NHLGeDYn1  team_successDYn1
# count  2449.000000  2449.000000  2446.000000  2446.000000       2446.000000
# mean    185.682728   195.139241     0.066088     0.024827          1.002437
# ...

# %%
Final10[Final10['NHLeDY0'] > .5]
# Out:
#      season_DY0         dob  height_x  weight_x       playername position_x  \
# 995   2015-2016  1997-09-17       191       205  Auston Matthews          C
# 1625  2011-2012  1993-11-12       190       214      Tomas Hertl       C/LW
#
#        NHLeDY0  NHLGeDY0  team_successDY0 season_DYn1  height_y  weight_y  \
# 995   0.557058  0.285112         0.822715   2014-2015       191       205
# 1625  0.560401  0.274993         1.070346   2010-2011       190       214
#
#      position_y  NHLeDYn1  NHLGeDYn1  team_successDYn1
# 995           C  0.225004   0.095783          0.756854
# 1625       C/LW  0.018462   0.018462          1.694349

# %%
Final10 = Final10.dropna()

# %%
Final10.describe()
# Out:
#           height_x     weight_x      NHLeDY0     NHLGeDY0  team_successDY0  \
# count  2445.000000  2445.000000  2445.000000  2445.000000      2445.000000
# mean    185.687117   195.161554     0.113645     0.042747         0.958374
# std       5.562163    15.698066     0.056392     0.028381         0.153754
# min     168.000000   150.000000     0.000000     0.000000         0.000000
# 25%     182.000000   185.000000     0.075958     0.021937         0.861046
# 50%     185.000000   194.000000     0.107492     0.038853         0.950206
# 75%     189.000000   205.000000     0.144340     0.058327         1.032080
# max     205.000000   258.000000     0.560401     0.285112         2.256617
#
#           height_y     weight_y     NHLeDYn1    NHLGeDYn1  team_successDYn1
# count  2445.000000  2445.000000  2445.000000  2445.000000       2445.000000
# mean    185.683027   195.132515     0.066090     0.024828          1.002438
# ...

# %% [markdown]
# # Cleaning the Final3 dataset
# - dont need to run when doing Final4, Final5....

# %%
Final10 = Final10.drop(columns = ['position_y','height_y','weight_y'])

# %%
Final10.head()
# Out:
#   season_DY0         dob  height_x  weight_x        playername position_x  \
# 0  2021-2022  2001-01-27       181       192     Lucas Edmonds      RW/LW
# 1  2021-2022  2002-01-12       183       187     Petteri Nurmi          D
# 2  2021-2022  2002-02-09       173       170  MiguÃ«l Tourigny          D
# 3  2021-2022  2002-02-10       188       190    Daylan Kuefler         LW
# 4  2021-2022  2002-02-18       180       170    Aidan Thompson          C
#
#     NHLeDY0  NHLGeDY0  team_successDY0 season_DYn1  NHLeDYn1  NHLGeDYn1  \
# 0  0.253563  0.076293         0.874386   2020-2021  0.075959   0.000000
# 1  0.044052  0.009049         1.026830   2020-2021  0.078291   0.017398
# 2  0.243123  0.094210         1.000000   2020-2021  0.228155   0.095065
# 3  0.112253  0.072298         0.798226   2020-2021  0.077822   0.028299
# 4  0.164331  0.048097         0.941925   2020-2021  0.074803   0.022668
#
#    team_successDYn1
# 0          1.392208
# 1          1.012425
# 2          0.829174
# ...

# %%
Final10["position_x"].value_counts()
# Out:
# D        872
# C        406
# RW       215
# LW       213
# C/LW     163
# LW/RW    104
# C/RW      94
# RW/LW     93
# LW/C      81
# C/W       72
# RW/C      58
# W/C       47
# F          7
# D/LW       6
# RW/D       4
# D/F        2
# D/C        2
# F/D        2
# W          2
# LW/D       1
# D/RW       1
# Name: position_x, dtype: int64

# %%
Final10[Final10['position_x']== "D/LW"]
# Out:
#      season_DY0         dob  height_x  weight_x        playername position_x  \
# 1302  2013-2014  1995-08-10       191       240  Mackenze Stewart       D/LW
# 1528  2012-2013  1995-04-19       193       216    Mason Geertsen       D/LW
# 1555  2012-2013  1995-07-12       197       203      Samuel Morin       D/LW
# 1577  2011-2012  1992-06-24       178       185     Joey LaLeggia       D/LW
# 1609  2011-2012  1993-09-21       193       205   Jaynen Rissling       D/LW
# 2209  2007-2008  1989-11-12       193       216       Harry Young       D/LW
#
#        NHLeDY0  NHLGeDY0  team_successDY0 season_DYn1  NHLeDYn1  NHLGeDYn1  \
# 1302  0.024468  0.012598         0.990647   2012-2013  0.006618   0.001324
# 1528  0.026081  0.003726         1.000000   2011-2012  0.012056   0.000000
# 1555  0.040979  0.008245         0.826989   2011-2012  0.016726   0.000000
# 1577  0.159478  0.046165         0.865935   2010-2011  0.086792   0.021169
# ...

# %%
pos = []
for i in Final10['position_x']:
    if i == "D":
        pos.append("D")
    elif i == "C":
        pos.append("F")
    elif i == "LW":
        pos.append("F")
    elif i == "RW":
        pos.append("F")
    elif i == "C/LW":
        pos.append("F")
    elif i == "LW/RW":
        pos.append("F")
    elif i == "RW/LW":
        pos.append("F")
    elif i == "C/RW":
        pos.append("F")
    elif i == "RW/C":
        pos.append("F")
    elif i == "C/W":
        pos.append("F")
    elif i == "LW/C":
        pos.append("F")
    elif i == "W/C":
        pos.append("F")
    elif i == "D/LW":
        pos.append("D")
    elif i == "F":
        pos.append("F")
    elif i == "RW/D":
        pos.append("F")
    elif i == "D/F":
        pos.append("F")
    elif i == "LW/D":
        pos.append("F")
    elif i == "D/RW":
        pos.append("F")
    elif i == "D/C":
        pos.append("F")
    elif i == "F/D":
        pos.append("F")
    elif i == "W":
        pos.append("F")
    else:
        pos.append(None)
Final10["position"] = pos

# %%
Final10["position"].value_counts()
# Out:
# F    1567
# D     878
# Name: position, dtype: int64

# %%
Final10 = Final10.drop(columns = 'position_x')

# %%
Final10.head()
# Out:
#   season_DY0         dob  height_x  weight_x        playername   NHLeDY0  \
# 0  2021-2022  2001-01-27       181       192     Lucas Edmonds  0.253563
# 1  2021-2022  2002-01-12       183       187     Petteri Nurmi  0.044052
# 2  2021-2022  2002-02-09       173       170  MiguÃ«l Tourigny  0.243123
# 3  2021-2022  2002-02-10       188       190    Daylan Kuefler  0.112253
# 4  2021-2022  2002-02-18       180       170    Aidan Thompson  0.164331
#
#    NHLGeDY0  team_successDY0 season_DYn1  NHLeDYn1  NHLGeDYn1  \
# 0  0.076293         0.874386   2020-2021  0.075959   0.000000
# 1  0.009049         1.026830   2020-2021  0.078291   0.017398
# 2  0.094210         1.000000   2020-2021  0.228155   0.095065
# 3  0.072298         0.798226   2020-2021  0.077822   0.028299
# 4  0.048097         0.941925   2020-2021  0.074803   0.022668
#
#    team_successDYn1 position
# 0          1.392208        F
# 1          1.012425        D
# 2          0.829174        D
# 3          0.842742        F
# ...

# %%
Final10['season_DY0'] = Final10['season_DY0'].str.split('-', n = 1, expand = False)

# %%
Final10['season_DY0'] = Final10['season_DY0'].str[0]

# %%
Final10['season_DYn1'] = Final10['season_DYn1'].str.split('-', n = 1, expand = False)

# %%
Final10['season_DYn1'] = Final10['season_DYn1'].str[0]

# %%
Final10.head()
# Out:
#   season_DY0         dob  height_x  weight_x        playername   NHLeDY0  \
# 0       2021  2001-01-27       181       192     Lucas Edmonds  0.253563
# 1       2021  2002-01-12       183       187     Petteri Nurmi  0.044052
# 2       2021  2002-02-09       173       170  MiguÃ«l Tourigny  0.243123
# 3       2021  2002-02-10       188       190    Daylan Kuefler  0.112253
# 4       2021  2002-02-18       180       170    Aidan Thompson  0.164331
#
#    NHLGeDY0  team_successDY0 season_DYn1  NHLeDYn1  NHLGeDYn1  \
# 0  0.076293         0.874386        2020  0.075959   0.000000
# 1  0.009049         1.026830        2020  0.078291   0.017398
# 2  0.094210         1.000000        2020  0.228155   0.095065
# 3  0.072298         0.798226        2020  0.077822   0.028299
# 4  0.048097         0.941925        2020  0.074803   0.022668
#
#    team_successDYn1 position
# 0          1.392208        F
# 1          1.012425        D
# 2          0.829174        D
# 3          0.842742        F
# ...

# %%
Final10['season_DY0'] = Final10['season_DY0'] + "-1-1"

# %%
Final10['season_DYn1'] = Final10['season_DYn1'] + "-1-1"

# %% [markdown]
# ## Fixing DOB

# %%
from datetime import datetime

# %%
from dateutil import relativedelta

# %%
Final10['season_DY0'] = pd.to_datetime(Final10['season_DY0'], format="%Y-%m-%d")

# %%
Final10['dob'] = pd.to_datetime(Final10['dob'], format="%Y-%m-%d")

# %%
#Final3.head()

# %%
Final10["age_DY0"] = (Final10["season_DY0"] - Final10["dob"]).dt.days

# %%
Final10["age_DY0"] = round(Final10["age_DY0"] / 365, 3)

# %%
Final10['season_DYn1'] = pd.to_datetime(Final10['season_DYn1'], format="%Y-%m-%d")

# %%
Final10["age_DYn1"] = (Final10["season_DYn1"] - Final10["dob"]).dt.days

# %%
Final10["age_DYn1"] = round(Final10["age_DYn1"] / 365, 3)

# %%
#Final3.head()

# %%
Final10 = Final10.drop(columns = ['season_DY0','dob','season_DYn1'])

# %%
Final10["NHLeDelta"] = Final10["NHLeDY0"] - Final10["NHLeDYn1"]
Final10["NHLGeDelta"] = Final10["NHLGeDY0"] - Final10["NHLGeDYn1"]

# %%
Final10.head()
# Out:
#    height_x  weight_x        playername   NHLeDY0  NHLGeDY0  team_successDY0  \
# 0       181       192     Lucas Edmonds  0.253563  0.076293         0.874386
# 1       183       187     Petteri Nurmi  0.044052  0.009049         1.026830
# 2       173       170  MiguÃ«l Tourigny  0.243123  0.094210         1.000000
# 3       188       190    Daylan Kuefler  0.112253  0.072298         0.798226
# 4       180       170    Aidan Thompson  0.164331  0.048097         0.941925
#
#    NHLeDYn1  NHLGeDYn1  team_successDYn1 position  age_DY0  age_DYn1  \
# 0  0.075959   0.000000          1.392208        F   19.942    18.940
# 1  0.078291   0.017398          1.012425        D   18.984    17.981
# 2  0.228155   0.095065          0.829174        D   18.907    17.904
# 3  0.077822   0.028299          0.842742        F   18.904    17.901
# 4  0.074803   0.022668          1.183537        F   18.882    17.879
#
#    NHLeDelta  NHLGeDelta
# 0   0.177603    0.076293
# 1  -0.034239   -0.008349
# ...

# %%
# Final3 = Final10

# %%
Combine2022 = pd.read_csv("2022Combine.csv", encoding='latin1')

# %%
Combine2019 = pd.read_csv("2019Combine.csv", encoding='latin1')

# %%
Combine2018 = pd.read_csv("2018Combine.csv", encoding='latin1')

# %%
Combine2017 = pd.read_csv("2017Combine.csv", encoding='latin1')

# %%
Combine2016 = pd.read_csv("2016Combine.csv", encoding='latin1')

# %%
Combine2015 = pd.read_csv("2015Combine.csv", encoding='latin1')

# %%
Combine2014 = pd.read_csv("2014Combine.csv", encoding='latin1')

# %%
Combine2013 = pd.read_csv("2013Combine.csv", encoding='latin1')

# %%
Combine2012 = pd.read_csv("2012Combine.csv", encoding='latin1')

# %%
Combine12_16 = Combine2016.append([Combine2022, Combine2019, Combine2018, Combine2017, Combine2015, Combine2014, Combine2013, Combine2012], ignore_index = True)

# %%
Combine12_16 = Combine12_16.drop(columns=['grip','upper_body','leg_strength','agility','fitness'])

# %%
Combine12_16.head(20)
# Out:
#             playername  combine_total
# 0       James Greenway            2.0
# 1    Jesse PuljujÃ¤rvi            2.0
# 2         Brett Murray            2.0
# 3       Matthew Cairns            4.0
# 4       Taylor Raddysh            3.0
# 5        Giovani Smith            2.0
# 6      Connor Bunnaman            4.0
# 7       Boris Katchouk            3.0
# 8     Keaton Middleton            1.0
# 9        Tage Thompson            1.0
# 10      Trent Frederic            4.0
# 11  Mikhail Sergachyov            2.0
# 12         Dylan Wells            2.0
# 13      Riley Stillman            1.0
# 14        Patrik Laine            1.0
# 15       Samuel Girard            2.0
# 16       Vojtech Budik            2.0
# 17          Tyson Jost            2.0
# 18     Carl Grundstrom            1.0
# 19      German Rubtsov            1.0

# %%
Final3 = pd.merge(Final10, Combine12_16, how='left', on ='playername')

# %%
Final3 = Final3.drop(columns=['team_successDY0'])

# %%
Combine12_16[Combine12_16['playername']=='Charles McAvoy']
# Out:
# Empty DataFrame
# Columns: [playername, combine_total]
# Index: []

# %%
Combine12_16
# Out:
#             playername  combine_total
# 0       James Greenway            2.0
# 1    Jesse PuljujÃ¤rvi            2.0
# 2         Brett Murray            2.0
# 3       Matthew Cairns            4.0
# 4       Taylor Raddysh            3.0
# ..                 ...            ...
# 978         Brady Vail            0.0
# 979     Mikko Vainonen            0.0
# 980  Andrei Vasilevski            0.0
# 981        Jimmy Vesey            0.0
# 982   Nicholas Walters            0.0
#
# [983 rows x 2 columns]

# %%
Final3[Final3['playername']== "Trent Frederic"]
# Out:
#       height_x  weight_x      playername   NHLeDY0  NHLGeDY0  NHLeDYn1  \
# 1040       191       209  Trent Frederic  0.087106   0.03786  0.015554
#
#       NHLGeDYn1  team_successDYn1 position  age_DY0  age_DYn1  NHLeDelta  \
# 1040   0.009333           0.90724        F   16.899    15.899   0.071551
#
#       NHLGeDelta  combine_total
# 1040    0.028528            4.0

# %%
Final3
# Out:
#       height_x  weight_x        playername   NHLeDY0  NHLGeDY0  NHLeDYn1  \
# 0          181       192     Lucas Edmonds  0.253563  0.076293  0.075959
# 1          183       187     Petteri Nurmi  0.044052  0.009049  0.078291
# 2          173       170  MiguÃ«l Tourigny  0.243123  0.094210  0.228155
# 3          188       190    Daylan Kuefler  0.112253  0.072298  0.077822
# 4          180       170    Aidan Thompson  0.164331  0.048097  0.074803
# ...        ...       ...               ...       ...       ...       ...
# 2445       183       192       Corey Tropp  0.118238  0.049584  0.034327
# 2446       180       196        Sam Gagner  0.209813  0.062233  0.084592
# 2447       185       190       Kyle Turris  0.114478  0.063449  0.065152
# 2448       189       209     Jakub Voracek  0.154668  0.043216  0.096000
# 2449       183       192    Aaron Palushaj  0.123210  0.040457  0.058593
#
#       NHLGeDYn1  team_successDYn1 position  age_DY0  age_DYn1  NHLeDelta  \
# ...

# %%
Final3[Final3['combine_total'].isna()]
# Out:
#       height_x  weight_x        playername   NHLeDY0  NHLGeDY0  NHLeDYn1  \
# 1          183       187     Petteri Nurmi  0.044052  0.009049  0.078291
# 2          173       170  MiguÃ«l Tourigny  0.243123  0.094210  0.228155
# 3          188       190    Daylan Kuefler  0.112253  0.072298  0.077822
# 4          180       170    Aidan Thompson  0.164331  0.048097  0.074803
# 5          188       185      Zakary Karpa  0.070372  0.035186  0.068759
# ...        ...       ...               ...       ...       ...       ...
# 2445       183       192       Corey Tropp  0.118238  0.049584  0.034327
# 2446       180       196        Sam Gagner  0.209813  0.062233  0.084592
# 2447       185       190       Kyle Turris  0.114478  0.063449  0.065152
# 2448       189       209     Jakub Voracek  0.154668  0.043216  0.096000
# 2449       183       192    Aaron Palushaj  0.123210  0.040457  0.058593
#
#       NHLGeDYn1  team_successDYn1 position  age_DY0  age_DYn1  NHLeDelta  \
# ...

# %%
#Final3['grip'] = Final3['grip'].astype(str)

# %%
#Final3['upper_body'] = Final3['upper_body'].astype(str)

# %%
#Final3['leg_strength'] = Final3['leg_strength'].astype(str)

# %%
#Final3['agility'] = Final3['agility'].astype(str)

# %%
#Final3['fitness'] = Final3['fitness'].astype(str)

# %%
Final3['combine_total'] = Final3['combine_total'].astype(str)

# %%
# gr = []
# for i in Final3['grip']:
#     if i == "nan":
#         gr.append("0.0")
#     else:
#         gr.append(i)
# Final3['grip'] = gr

# %%
# gr = []
# for i in Final3['upper_body']:
#     if i == "nan":
#         gr.append("0.0")
#     else:
#         gr.append(i)
# Final3['upper_body'] = gr

# %%
# gr = []
# for i in Final3['leg_strength']:
#     if i == "nan":
#         gr.append("0.0")
#     else:
#         gr.append(i)
# Final3['leg_strength'] = gr

# %%
# gr = []
# for i in Final3['agility']:
#     if i == "nan":
#         gr.append("0.0")
#     else:
#         gr.append(i)
# Final3['agility'] = gr

# %%
# gr = []
# for i in Final3['fitness']:
#     if i == "nan":
#         gr.append("0.0")
#     else:
#         gr.append(i)
# Final3['fitness'] = gr

# %%
Combine12_16['combine_total'].mean()
# Out:
# 1.2746693794506612

# %%
gr = []
for i in Final3['combine_total']:
    if i == "nan":
        gr.append("1.3120418848167539")
    else:
        gr.append(i)
Final3['combine_total'] = gr

# %%
#Final3['grip'] = Final3['grip'].astype(float)

# %%
#Final3['upper_body'] = Final3['upper_body'].astype(float)

# %%
#Final3['leg_strength'] = Final3['leg_strength'].astype(float)

# %%
#Final3['agility'] = Final3['agility'].astype(float)

# %%
#Final3['fitness'] = Final3['fitness'].astype(float)

# %%
Final3['combine_total'] = Final3['combine_total'].astype(float)

# %%
Final3.head()
# Out:
#    height_x  weight_x        playername   NHLeDY0  NHLGeDY0  NHLeDYn1  \
# 0       181       192     Lucas Edmonds  0.253563  0.076293  0.075959
# 1       183       187     Petteri Nurmi  0.044052  0.009049  0.078291
# 2       173       170  MiguÃ«l Tourigny  0.243123  0.094210  0.228155
# 3       188       190    Daylan Kuefler  0.112253  0.072298  0.077822
# 4       180       170    Aidan Thompson  0.164331  0.048097  0.074803
#
#    NHLGeDYn1  team_successDYn1 position  age_DY0  age_DYn1  NHLeDelta  \
# 0   0.000000          1.392208        F   19.942    18.940   0.177603
# 1   0.017398          1.012425        D   18.984    17.981  -0.034239
# 2   0.095065          0.829174        D   18.907    17.904   0.014968
# 3   0.028299          0.842742        F   18.904    17.901   0.034431
# 4   0.022668          1.183537        F   18.882    17.879   0.089527
#
#    NHLGeDelta  combine_total
# 0    0.076293       2.000000
# 1   -0.008349       1.312042
# 2   -0.000854       1.312042
# ...

# %% [markdown]
# ## Splitting into forwards and defensemen

# %%
Final3D = Final3.loc[Final3['position'] =='D']

# %%
Final3D = Final3D.drop(columns = 'position')

# %%
Final3F = Final3.loc[Final3['position'] =='F']

# %%
Final3F = Final3F.drop(columns = 'position')

# %%
Final3F.head()
# Out:
#    height_x  weight_x      playername   NHLeDY0  NHLGeDY0  NHLeDYn1  \
# 0       181       192   Lucas Edmonds  0.253563  0.076293  0.075959
# 3       188       190  Daylan Kuefler  0.112253  0.072298  0.077822
# 4       180       170  Aidan Thompson  0.164331  0.048097  0.074803
# 5       188       185    Zakary Karpa  0.070372  0.035186  0.068759
# 6       175       179    Patrick Guay  0.193761  0.102470  0.116769
#
#    NHLGeDYn1  team_successDYn1  age_DY0  age_DYn1  NHLeDelta  NHLGeDelta  \
# 0   0.000000          1.392208   19.942    18.940   0.177603    0.076293
# 3   0.028299          0.842742   18.904    17.901   0.034431    0.044000
# 4   0.022668          1.183537   18.882    17.879   0.089527    0.025429
# 5   0.022101          1.000000   18.786    17.784   0.001613    0.013085
# 6   0.058384          1.000000   18.690    17.688   0.076993    0.044086
#
#    combine_total
# 0       2.000000
# 3       1.312042
# 4       1.312042
# 5       1.312042
# 6       1.312042

# %% [markdown]
# - Next have to append the point shares data to this based on playername,
# - and then split the datasets to just get point shares and just the feature
# - Final3 should be for the 2014,15,16 drafts

# %%
Final3D.loc[Final3D['playername'] =='Cale Makar']
# Out:
#      height_x  weight_x  playername   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 848       180       187  Cale Makar  0.131155   0.04197  0.100244   0.018226
#
#      team_successDYn1  age_DY0  age_DYn1  NHLeDelta  NHLGeDelta  combine_total
# 848          0.680351   17.184    16.184   0.030911    0.023743            5.0

# %%
Final3D.describe()
# Out:
#          height_x    weight_x     NHLeDY0    NHLGeDY0    NHLeDYn1   NHLGeDYn1  \
# count  880.000000  880.000000  880.000000  880.000000  880.000000  880.000000
# mean   187.282955  198.389773    0.099130    0.024372    0.057805    0.014188
# std      5.401359   15.827185    0.052986    0.018604    0.044015    0.015634
# min    171.000000  150.000000    0.000000    0.000000    0.000000    0.000000
# 25%    183.000000  187.000000    0.060159    0.010922    0.026636    0.002923
# 50%    188.000000  196.000000    0.091967    0.020383    0.048753    0.010402
# 75%    191.000000  209.000000    0.128779    0.032675    0.078639    0.020574
# max    205.000000  258.000000    0.357232    0.131745    0.297286    0.143343
#
#        team_successDYn1     age_DY0    age_DYn1   NHLeDelta  NHLGeDelta  \
# count        880.000000  880.000000  880.000000  880.000000  880.000000
# mean           1.005165   17.087605   16.086950    0.041324    0.010184
# ...

# %%
Final3F.describe()
# Out:
#           height_x     weight_x      NHLeDY0     NHLGeDY0     NHLeDYn1  \
# count  1570.000000  1570.000000  1570.000000  1570.000000  1570.000000
# mean    184.783439   193.325478     0.121975     0.053077     0.071016
# std       5.448430    15.362223     0.056946     0.027732     0.046103
# min     168.000000   150.000000     0.000000     0.000000     0.000000
# 25%     180.000000   183.000000     0.085220     0.034796     0.038787
# 50%     185.000000   194.000000     0.113423     0.049005     0.061998
# 75%     188.000000   203.000000     0.150005     0.066845     0.095964
# max     205.000000   247.000000     0.560401     0.285112     0.503830
#
#          NHLGeDYn1  team_successDYn1      age_DY0     age_DYn1    NHLeDelta  \
# count  1570.000000       1570.000000  1570.000000  1570.000000  1570.000000
# mean      0.030856          1.000623    17.137450    16.136789     0.050959
# std       0.023854          0.270959     0.681944     0.681973     0.048397
# ...

# %%
Final3F.loc[Final3F['playername'] =='Connor McDavid']
# Out:
#       height_x  weight_x      playername   NHLeDY0  NHLGeDY0  NHLeDYn1  \
# 1184       185       194  Connor McDavid  0.377708  0.130023  0.240675
#
#       NHLGeDYn1  team_successDYn1  age_DY0  age_DYn1  NHLeDelta  NHLGeDelta  \
# 1184   0.067132          0.770938   16.978    15.978   0.137033    0.062891
#
#       combine_total
# 1184            2.0

# %%
Final3F.loc[Final3F['playername'] =='Kirill Kaprizov']
# Out:
#       height_x  weight_x       playername   NHLeDY0  NHLGeDY0  NHLeDYn1  \
# 1236       178       203  Kirill Kaprizov  0.251205  0.071939  0.165846
#
#       NHLGeDYn1  team_successDYn1  age_DY0  age_DYn1  NHLeDelta  NHLGeDelta  \
# 1236   0.053899          1.015545   16.696    15.696   0.085359     0.01804
#
#       combine_total
# 1236       1.312042

# %%
Final3F.loc[Final3F['NHLeDY0'] >= 0.23]
# Out:
#       height_x  weight_x            playername   NHLeDY0  NHLGeDY0  NHLeDYn1  \
# 0          181       192         Lucas Edmonds  0.253563  0.076293  0.075959
# 118        181       183         Joakim Kemell  0.237199  0.125521  0.081648
# 300        185       170        Maxim Marushev  0.259596  0.142587  0.143830
# 305        176       179  Benjamin Baumgartner  0.300093  0.077802  0.075041
# 334        176       183           Marco Rossi  0.320052  0.104017  0.181582
# ...        ...       ...                   ...       ...       ...       ...
# 2053       185       212          John Tavares  0.301492  0.165453  0.225772
# 2056       175       174      Jordan Schroeder  0.289767  0.081819  0.146111
# 2128       187       205       Magnus Pääjärvi  0.235948  0.093824  0.090362
# 2160       188       209          Evander Kane  0.246063  0.116182  0.097109
# 2361       178       176          Patrick Kane  0.295255  0.134245  0.179686
#
# ...

# %%
Final3F = Final3F.drop_duplicates(subset=['playername', 'NHLeDY0'])

# %%
Final3D = Final3D.drop_duplicates(subset=['playername', 'NHLeDY0'])

# %%
Final3F.loc[Final3F['NHLeDelta'] <=.02]
# Out:
#       height_x  weight_x        playername   NHLeDY0  NHLGeDY0  NHLeDYn1  \
# 5          188       185      Zakary Karpa  0.070372  0.035186  0.068759
# 14         182       179     Dominic James  0.081294  0.023697  0.077070
# 19         182       168     Linus SjÃ¶din  0.090478  0.049964  0.104837
# 44         180       170       Jack Hughes  0.079394  0.034735  0.090510
# 47         191       207    Nathan Gaucher  0.102767  0.055342  0.129942
# ...        ...       ...               ...       ...       ...       ...
# 2424       183       201       Brett Sonne  0.071721  0.050205  0.055696
# 2426       188       216       Brad Malone  0.059621  0.025294  0.053464
# 2427       191       185  Justin Courtnall  0.012450  0.004446  0.000000
# 2438       197       238      Justin Vaive  0.049309  0.023582  0.057212
# 2441       181       185      Andrew Glass  0.043281  0.017821  0.061629
#
#       NHLGeDYn1  team_successDYn1  age_DY0  age_DYn1  NHLeDelta  NHLGeDelta  \
# ...

# %%
Final3D.loc[Final3D['NHLeDY0'] >= 0.23]
# Out:
#       height_x  weight_x             playername   NHLeDY0  NHLGeDY0  NHLeDYn1  \
# 2          173       170       MiguÃ«l Tourigny  0.243123  0.094210  0.228155
# 312        185       192            Adam Wilsby  0.249688  0.038538  0.144152
# 473        191       207          Ronnie Attard  0.238348  0.111726  0.059109
# 650        183       194             Sean Durzi  0.250139  0.076573  0.138394
# 680        191       194          Evan Bouchard  0.265148  0.076192  0.141394
# 755        190       207          Rasmus Dahlin  0.246310  0.065662  0.150058
# 797        180       183          Sebastian Aho  0.318008  0.106003  0.297286
# 987        190       205         Filip Berglund  0.232425  0.107709  0.085664
# 1137       187       196         Petter Hansson  0.259726  0.106867  0.062142
# 1205       180       190  Mitchell Vande Sompel  0.239527  0.045624  0.094676
# 1315       180       181          Tony DeAngelo  0.309739  0.065438  0.190150
# ...

# %%
Final3D.loc[Final3D['age_DY0'] >= 18.5]
# Out:
#       height_x  weight_x             playername   NHLeDY0  NHLGeDY0  NHLeDYn1  \
# 1          183       187          Petteri Nurmi  0.044052  0.009049  0.078291
# 2          173       170       MiguÃ«l Tourigny  0.243123  0.094210  0.228155
# 8          193       205        Hunter McDonald  0.037905  0.010830  0.022932
# 10         191       216         Victor Mancini  0.030627  0.000000  0.075214
# 147        185       183             J.J. Moser  0.120087  0.036026  0.103742
# 149        186       194        Daniil Pylenkov  0.217112  0.056054  0.065064
# 307        182       192           Axel Rindell  0.178053  0.050815  0.142906
# 310        191       203            Matt Kessel  0.078581  0.050006  0.054782
# 473        191       207          Ronnie Attard  0.238348  0.111726  0.059109
# 644        179       183        Jesper Sellgren  0.084372  0.018645  0.085293
# 797        180       183          Sebastian Aho  0.318008  0.106003  0.297286
# ...

# %% [markdown]
# ## Inserting Point Shares datasets which say how good the player actually turned out to be in the NHL

# %%
#PS2014 = pd.read_csv("2014DraftPS3.csv")

# %%
#PS2014.head()

# %%
#PS2014 = PS2014.drop(columns = ['Player', 'GP','GP_new','Pos','PS', 'Years1','MajorYears'])

# %%
#PS2014.head()

# %%
#PS2014F = PS2014.loc[PS2014['position'] =='F']

# %%
#PS2014F = PS2014F.drop(columns = 'position')

# %%
#PS2014F.describe()

# %%
#PS2014F.head()

# %%
#PS2014D = PS2014.loc[PS2014['position'] =='D']

# %%
#PS2014D = PS2014D.drop(columns = 'position')

# %%
#PS2014D.describe()

# %%
#PS2014D.head()

# %% [markdown]
# ## PS 2015

# %%
#PS2015 = pd.read_csv("2015DraftPS2.csv")

# %%
#PS2015.head()

# %%
#PS2015 = PS2015.drop(columns = ['GP','Pos','PS','Years1','MajorYears'])

# %%
#PS2015F = PS2015.loc[PS2015['position'] =='F']

# %%
#PS2015F = PS2015F.drop(columns = 'position')

# %%
#PS2015F.describe()

# %%
#PS2015D = PS2015.loc[PS2015['position'] =='D']

# %%
#PS2015D = PS2015D.drop(columns = 'position')

# %%
#PS2015D.describe()

# %% [markdown]
# ## 2016 PS

# %%
#PS2016 = pd.read_csv("2016DraftPS2.csv")

# %%
#PS2016.head()

# %%
#PS2016 = PS2016.drop(columns = ['GP','Pos','PS','Years1','MajorYears'])

# %%
#PS2016F = PS2016.loc[PS2016['position'] =='F']

# %%
#PS2016F = PS2016F.drop(columns = 'position')

# %%
#PS2016F.describe()

# %%
#PS2016D = PS2016.loc[PS2016['position'] =='D']

# %%
#PS2016D = PS2016D.drop(columns = 'position')

# %%
#PS2016D.describe()

# %% [markdown]
# ## PS 2017

# %%
PS2017 = pd.read_csv("2023DraftPS2.csv", encoding='latin1')

# %%
PS2017.head()
# Out:
#          playername Pos position  GP  PS  PS_new
# 0     Connor Bedard   C        F   0   0       0
# 1      Leo Carlsson   C        F   0   0       0
# 2     Adam Fantilli   C        F   0   0       0
# 3     William Smith   C        F   0   0       0
# 4  David Reinbacher   D        D   0   0       0

# %%
PS2017 = PS2017.drop(columns = ['Pos','GP','PS'])

# %%
PS2017F = PS2017.loc[PS2017['position'] =='F']

# %%
PS2017D = PS2017.loc[PS2017['position'] =='D']

# %%
PS2017F = PS2017F.drop(columns = 'position')

# %%
PS2017F.describe()
# Out:
#        PS_new
# count   129.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0

# %%
PS2017F.head()
# Out:
#        playername  PS_new
# 0   Connor Bedard       0
# 1    Leo Carlsson       0
# 2   Adam Fantilli       0
# 3   William Smith       0
# 6  Matvei Michkov       0

# %%
PS2017F2 = PS2017F.drop(columns='playername')

# %%
PS2017F2
# Out:
#      PS_new
# 0         0
# 1         0
# 2         0
# 3         0
# 6         0
# ..      ...
# 216       0
# 217       0
# 218       0
# 220       0
# 223       0
#
# [129 rows x 1 columns]

# %%
PS2017D.head()
# Out:
#               playername position  PS_new
# 4       David Reinbacher        D       0
# 5       Dmitriy Simashev        D       0
# 10         Tom Willander        D       0
# 16  Axel Sandin Pellikka        D       0
# 21           Oliver Bonk        D       0

# %%
PS2017D2 = PS2017D.drop(columns=['position','playername'])

# %%
PS2017D2.head()
# Out:
#     PS_new
# 4        0
# 5        0
# 10       0
# 16       0
# 21       0

# %%
Test17F.head()
# Out:
#    height_x       playername   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 1       185      Justin Gill  0.166837  0.078933  0.085702   0.037262
# 2       180     Brett Hyland  0.136053  0.075263  0.058793   0.026356
# 3       198  Milton Oscarson  0.065633  0.033680  0.102271   0.035310
# 4       180       Ty Mueller  0.134468  0.064545  0.104825   0.064508
# 6       178      Jack Harvey  0.127937  0.069155  0.090278   0.047903
#
#    team_successDYn1  NHLeDelta  NHLGeDelta   age0new
# 1          0.864152   0.081135    0.041672  0.052793
# 2          1.050876   0.077260    0.048908  0.052960
# 3          0.872598  -0.036637   -0.001630  0.052960
# 4          0.875647   0.029643    0.000037  0.053022
# 6          0.843313   0.037659    0.021252  0.053277

# %%
#T17MergeD = pd.merge(PS2017D, Test17D, on ='playername', how='right')

# %%
T17MergeD = Test17D

# %%
T17MergeD.head()
# Out:
#    height_x              playername   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 0       180        Luke Mittelstadt  0.130248  0.022770  0.134020   0.046298
# 1       185           Jeremy Hanzel  0.132490  0.035883  0.094889   0.020128
# 2       191  Charles-Alexis Legault  0.053281  0.011840  0.039488   0.013163
# 3       190          Rasmus Larsson  0.118038  0.055547  0.000000   0.000000
# 4       188        Dennis Good Bogg  0.121215  0.017316  0.030074   0.007450
#
#    team_successDYn1  NHLeDelta  NHLGeDelta   age0new
# 0          0.913627  -0.003772   -0.023528  0.052754
# 1          0.845354   0.037602    0.015755  0.053028
# 2          0.784031   0.013793   -0.001322  0.054535
# 3          1.175042   0.118038    0.055547  0.055844
# 4          0.993434   0.091141    0.009867  0.056032

# %%
#T17Merge = pd.merge(PS2017F, Test17F, on ='playername', how='right')

# %%
T17Merge = Test17F

# %%
T17Merge.head()
# Out:
#    height_x       playername   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 1       185      Justin Gill  0.166837  0.078933  0.085702   0.037262
# 2       180     Brett Hyland  0.136053  0.075263  0.058793   0.026356
# 3       198  Milton Oscarson  0.065633  0.033680  0.102271   0.035310
# 4       180       Ty Mueller  0.134468  0.064545  0.104825   0.064508
# 6       178      Jack Harvey  0.127937  0.069155  0.090278   0.047903
#
#    team_successDYn1  NHLeDelta  NHLGeDelta   age0new
# 1          0.864152   0.081135    0.041672  0.052793
# 2          1.050876   0.077260    0.048908  0.052960
# 3          0.872598  -0.036637   -0.001630  0.052960
# 4          0.875647   0.029643    0.000037  0.053022
# 6          0.843313   0.037659    0.021252  0.053277

# %%
Combine2018 = pd.read_csv("2023Combine.csv", encoding='latin1')

# %%
Combine2018.head(50)
# Out:
#               playername  combine_total
# 0        Jordan Tourigny              1
# 1           Jakub Dvorak              1
# 2         Michael Hrabal              1
# 3            Matteo Mann              1
# 4      Terrell Goldsmith              1
# 5          Ethan Miedema              1
# 6          Carsen Musser              1
# 7         Jaden Lipinski              2
# 8           Paul Fischer              2
# 9          Nico Myatovic              2
# 10         Brad Gardiner              5
# 11         Bradly Nadeau              4
# 12            Noel Nordh              2
# 13   Beckett Hendrickson              1
# 14          Easton Cowan              3
# 15        Aram Minnetian              1
# 16    Hunter Brzustewicz              3
# 17  Axel Sandin Pellikka              2
# 18     Jonathan Castagna              5
# 19          Oliver Moore              5
# 20       Brandon Svoboda              2
# 21         Jayden Perron              1
# ...

# %%
Combine2018[Combine2018['playername']=='Quinn Hughes']
# Out:
# Empty DataFrame
# Columns: [playername, combine_total]
# Index: []

# %%
T17MergeD = pd.merge(T17MergeD, Combine2018, how='left', on ='playername')

# %%
T17MergeD.tail()
# Out:
#     height_x        playername   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 47       185    Gavin McCarthy  0.088737  0.026292  0.035861   0.005517
# 48       194       Axel Hurtig  0.035181  0.007233  0.020495   0.000000
# 49       185       Zach Schulz  0.031699  0.005153  0.030961   0.001720
# 50       188  Tristan Bertucci  0.114247  0.025134  0.039349   0.003027
# 51       185       Caden Price  0.111227  0.011530  0.080940   0.007709
#
#     team_successDYn1  NHLeDelta  NHLGeDelta   age0new  combine_total
# 47          0.831543   0.052876    0.020775  0.060259            NaN
# 48          0.803447   0.014686    0.007233  0.060339            NaN
# 49          0.936561   0.000739    0.003433  0.060379            NaN
# 50          0.871329   0.074897    0.022107  0.060661            0.0
# 51          0.916364   0.030288    0.003821  0.061099            1.0

# %%
T17MergeD[T17MergeD['playername']=="K'Andre Miller"]
# Out:
# Empty DataFrame
# Columns: [height_x, playername, NHLeDY0, NHLGeDY0, NHLeDYn1, NHLGeDYn1, team_successDYn1, NHLeDelta, NHLGeDelta, age0new, combine_total]
# Index: []

# %%
T17Merge = pd.merge(T17Merge, Combine2018, how='left', on ='playername')

# %%
T17Merge.tail(50)
# Out:
#     height_x              playername   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 47       180            Oliver Moore  0.133416  0.053393  0.095634   0.050474
# 48       184              Kalan Lind  0.124407  0.045239  0.077039   0.040547
# 49       183          Ethan Gauthier  0.127533  0.055449  0.076014   0.035083
# 50       185            Tyler Peddle  0.078149  0.045746  0.068218   0.033134
# 51       189       Yegor Rimashevsky  0.117199  0.058599  0.075526   0.046478
# 52       178         Andrew Cristall  0.194559  0.077965  0.139887   0.056766
# 53       193            Matthew Wood  0.201180  0.081054  0.116528   0.065874
# 54       185            Colby Barlow  0.177974  0.106276  0.121552   0.077586
# 55       184       Mikhail Ye. Ilyin  0.109505  0.013897  0.055773   0.022309
# 56       195              Daniil But  0.128595  0.080610  0.125205   0.048375
# 57       183  Oscar Fisker MÃ¸lgaard  0.105744  0.043189  0.036956   0.013859
# ...

# %%
#T17Merge['grip'] = T17Merge['grip'].astype(str)

# %%
#T17Merge['upper_body'] = T17Merge['upper_body'].astype(str)

# %%
#T17Merge['leg_strength'] = T17Merge['leg_strength'].astype(str)

# %%
#T17Merge['agility'] = T17Merge['agility'].astype(str)

# %%
#T17Merge['fitness'] = T17Merge['fitness'].astype(str)

# %%
T17Merge['combine_total'] = T17Merge['combine_total'].astype(str)

# %%
Combine2018['combine_total'].mean()
# Out:
# 0.9528301886792453

# %%
# gr = []
# for i in T17Merge['grip']:
#     if i == "nan":
#         gr.append("0.0")
#     else:
#         gr.append(i)
# T17Merge['grip'] = gr

# %%
# gr = []
# for i in T17Merge['upper_body']:
#     if i == "nan":
#         gr.append("0.0")
#     else:
#         gr.append(i)
# T17Merge['upper_body'] = gr

# %%
# gr = []
# for i in T17Merge['leg_strength']:
#     if i == "nan":
#         gr.append("0.0")
#     else:
#         gr.append(i)
# T17Merge['leg_strength'] = gr

# %%
# gr = []
# for i in T17Merge['agility']:
#     if i == "nan":
#         gr.append("0.0")
#     else:
#         gr.append(i)
# T17Merge['agility'] = gr

# %%
# gr = []
# for i in T17Merge['fitness']:
#     if i == "nan":
#         gr.append("0.0")
#     else:
#         gr.append(i)
# T17Merge['fitness'] = gr

# %%
gr = []
for i in T17Merge['combine_total']:
    if i == "nan":
        gr.append("1.5576923076923077")
    else:
        gr.append(i)
T17Merge['combine_total'] = gr

# %%
#T17Merge['grip'] = T17Merge['grip'].astype(float)

# %%
#T17Merge['upper_body'] = T17Merge['upper_body'].astype(float)

# %%
#T17Merge['leg_strength'] = T17Merge['leg_strength'].astype(float)

# %%
#T17Merge['agility'] = T17Merge['agility'].astype(float)

# %%
#T17Merge['fitness'] = T17Merge['fitness'].astype(float)

# %%
T17Merge['combine_total'] = T17Merge['combine_total'].astype(float)

# %%
T17Merge.head(20)
# Out:
#     height_x         playername   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 0        185        Justin Gill  0.166837  0.078933  0.085702   0.037262
# 1        180       Brett Hyland  0.136053  0.075263  0.058793   0.026356
# 2        198    Milton Oscarson  0.065633  0.033680  0.102271   0.035310
# 3        180         Ty Mueller  0.134468  0.064545  0.104825   0.064508
# 4        178        Jack Harvey  0.127937  0.069155  0.090278   0.047903
# 5        180       Matt Copponi  0.143336  0.069197  0.069668   0.023223
# 6        181  Stanislav Yarovoy  0.199883  0.103321  0.082166   0.034858
# 7        180         Sam Harris  0.107191  0.057424  0.066634   0.030461
# 8        187    Michael Emerson  0.114337  0.053595  0.022211   0.012692
# 9        178       Austin Roest  0.158053  0.064842  0.067074   0.027249
# 10       193    Casper NÃ¤ssÃ©n  0.085663  0.049256  0.009624   0.000000
# 11       195           Samu Bau  0.063615  0.020977  0.043435   0.021353
# ...

# %%
T17Merge['agexNHLe'] = T17Merge['age0new'] * T17Merge['NHLeDY0']

# %%
# ff = []
# for i in T17Merge['years']:
#     if i < 0.25 and i >= 0:  
#         ff.append(1)
#     else:
#         ff.append(0)
# T17Merge['ManyYears'] = ff

# %%
#ff = []
#for i in T17Merge['years']:
#    if i == 0.250000:  
#        ff.append(1)
#    else:
#        ff.append(0)
#T17Merge['medYears'] = ff

# %%
#ff = []
#for i in T17Merge['years']:
#    if i == 0.333333:  
#        ff.append(1)
#    else:
#        ff.append(0)
#T17Merge['FewishYears'] = ff

# %%
# ff = []
# for i in T17Merge['years']:
#     if i > 0.500000:  
#         ff.append(1)
#     else:
#         ff.append(0)
# T17Merge['FewYears'] = ff

# %%
# ff = []
# for i in T17Merge['NHLeDelta']:
#     if i <= 0:  
#         ff.append(1)
#     else:
#         ff.append(0)
# T17Merge['NoImprove'] = ff

# %%
#T17MergeD['grip'] = T17MergeD['grip'].astype(str)

# %%
#T17MergeD['upper_body'] = T17MergeD['upper_body'].astype(str)

# %%
#T17MergeD['leg_strength'] = T17MergeD['leg_strength'].astype(str)

# %%
#T17MergeD['agility'] = T17MergeD['agility'].astype(str)

# %%
#T17MergeD['fitness'] = T17MergeD['fitness'].astype(str)

# %%
T17MergeD['combine_total'] = T17MergeD['combine_total'].astype(str)

# %%
# gr = []
# for i in T17MergeD['grip']:
#     if i == "nan":
#         gr.append("0.0")
#     else:
#         gr.append(i)
# T17MergeD['grip'] = gr

# %%
# gr = []
# for i in T17MergeD['upper_body']:
#     if i == "nan":
#         gr.append("0.0")
#     else:
#         gr.append(i)
# T17MergeD['upper_body'] = gr

# %%
# gr = []
# for i in T17MergeD['leg_strength']:
#     if i == "nan":
#         gr.append("0.0")
#     else:
#         gr.append(i)
# T17MergeD['leg_strength'] = gr

# %%
# gr = []
# for i in T17MergeD['agility']:
#     if i == "nan":
#         gr.append("0.0")
#     else:
#         gr.append(i)
# T17MergeD['agility'] = gr

# %%
# gr = []
# for i in T17MergeD['fitness']:
#     if i == "nan":
#         gr.append("0.0")
#     else:
#         gr.append(i)
# T17MergeD['fitness'] = gr

# %%
gr = []
for i in T17MergeD['combine_total']:
    if i == "nan":
        gr.append("1.5576923076923077")
    else:
        gr.append(i)
T17MergeD['combine_total'] = gr

# %%
#T17MergeD['grip'] = T17MergeD['grip'].astype(float)

# %%
#T17MergeD['upper_body'] = T17MergeD['upper_body'].astype(float)

# %%
#T17MergeD['leg_strength'] = T17MergeD['leg_strength'].astype(float)

# %%
#T17MergeD['agility'] = T17MergeD['agility'].astype(float)

# %%
#T17MergeD['fitness'] = T17MergeD['fitness'].astype(float)

# %%
T17MergeD['combine_total'] = T17MergeD['combine_total'].astype(float)

# %%
T17MergeD.head(20)
# Out:
#     height_x              playername   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 0        180        Luke Mittelstadt  0.130248  0.022770  0.134020   0.046298
# 1        185           Jeremy Hanzel  0.132490  0.035883  0.094889   0.020128
# 2        191  Charles-Alexis Legault  0.053281  0.011840  0.039488   0.013163
# 3        190          Rasmus Larsson  0.118038  0.055547  0.000000   0.000000
# 4        188        Dennis Good Bogg  0.121215  0.017316  0.030074   0.007450
# 5        180           Eric Pohlkamp  0.119318  0.037433  0.043142   0.016777
# 6        187         Rodwin Dionicio  0.156616  0.053985  0.086830   0.016806
# 7        183            Kalem Parker  0.101803  0.016074  0.055042   0.009754
# 8        189        David Reinbacher  0.115416  0.012817  0.081272   0.004271
# 9        197            Konnor Smith  0.040601  0.008120  0.043307   0.014436
# 10       183      Hunter Brzustewicz  0.147479  0.015524  0.054666   0.003249
# ...

# %%
T17MergeD['agexNHLe'] = T17MergeD['age0new'] * T17MergeD['NHLeDY0']

# %%
T17MergeD = T17MergeD.dropna()

# %%
PS2017D2 = T17MergeD.drop(columns = ['height_x','playername','combine_total','agexNHLe','NHLGeDY0','NHLGeDYn1','NHLGeDelta','NHLeDY0','NHLeDYn1','NHLeDelta','age0new'])

# %%
PS2017D2
# Out:
#     team_successDYn1
# 0           0.913627
# 1           0.845354
# 2           0.784031
# 3           1.175042
# 4           0.993434
# 5           1.138369
# 6           1.233698
# 7           1.152536
# 8           1.335831
# 9           1.038333
# 10          0.902126
# 11          1.023189
# 12          0.768761
# 13          1.252261
# 14          1.149407
# 15          1.341464
# 16          0.992829
# 17          0.943939
# 18          1.119065
# 19          0.870507
# 20          0.934892
# 21          0.877055
# 22          1.046077
# 23          0.896590
# 24          0.673655
# 25          0.980231
# 26          1.017143
# 27          0.818750
# 28          1.087054
# 29          1.138355
# 30          1.411462
# 31          0.912654
# 32          0.798226
# 33          1.055932
# 34          0.932030
# 35          0.928278
# 36          1.038499
# 37          0.944404
# 38          0.874386
# 39          0.964318
# 40          1.221963
# 41          0.804960
# ...

# %%
Test17D2 = T17MergeD.drop(columns = ['playername','NHLGeDY0','agexNHLe','NHLGeDYn1','NHLGeDelta'])

# %%
#Test17D2 = Test17D2.drop(columns=['grip','agility','upper_body','leg_strength','fitness'])

# %%
import math as m

# %%
# Test17D2['NHLe0sqrt'] = [m.sqrt(i) for i in Test17D2['NHLeDY0']]

# %%
# Test17D2['NHLe1sqrt'] = [m.sqrt(i) for i in Test17D2['NHLeDYn1']]

# %%
Test17D2['NHLecomb3'] = (Test17D2['NHLeDY0'] * 0.6) + (Test17D2['NHLeDYn1'] * 0.4)

# %%
Test17D2['NHLecomb3'].max()
# Out:
# 0.1762716329065217

# %%
Test17D2['NHLecomb3'].min()
# Out:
# 0.015327912510755399

# %%
Test17D2['NHLecomb3'] = (Test17D2['NHLecomb3'] - 0.015327912510755399) / (0.1762716329065217 - 0.015327912510755399)

# %%
Test17D2['NHLecomb3'] = [m.sqrt(i) for i in Test17D2['NHLecomb3']]

# %%
sns.distplot(Test17D2['NHLecomb3'])
# Out:
# <AxesSubplot:xlabel='NHLecomb3', ylabel='Density'>

# %%
Test17D2['age0new'].max()
# Out:
# 0.061098551964318445

# %%
Test17D2['age0new'].min()
# Out:
# 0.052753745515931635

# %%
Test17D2['age0new'] = (Test17D2['age0new'] - 0.052753745515931635) /  (0.061098551964318445 - 0.052753745515931635)

# %%
Test17D2['age0new'] = [i**2 for i in Test17D2['age0new']]

# %%
sns.distplot(Test17D2['age0new'])
# Out:
# <AxesSubplot:xlabel='age0new', ylabel='Density'>

# %%
sns.distplot(Test17D2['NHLecomb3'])
# Out:
# <AxesSubplot:xlabel='NHLecomb3', ylabel='Density'>

# %%
#Test17F2['NHLesqrt'] = [m.sqrt(i) for i in Test17F2['NHLe01']]

# %%
# Test17D2['successDY0log'] = [m.log(i) for i in Test17D2['team_successDY0']]

# %%
Test17D2 = Test17D2.drop(columns=['NHLeDY0','NHLeDYn1','NHLeDelta'])

# %%
# Test17D2 = Test17D2.drop(columns=['NHLe0sqrt','NHLe1sqrt'])

# %%
#Test17D2 = Test17D2.drop(columns=['position'])

# %%
a = []
for i in Test17D2['combine_total']:
    if i == 1:
        a.append(1)
    elif i == 2:
        a.append(1)
    else:
        a.append(0)
Test17D2['Comb1-2'] = a

# %%
b = []
for i in Test17D2['combine_total']:
    if i == 4:
        b.append(1)
    elif i == 3:
        b.append(1)
    elif i == 5:
        b.append(1)
    elif i == 6:
        b.append(1)
    elif i >= 7:
        b.append(1)
    else:
        b.append(0)
Test17D2['Comb3+'] = b

# %%
# c = []
# for i in Test17D2['combine_total']:
#     if i >= 7:
#         c.append(1)
#     else:
#         c.append(0)
# Test17D2['Comb7+'] = c

# %%
d = []
for i in Test17D2['combine_total']:
    if i == 0:
        d.append(1)
    else:
        d.append(0)
Test17D2['Comb0'] = d

# %%
Test17D2 = Test17D2.drop(columns='combine_total')

# %%
Test17D2['height_x'].max()
# Out:
# 197

# %%
# Test17D2['height'] = Test17D2['height_x'] / 197

# %%
a = [] 
for i in Test17D2['height_x']:
    if i < 0.9:
        a.append(1)
    else:
        a.append(0)
Test17D2['low_height'] = a

# %%
Test17D2['height_x'].max()
# Out:
# 197

# %%
Test17D2['height_x'].min()
# Out:
# 175

# %%
Test17D2['height'] = (Test17D2['height_x'] - 175) /  (197 - 175)

# %%
sns.distplot(Test17D2['height'])
# Out:
# <AxesSubplot:xlabel='height', ylabel='Density'>

# %%
Test17D2 = Test17D2.drop(columns=['low_height','height_x','height'])

# %%
#Test17D2['combine_total'] = Test17D2['combine_total'] / 8

# %%
### Add combine dummy variables here

# %%
# Test17D2['successDY0std'] = [(i - (Test17D2['successDY0log'].mean()))/ s.stdev(Test17D2['successDY0log']) for i in Test17D2['successDY0log']]

# %%
# Test17D2['successDYn1std'] = [(i - (Test17D2['team_successDYn1'].mean()))/ s.stdev(Test17D2['team_successDYn1']) for i in Test17D2['team_successDYn1']]

# %%
# Test17D2['NHLestd'] = [(i - (Test17D2['NHLecomb3'].mean()))/ s.stdev(Test17D2['NHLecomb3']) for i in Test17D2['NHLecomb3']]

# %%
# Test17D2['Agestd'] = [(i - (Test17D2['age0new'].mean()))/ s.stdev(Test17D2['age0new']) for i in Test17D2['age0new']]

# %%
# Test17D2 = Test17D2.drop(columns=['age0new','NHLecomb3'])

# %%
Test17D2 = Test17D2.drop(columns=['team_successDYn1'])

# %%
Test17D2.head()
# Out:
#     age0new  NHLecomb3  Comb1-2  Comb3+  Comb0
# 0  0.000000   0.850537        0       0      0
# 1  0.001079   0.796566        0       0      0
# 2  0.045541   0.448927        0       0      0
# 3  0.137145   0.587205        0       0      0
# 4  0.154314   0.656810        0       0      0

# %%
T17Merge.describe()
# Out:
#          height_x    NHLeDY0   NHLGeDY0   NHLeDYn1  NHLGeDYn1  \
# count   97.000000  97.000000  97.000000  97.000000  97.000000
# mean   184.164948   0.131734   0.057606   0.078432   0.036137
# std      5.570907   0.053705   0.026814   0.042055   0.022876
# min    173.000000   0.049841   0.013897   0.004760   0.000000
# 25%    180.000000   0.095531   0.041303   0.049571   0.021353
# 50%    183.000000   0.126480   0.053638   0.075377   0.034738
# 75%    188.000000   0.148244   0.069155   0.095634   0.046556
# max    200.000000   0.406843   0.184960   0.270361   0.147957
#
#        team_successDYn1  NHLeDelta  NHLGeDelta    age0new  combine_total  \
# count         97.000000  97.000000   97.000000  97.000000      97.000000
# mean           0.956861   0.053301    0.021469   0.058599       1.257534
# std            0.152514   0.035785    0.018611   0.001929       1.040535
# min            0.555256  -0.036637   -0.022302   0.052793       0.000000
# ...

# %%
T17Merge = T17Merge.dropna()


### Need to fix by matching names in the 2018PS file to the eliteprospect names with accents

# %%
PS2017F2 = T17Merge.drop(columns = ['height_x','age0new','playername','combine_total','agexNHLe','NHLGeDY0','NHLGeDYn1','NHLGeDelta','NHLeDY0','NHLeDYn1','NHLeDelta'])

# %%
PS2017F2.head()
# Out:
#    team_successDYn1
# 0          0.864152
# 1          1.050876
# 2          0.872598
# 3          0.875647
# 4          0.843313

# %%
Test17F2 = T17Merge.drop(columns = ['playername','NHLGeDY0','agexNHLe','NHLGeDYn1','NHLGeDelta'])

# %%
Test17F2 = Test17F2.reset_index()

# %%
Test17F2 = Test17F2.drop(columns = 'index')

# %%
#PS2017F2 = PS2017F2.reset_index()

# %%
#PS2017F2 = PS2017F2.drop(columns = 'index')

# %%
#Test17F2['age*NHLeDY0'] = Test17F2['NHLeDY0'] * Test17F2['age0new']

# %%
#Test17F2['age*NHLeDYn1'] = Test17F2['NHLeDYn1'] * Test17F2['age0new']

# %%
#Test17F2['years_majoryears'] = Test17F2['years'] * Test17F2['major_years']

# %%
#Test17F2['years_NHLeDY0'] = Test17F2['years'] * Test17F2['NHLeDY0']

# %%
#Test17F2['years_success0'] = Test17F2['years'] * Test17F2['team_successDY0']

# %%
#Test17F2['years_NHLeDYn1'] = Test17F2['NHLeDYn1'] * Test17F2['years']

# %%
#Test17F2['years_success1'] = Test17F2['years'] * Test17F2['team_successDYn1']

# %%
#Test17F2['years_delta'] = Test17F2['years'] * Test17F2['NHLeDelta']

# %%
#Test17F2['years_age'] = Test17F2['years'] * Test17F2['age0new']

# %%
#Test17F2['major_NHLeDY0'] = Test17F2['major_years'] * Test17F2['NHLeDY0']

# %%
#Test17F2['major_success0'] = Test17F2['major_years'] * Test17F2['team_successDY0']

# %%
#Test17F2['major_NHLeDYn1'] = Test17F2['NHLeDYn1'] * Test17F2['major_years']

# %%
#Test17F2['major_success1'] = Test17F2['major_years'] * Test17F2['team_successDYn1']

# %%
#Test17F2['major_delta'] = Test17F2['major_years'] * Test17F2['NHLeDelta']

# %%
#Test17F2['major_age'] = Test17F2['major_years'] * Test17F2['age0new']

# %%
#Test17F2['NHLeDY0_success0'] = Test17F2['NHLeDY0'] * Test17F2['team_successDY0']

# %%
#Test17F2['NHLeDY0*NHLeDYn1'] = Test17F2['NHLeDYn1'] * Test17F2['NHLeDY0']

# %%
#Test17F2['NHLeDY0_success1'] = Test17F2['NHLeDY0'] * Test17F2['team_successDYn1']

# %%
#Test17F2['NHLeDY0_Delta'] = Test17F2['NHLeDY0'] * Test17F2['NHLeDelta']

# %%
#Test17F2['success0_NHLeDYn1'] = Test17F2['NHLeDYn1'] * Test17F2['team_successDY0']

# %%
#Test17F2['success1_success0'] = Test17F2['team_successDY0'] * Test17F2['team_successDYn1']

# %%
#Test17F2['success0_delta'] = Test17F2['team_successDY0'] * Test17F2['NHLeDelta']

# %%
#Test17F2['success_age'] = Test17F2['team_successDY0'] * Test17F2['age0new']

# %%
#Test17F2['success1_NHLeDYn1'] = Test17F2['NHLeDYn1'] * Test17F2['team_successDYn1']

# %%
#Test17F2['Delta_NHLeDYn1'] = Test17F2['NHLeDYn1'] * Test17F2['NHLeDelta']

# %%
#Test17F2['success1_deta'] = Test17F2['team_successDYn1'] * Test17F2['NHLeDelta']

# %%
#Test17F2['success1_age'] = Test17F2['team_successDYn1'] * Test17F2['age0new']

# %%
#Test17F2['age_delta'] = Test17F2['NHLeDelta'] * Test17F2['age0new']

# %%
#Test17F2['age*majoryears*NHLeDY0'] = Test17F2['NHLeDY0'] * Test17F2['age0new'] * Test17F2['major_years']

# %%
#Test17F2['age*years*NHLeDY0'] = Test17F2['NHLeDY0'] * Test17F2['age0new'] * Test17F2['years']

# %%
#Test17F2['age*teamsuccessDY0*NHLeDY0'] = Test17F2['NHLeDY0'] * Test17F2['age0new'] * Test17F2['team_successDY0']

# %%
#Test17F2['delta*age*NHLeDY0'] = Test17F2['NHLeDY0'] * Test17F2['age0new'] * Test17F2['NHLeDelta']

# %%
#Test17F2['age*majoryears*NHLeDYn1'] = Test17F2['NHLeDYn1'] * Test17F2['age0new'] * Test17F2['major_years']

# %%
#Test17F2['age*teamsuccessDYn1*NHLeDYn1'] = Test17F2['NHLeDYn1'] * Test17F2['age0new'] * Test17F2['team_successDYn1']

# %%
#Test17F2['NHLe01'] = Test17F2['NHLeDY0'] * .4 + (Test17F2['NHLeDYn1'] * .6)

# %%
#Test17F2 = Test17F2.drop(columns=['years','major_years','NHLeDY0','team_successDY0','NHLeDYn1','team_successDYn1','NHLeDelta','age0new'])

# %%
#Test17F2 = Test17F2.drop(columns=['grip','agility','upper_body','leg_strength','fitness'])

# %%
import math as m

# %%
# Test17F2['NHLe0sqrt'] = [m.sqrt(i) for i in Test17F2['NHLeDY0']]

# %%
# Test17F2['NHLe1sqrt'] = [m.sqrt(i) for i in Test17F2['NHLeDYn1']]

# %%
Test17F2['NHLecomb3'] = (Test17F2['NHLeDY0'] * 0.8) + (Test17F2['NHLeDYn1'] * 0.2)

# %%
Test17F2['NHLecomb3'].max()
# Out:
# 0.36844308155506367

# %%
Test17F2['NHLecomb3'].min()
# Out:
# 0.04141290638819664

# %%
Test17F2['NHLecomb3'] = (Test17F2['NHLecomb3'] - 0.04141290638819664) / (0.36844308155506367 - 0.04141290638819664)

# %%
sns.distplot(Test17F2['NHLecomb3'])
# Out:
# <AxesSubplot:xlabel='NHLecomb3', ylabel='Density'>

# %%
Test17F2['NHLecomb3'] = [m.sqrt(i) for i in Test17F2['NHLecomb3']]

# %%
Test17F2['age0new'].max()
# Out:
# 0.061312078479460456

# %%
Test17F2['age0new'].min()
# Out:
# 0.052792735719564984

# %%
Test17F2['age0new'] = (Test17F2['age0new'] - 0.052792735719564984) / (0.061312078479460456 - 0.052792735719564984)

# %%
Test17F2['age0new'] = [i**2 for i in Test17F2['age0new']]

# %%
sns.distplot(Test17F2['age0new'])
# Out:
# <AxesSubplot:xlabel='age0new', ylabel='Density'>

# %%
#Test17F2['NHLesqrt'] = [m.sqrt(i) for i in Test17F2['NHLe01']]

# %%
# Test17F2['successDY0log'] = [m.log(i) for i in Test17F2['team_successDY0']]

# %%
Test17F2 = Test17F2.drop(columns=['NHLeDY0','NHLeDYn1','NHLeDelta'])

# %%
# Test17F2 = Test17F2.drop(columns=['NHLe0sqrt','NHLe1sqrt'])

# %%
a = []
for i in Test17F2['combine_total']:
    if i == 1:
        a.append(1)
    elif i == 2:
        a.append(1)
    else:
        a.append(0)
Test17F2['Comb1-2'] = a

# %%
b = []
for i in Test17F2['combine_total']:
    if i == 4:
        b.append(1)
    elif i == 3:
        b.append(1)
    elif i == 5:
        b.append(1)
    elif i == 6:
        b.append(1)
    elif i >= 7:
        b.append(1)
    else:
        b.append(0)
Test17F2['Comb3+'] = b

# %%
# c = []
# for i in Test17F2['combine_total']:
#     if i >= 7:
#         c.append(1)
#     else:
#         c.append(0)
# Test17F2['Comb7+'] = c

# %%
d = []
for i in Test17F2['combine_total']:
    if i == 0:
        d.append(1)
    else:
        d.append(0)
Test17F2['Comb0'] = d

# %%
# e = []
# for i in Test17F2['combine_total']:
#     if i == 1:
#         e.append(1)
#     else:
#         e.append(0)
# Test17F2['Comb1'] = e

# %%
# e = []
# for i in Test17F2['combine_total']:
#     if i == 1.5576923076923077:
#         e.append(1)
#     else:
#         e.append(0)
# Test17F2['CombAvg'] = e

# %%
Test17F2 = Test17F2.drop(columns='combine_total')

# %%
# Test17F2 = Test17F2.drop(columns=['team_successDYn1'])

# %%
Test17F2['height_x'].max()
# Out:
# 200

# %%
Test17F2['height_x'].mean()
# Out:
# 184.16494845360825

# %%
Test17F2['height_x'].min()
# Out:
# 173

# %%
Test17F2['height'] = (Test17F2['height_x'] - 173) / (200 - 173)

# %%
sns.distplot(Test17F2['height'])
# Out:
# <AxesSubplot:xlabel='height', ylabel='Density'>

# %%
a = [] 
for i in Test17F2['height_x']:
    if i < 0.9:
        a.append(1)
    else:
        a.append(0)
Test17F2['low_height'] = a

# %%
Test17F2['team_successDYn1'].max()
# Out:
# 1.400493421

# %%
Test17F2['team_successDYn1'].min()
# Out:
# 0.555256065

# %%
Test17F2['team_successDYn1'] = (Test17F2['team_successDYn1'] - 0.555256065) /  (1.400493421 - 0.555256065)

# %%
Test17F2['team_successDYn1'] = [m.sqrt(i) for i in Test17F2['team_successDYn1']]

# %%
sns.distplot(Test17F2['team_successDYn1'])
# Out:
# <AxesSubplot:xlabel='team_successDYn1', ylabel='Density'>

# %%
Test17F2 = Test17F2.drop(columns=['height_x','low_height','team_successDYn1','height'])

# %%
#Test17F2['combine_total'] = Test17F2['combine_total'] / 8

# %%
### add combine dummy variables here

# %%
Test17F2.head()
# Out:
#     age0new  NHLecomb3  Comb1-2  Comb3+  Comb0
# 0  0.000000   0.577845        0       0      0
# 1  0.000388   0.492081        0       0      0
# 2  0.000388   0.310594        0       0      0
# 3  0.000726   0.516157        0       0      0
# 4  0.003225   0.491472        0       0      0

# %%
PS2017F2
# Out:
#     team_successDYn1
# 0           0.864152
# 1           1.050876
# 2           0.872598
# 3           0.875647
# 4           0.843313
# ..               ...
# 92          0.864626
# 93          1.000000
# 94          0.995882
# 95          0.995882
# 96          1.033004
#
# [97 rows x 1 columns]

# %%
##PS2017D = PS2017.loc[PS2017['position'] =='D']

# %%
#PS2017D = PS2017D.drop(columns = 'position')

# %%
PS2017D.describe()
# Out:
#        PS_new
# count    69.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0

# %% [markdown]
# ## Combining PS Forwards and Defensemen

# %% [markdown]
# ## NEW PS 2005-2016

# %%
PS07 = pd.read_csv("07PS2.csv", encoding='latin1')

# %%
PS08 = pd.read_csv("08PS2.csv", encoding='latin1')

# %%
PS09 = pd.read_csv("09PS2.csv", encoding='latin1')

# %%
PS10 = pd.read_csv("10PS2.csv", encoding='latin1')

# %%
PS11 = pd.read_csv("11PS2.csv", encoding='latin1')

# %%
PS12 = pd.read_csv("12PS2.csv", encoding='latin1')

# %%
PS13 = pd.read_csv("13PS2.csv", encoding='latin1')

# %%
PS14 = pd.read_csv("14PS2.csv", encoding='latin1')

# %%
PS15 = pd.read_csv("15PS2.csv", encoding='latin1')

# %%
PS16 = pd.read_csv("16PS2.csv", encoding='latin1')

# %%
PS17 = pd.read_csv("17PS2.csv", encoding='latin1')

# %%
PS18 = pd.read_csv("18PS2.csv", encoding='latin1')

# %%
PS19 = pd.read_csv("19PS2.csv", encoding='latin1')

# %%
PS20 = pd.read_csv("20PS2.csv", encoding='latin1')

# %%
PS21 = pd.read_csv("21PS2.csv", encoding='latin1')

# %%
PS22 = pd.read_csv("22PS2.csv", encoding='latin1')

# %%
#PSzeros = pd.read_csv("07-15PSzeros.csv", encoding='latin1')

# %%
#import concat

# %%
PScombined = PS16.append([PS19, PS22, PS20, PS21, PS18,PS17,PS15,PS14,PS13,PS12,PS11,PS10,PS09,PS08,PS07], ignore_index = True)

# %%
len(PScombined)
# Out:
# 15844

# %%
PScombined.head()
# Out:
#           playername Pos position    GP    PS     PS/GP
# 0        Brent Burns   D        D  82.0  15.3  0.186585
# 1   Sergei Bobrovsky   G        G  63.0  14.9  0.236508
# 2         Cam Talbot   G        G  73.0  14.0  0.191781
# 3       Devan Dubnyk   G        G  65.0  13.1  0.201538
# 4  Frederik Andersen   G        G  66.0  13.1  0.198485

# %%
PScombined[PScombined['playername']=='Sergei Korostin']
# Out:
# Empty DataFrame
# Columns: [playername, Pos, position, GP, PS, PS/GP]
# Index: []

# %%
PScombined['GP'] = PScombined['GP'].astype(float)

# %%
PScombined['PS'] = PScombined['PS'].astype(float)

# %%
PScombined2 = PScombined.groupby(['playername','position'], as_index=False).agg({'GP':'sum','PS':'sum'})

# %%
PScombined2.head()
# Out:
#           playername position     GP    PS
# 0  ?ubomír Vi?ovský        D  466.0  45.4
# 1         A.J. Greer        F   96.0   1.3
# 2         Aaron Dell        G  110.0  15.8
# 3       Aaron Downey        F   57.0  -0.1
# 4       Aaron Ekblad        D  625.0  59.4

# %%
len(set(PScombined2['playername']))
# Out:
# 3170

# %%
PScombined2['PS_new'] = PScombined2['PS'] / PScombined2['GP']

# %%
PScombined2.head()
# Out:
#           playername position     GP    PS    PS_new
# 0  ?ubomír Vi?ovský        D  466.0  45.4  0.097425
# 1         A.J. Greer        F   96.0   1.3  0.013542
# 2         Aaron Dell        G  110.0  15.8  0.143636
# 3       Aaron Downey        F   57.0  -0.1 -0.001754
# 4       Aaron Ekblad        D  625.0  59.4  0.095040

# %%
# pd.set_option('display.max_rows', None)

# %%
PScombined2.loc[PScombined2.duplicated(subset=['playername']), :]
# Out:
#                playername position     GP    PS    PS_new
# 121      Alexandre Picard        F   17.0  -0.1 -0.005882
# 415           Brent Burns        F  441.0  47.4  0.107483
# 624    Christoph Schubert        F   50.0  -0.4 -0.008000
# 670           Colin White        F  291.0   6.9  0.023711
# 779      Daniil Miromanov        F    1.0   0.0  0.000000
# 781        Daniil Tarasov        G   18.0   2.3  0.127778
# 827            David Ko?í        F   55.0  -0.3 -0.005455
# 940      Dustin Byfuglien        F   77.0   2.9  0.037662
# 1344         Jay Rosehill        F   34.0  -0.2 -0.005882
# 1500           John Scott        F   95.0  -0.5 -0.005263
# 1786       Lane MacDermid        F    1.0   0.0  0.000000
# 1886  Marc-André Gragnani        F   61.0   0.5  0.008197
# 2015         Matt Carkner        F    1.0   0.0  0.000000
# 2050          Matt Pelech        F    1.0   0.0  0.000000
# 2219       Mikko Lehtonen        F    2.0   0.0  0.000000
# ...

# %%
PScombined2 = PScombined2.drop([121]) # Brent Burns as a forward
PScombined2 = PScombined2.drop([415]) # Schubert as a forward
PScombined2 = PScombined2.drop([624]) # David Koci as a forward
# PScombined2 = PScombined2.drop([653]) # Dustin Buf as a forward
PScombined2 = PScombined2.drop([779]) # Jay Rosehill as a forward
PScombined2 = PScombined2.drop([781]) #  scott as a forward
PScombined2 = PScombined2.drop([827]) # conboy as a forward
PScombined2 = PScombined2.drop([940]) # strachan as a forward
PScombined2 = PScombined2.drop([1344]) # wade belak as a forward
PScombined2 = PScombined2.drop([1500]) # wade belak as a forward
PScombined2 = PScombined2.drop([1786]) # wade belak as a forward
PScombined2 = PScombined2.drop([1886]) # wade belak as a forward
PScombined2 = PScombined2.drop([2015]) # wade belak as a forward
PScombined2 = PScombined2.drop([2050]) # wade belak as a forward
PScombined2 = PScombined2.drop([2219]) # wade belak as a forward
# PScombined2 = PScombined2.drop([2663]) # wade belak as a forward
PScombined2 = PScombined2.drop([2751]) # wade belak as a forward
PScombined2 = PScombined2.drop([2919]) # wade belak as a forward
PScombined2 = PScombined2.drop([3053]) # wade belak as a forward
PScombined2 = PScombined2.drop([3112]) # wade belak as a forward

# %%
PScombined2.loc[PScombined2.duplicated(subset=['playername']), :]
# Out:
#          playername position     GP    PS    PS_new
# 670     Colin White        F  291.0   6.9  0.023711
# 2763  Sebastian Aho        F  520.0  56.8  0.109231

# %%
PScombined2[PScombined2['playername']=='Gabriel Gagne']
# Out:
# Empty DataFrame
# Columns: [playername, position, GP, PS, PS_new]
# Index: []

# %%
# PScombined2 = PScombined2.drop(columns=['GP','PS'])

# %%
D07 = pd.read_csv("2007TotalDraft.csv")

# %%
D08 = pd.read_csv("2008TotalDraft.csv")

# %%
D09 = pd.read_csv("2009TotalDraft.csv")

# %%
D10 = pd.read_csv("2010TotalDraft.csv")

# %%
D11 = pd.read_csv("2011TotalDraft.csv")

# %%
D12 = pd.read_csv("2012TotalDraft.csv")

# %%
D13 = pd.read_csv("2013TotalDraft.csv")

# %%
D14 = pd.read_csv("2014TotalDraft.csv")

# %%
D15 = pd.read_csv("2015TotalDraft.csv")

# %%
D16 = pd.read_csv("2016TotalDraft.csv", encoding='latin1')

# %%
D17 = pd.read_csv("2017TotalDraft.csv", encoding='latin1')

# %%
D18 = pd.read_csv("2018TotalDraft.csv", encoding='latin1')

# %%
D19 = pd.read_csv("2019TotalDraft.csv", encoding='latin1')

# %%
abc = D07.append(D08, ignore_index = True)
abcd = abc.append(D09, ignore_index = True)
abcdf = abcd.append(D10, ignore_index = True)
abcdfg = abcdf.append(D11, ignore_index = True)
abcdfgh = abcdfg.append(D12, ignore_index = True)
abcdfghi = abcdfgh.append(D13, ignore_index = True)
abcdfghij = abcdfghi.append(D14, ignore_index = True)
abcdfghijk = abcdfghij.append(D15, ignore_index = True)
abcdfghijkl = abcdfghijk.append(D16, ignore_index = True)
abcdfghijklm = abcdfghijkl.append(D17, ignore_index = True)
abcdfghijklmn = abcdfghijklm.append(D18, ignore_index = True)
abcdfghijklmno = abcdfghijklmn.append(D19, ignore_index = True)

# %%
abcdfghijklmno.head()
# Out:
#        playername Pos position  GP  PS_new
# 0    Patrick Kane  RW        F   1       0
# 1      Jamie Benn  LW        F   1       0
# 2  Max Pacioretty  LW        F   1       0
# 3     P.K. Subban   D        D   1       0
# 4   Logan Couture   C        F   1       0

# %%
### merge on abcdf
total2 = pd.merge(abcdfghijklmno, PScombined2, on ='playername', how='left')

# %%
total2 = total2[total2['PS_new_y'].isnull()]

# %%
total2.fillna(0, inplace=True)

# %%
total2 = total2.drop(columns=['Pos','position_y','GP_y','PS','PS_new_y','GP_x'])

# %%
total2 = total2.rename(columns={'position_x':'position','PS_new_x':'PS_new_y'})

# %%
total2.head()
# Out:
#            playername position  PS_new_y
# 8       Jakub Voracek        F         0
# 59   Chris Didomenico        F         0
# 85       Milan Kytnar        F         0
# 106   Jacob Markstrom        G         0
# 125    Mikkel Boedker        F         0

# %%
D14 = pd.read_csv("2020DraftPS2.csv", encoding='latin1')

# %%
D15 = pd.read_csv("2021DraftPS2.csv", encoding='latin1')

# %%
D16 = pd.read_csv("2022DraftPS2.csv", encoding='latin1')

# %%
#Dmerge1 = D11.append(D12, ignore_index = True)
#Dmerge2 = D12.append(D13, ignore_index = True)
Dmerge3 = D14.append(D15, ignore_index = True)
Dmerge4 = Dmerge3.append(D16, ignore_index = True)

# %%
# Dmerge4 = Dmerge4.drop(columns=['GP','PS','Pos'])

# %%
Dmerge4.head()
# Out:
#           playername Pos position   GP    PS    PS_new
# 0        Tim Stützle  LW        F  210  17.1  0.081429
# 1      Dawson Mercer   C        F  164   9.0  0.054878
# 2  Alexis Lafrenière  LW        F  216   8.6  0.039815
# 3        Seth Jarvis   C        F  150   7.9  0.052667
# 4      Lucas Raymond  LW        F  156   7.6  0.048718

# %%
total3 = pd.merge(Dmerge4, PScombined2, on ='playername', how='left')

# %%
total3.head()
# Out:
#           playername Pos position_x  GP_x  PS_x  PS_new_x position_y   GP_y  \
# 0        Tim Stützle  LW          F   210  17.1  0.081429          F  210.0
# 1      Dawson Mercer   C          F   164   9.0  0.054878          F  164.0
# 2  Alexis Lafrenière  LW          F   216   8.6  0.039815          F  216.0
# 3        Seth Jarvis   C          F   150   7.9  0.052667          F  150.0
# 4      Lucas Raymond  LW          F   156   7.6  0.048718          F  156.0
#
#    PS_y  PS_new_y
# 0  17.0  0.080952
# 1   9.0  0.054878
# 2   8.6  0.039815
# 3   7.9  0.052667
# 4   7.6  0.048718

# %%
total3 = total3.dropna(subset=['PS_new_y'])

# %%
total3 = total3[total3['GP_y']>=40]

# %%
total3 = total3.drop(columns=['Pos', 'GP_x','PS_x','PS_new_x','position_x','GP_y','PS_y'])

# %%
total3 = total3.rename(columns={'position_y':'position'})

# %%
# PSCombFin = total3.append(total2, ignore_index = True)

# %%
total3.head()
# Out:
#           playername position  PS_new_y
# 0        Tim Stützle        F  0.080952
# 1      Dawson Mercer        F  0.054878
# 2  Alexis Lafrenière        F  0.039815
# 3        Seth Jarvis        F  0.052667
# 4      Lucas Raymond        F  0.048718

# %%
PSCombFin = total3

# %%
total4 = pd.merge(abcdfghijklmno, PScombined2, on ='playername', how='left')

# %%
total4 = total4.dropna(subset=['PS_new_y'])

# %%
total4 = total4.drop(columns=['Pos','PS_new_x','GP_x','GP_y','position_y','PS'])

# %%
total4 = total4.rename(columns={'position_x':'position'})

# %%
total4.head()
# Out:
#        playername position  PS_new_y
# 0    Patrick Kane        F  0.117119
# 1      Jamie Benn        F  0.098447
# 2  Max Pacioretty        F  0.097650
# 3     P.K. Subban        D  0.099520
# 4   Logan Couture        F  0.087379

# %%
PSCombFin1 = PSCombFin.append(total4, ignore_index = True)

# %%
PScombined2.head()
# Out:
#           playername position     GP    PS    PS_new
# 0  ?ubomír Vi?ovský        D  466.0  45.4  0.097425
# 1         A.J. Greer        F   96.0   1.3  0.013542
# 2         Aaron Dell        G  110.0  15.8  0.143636
# 3       Aaron Downey        F   57.0  -0.1 -0.001754
# 4       Aaron Ekblad        D  625.0  59.4  0.095040

# %%
### new as of 1/2/24

# PSCombFin1 = PSCombFin.append(PScombined2, ignore_index = True)

# %%
PSCombFin1 = PSCombFin1.rename(columns={'PS_new_y':'PS_new'})

# %%
PSzeros = pd.read_csv("07-18PSzeros.csv", encoding='latin1')

# %%
PSzeros = PSzeros.drop(columns=['Pos','GP','PS'])

# %%
PSzeros = PSzeros.rename(columns={'PS/GP':'PS_new'})

# %%
PSCombFin1.head()
# Out:
#           playername position    PS_new
# 0        Tim Stützle        F  0.080952
# 1      Dawson Mercer        F  0.054878
# 2  Alexis Lafrenière        F  0.039815
# 3        Seth Jarvis        F  0.052667
# 4      Lucas Raymond        F  0.048718

# %%
PSComb2 = PSCombFin1.append(PSzeros, ignore_index = True)

# %%
PSComb2[PSComb2['playername']=='Moritz Seider']
# Out:
#          playername position    PS_new
# 1175  Moritz Seider        D  0.078049

# %%
PSComb2.head(75)
# Out:
#            playername position    PS_new
# 0         Tim Stützle        F  0.080952
# 1       Dawson Mercer        F  0.054878
# 2   Alexis Lafrenière        F  0.039815
# 3         Seth Jarvis        F  0.052667
# 4       Lucas Raymond        F  0.048718
# ..                ...      ...       ...
# 70        Chris Terry        F  0.023438
# 71     Dustin Jeffrey        F  0.023214
# 72       Matt Frattin        F  0.022835
# 73      Nick Palmieri        F  0.032927
# 74        Keith Aulie        D  0.014970
#
# [75 rows x 3 columns]

# %%
PSComb2.describe()
# Out:
#             PS_new
# count  2681.000000
# mean      0.016539
# std       0.033440
# min      -0.029412
# 25%       0.000000
# 50%       0.000000
# 75%       0.021765
# max       0.222059

# %%
PSComb2.describe()
# Out:
#             PS_new
# count  2681.000000
# mean      0.016539
# std       0.033440
# min      -0.029412
# 25%       0.000000
# 50%       0.000000
# 75%       0.021765
# max       0.222059

# %%
PScombinedF = PSComb2.loc[PSComb2['position'] =='F']

# %%
PScombinedF = PScombinedF.drop(columns = ['position'])

# %%
PScombinedD = PSComb2.loc[PSComb2['position'] =='D']

# %%
PScombinedD = PScombinedD.drop(columns = ['position'])

# %%
PScombinedF.head(75)
# Out:
#             playername    PS_new
# 0          Tim Stützle  0.080952
# 1        Dawson Mercer  0.054878
# 2    Alexis Lafrenière  0.039815
# 3          Seth Jarvis  0.052667
# 4        Lucas Raymond  0.048718
# ..                 ...       ...
# 108     Maksim Mayorov  0.000000
# 109        John Albert  0.000000
# 110     Colton Gillies -0.000676
# 111        Bill Sweatt  0.000000
# 113   Maxime Macenauer -0.003448
#
# [75 rows x 2 columns]

# %%
PScombinedF[PScombinedF['playername']=='Mitch Marner']
# Out:
# Empty DataFrame
# Columns: [playername, PS_new]
# Index: []

# %% [markdown]
# ## SPLIT BY POSITION

# %%
Forwards3 = PScombinedF

# %%
Defense3 = PScombinedD

# %%
#Forwards1 = PS2014F.append(PS2015F, ignore_index = True)

# %%
#Forwards2 = Forwards1.append(PS2016F, ignore_index = True)

# %%
#Forwards3 = Forwards2.append(PS2017F, ignore_index = True)

# %%
Forwards3.describe() # had 355 forwards collected
# Out:
#             PS_new
# count  1502.000000
# mean      0.013046
# std       0.025336
# min      -0.029412
# 25%       0.000000
# 50%       0.000000
# 75%       0.018247
# max       0.177153

# %%
#Defense1 = PS2014D.append(PS2015D, ignore_index = True)

# %%
#Defense2 = Defense1.append(PS2016D, ignore_index = True)

# %%
#Defense3 = Defense2.append(PS2017D, ignore_index = True)

# %%
Defense3.describe()  # Had 194 Defensemen collected
# Out:
#            PS_new
# count  898.000000
# mean     0.017172
# std      0.028488
# min     -0.012000
# 25%      0.000000
# 50%      0.000000
# 75%      0.032800
# max      0.171429

# %% [markdown]
# ## Combining PSF with FinalF and PSD with FinalD
# - Adding in the point shares to the model training set to use that as the projected score that the model is predicting

# %%
ForwardsFin1 = pd.merge(Forwards3, Final3F, on ='playername', how='right')
##### Have to Merge on left or right here

# %%
ForwardsFin1
# Out:
#           playername    PS_new  height_x  weight_x   NHLeDY0  NHLGeDY0  \
# 0      Lucas Edmonds       NaN       181       192  0.253563  0.076293
# 1     Daylan Kuefler       NaN       188       190  0.112253  0.072298
# 2     Aidan Thompson       NaN       180       170  0.164331  0.048097
# 3       Zakary Karpa       NaN       188       185  0.070372  0.035186
# 4       Patrick Guay       NaN       175       179  0.193761  0.102470
# ...              ...       ...       ...       ...       ...       ...
# 1644     Corey Tropp  0.005369       183       192  0.118238  0.049584
# 1645      Sam Gagner  0.044039       180       196  0.209813  0.062233
# 1646     Kyle Turris  0.054393       185       190  0.114478  0.063449
# 1647   Jakub Voracek       NaN       189       209  0.154668  0.043216
# 1648  Aaron Palushaj  0.015385       183       192  0.123210  0.040457
#
#       NHLeDYn1  NHLGeDYn1  team_successDYn1  age_DY0  age_DYn1  NHLeDelta  \
# ...

# %%
ForwardsFin1[ForwardsFin1['playername']=='David Pastrnak']
# Out:
#          playername  PS_new  height_x  weight_x   NHLeDY0  NHLGeDY0  NHLeDYn1  \
# 912  David Pastrnak     NaN       182       194  0.135514  0.039282  0.081506
#
#      NHLGeDYn1  team_successDYn1  age_DY0  age_DYn1  NHLeDelta  NHLGeDelta  \
# 912   0.037449          0.859428   16.616    15.614   0.054008    0.001833
#
#      combine_total
# 912            1.0

# %%
ForwardsFin1[ForwardsFin1['PS_new'].isna()]
# Out:
#           playername  PS_new  height_x  weight_x   NHLeDY0  NHLGeDY0  \
# 0      Lucas Edmonds     NaN       181       192  0.253563  0.076293
# 1     Daylan Kuefler     NaN       188       190  0.112253  0.072298
# 2     Aidan Thompson     NaN       180       170  0.164331  0.048097
# 3       Zakary Karpa     NaN       188       185  0.070372  0.035186
# 4       Patrick Guay     NaN       175       179  0.193761  0.102470
# ...              ...     ...       ...       ...       ...       ...
# 1574  Maxim Grachyov     NaN       180       203  0.127891  0.058132
# 1590    Dávid Skokan     NaN       182       183  0.079207  0.025433
# 1591   Brett MacLean     NaN       188       196  0.169963  0.079883
# 1597    Oscar Möller     NaN       179       190  0.161401  0.070896
# 1647   Jakub Voracek     NaN       189       209  0.154668  0.043216
#
#       NHLeDYn1  NHLGeDYn1  team_successDYn1  age_DY0  age_DYn1  NHLeDelta  \
# ...

# %%
ForwardsFin1.to_csv("23ForwardsComb.csv")

# %% [markdown]
# ### PLayers who need their name fixed in the excel sheets
#
# - pastrnak
# - ondrej palat
# - mitch to mitchell marner
# - jakub voracek

# %%
### Fixed

# %%
# zeros16 = ['Timothy Gettinger','Riley Tufte','Joseph Woll','Fredrik Karlstrom','Joachim Blichfeld','Kasper Bjorkqvist','Vitaly Abramov','Joona Koppanen','Linus Hogberg','German Rubtsov','William Bitten','Frederic Allard',
# 'Tarmo Reunanen','Blake Hillman','Chase Priskie','Lucas Johansen','Garrett Pilon','Keaton Middleton','Matthew Phillips',
# 'Calvin Thurkauf','Jack LaFontaine','Sean Day','Adam Werner','Yegor Korshkov','Brandon Gignac','Dylan Wells','Pascal Laberge',
# 'Adam Mascherin','Cameron Morrison','Chad Krys','Artur Kayumov','Tyler Parsons','Evan Fitzpatrick','Matt Filipe','Cliff Pu',
# 'Josh Anderson','James Greenway','Hudson Elynuik','Connor Hall','Luke Green','Wouter Peeters','Matthew Cairns','Linus Nassen',
# 'Filip Berglund','Jack Kopacka','Jonathan Ang','Anatoli Golyshev','Linus Lindstrom','Jacob Cederholm','Todd Burgess','Max Zimmer',
# 'Evan Cormier','Alfons Malmstrom','Hardy Haman Aktell','Nathan Noel','Alex Dostie','Damien Riat','Tanner Kaspick','Ryan Jones',
# 'Vladimir Bobylev','Casey Staum','Nolan Stevens','Mitchell Mattson','Jordan Stallard','Colton Point','Philip Nyberg','Vojtech Budik',
# 'Yegor Rykov','Jeremy Helvig','Cameron Clarke','Jordan Sambrook','Patrick Harper','Cole Candella','Mathias From','Conner Bleackley',
# 'Christopher Paquette','Graham McPhee','Manuel Wiederer','Niclas Almari','Jonathan Walker','Aapeli Rasanen','Jakob Stukel',
# 'Peter Thome','Eetu Tuulola','Mikhail Berdin','Patrick Kudla','Nathan Clurman','Markus Nurmi','Noah Carroll','Filip Larsson','Konstantin Volkov',
# 'Collin Adams','Gabriel Fontaine','Anthony Salinitri','Tyler Wall','Jakob Stenqvist','Oleg Sosunov','Nicolas Mattinen','Mark Shoemaker',
# 'Joseph Masonius','Nikolai Chebykin','Rodrigo Abols','Stepan Falkovsky','Arvid Henrikson','Dean Stewart','Austin Osmanski',
# 'Vasily Glotov','Travis Barron','Nick Pastujov','Brett McKenzie','Benjamin Finkelstein','Dmitry Sokolov','Mattias Elfstrom','Adam Smith',
# 'David Bernhardt','David Quenneville','Ty Ronning','Jacob Friend','Jake Ryczek','Brayden Chizen','Tyler Soy','Otto Somppi',
# 'Dmitriy Zaitsev','Ryan Lohin','Nikolaj Krag Christensen','Filip Helt'
# ]

# %%
# for i in ForwardsFin1['playername']:
#     if i in zeros16:
#         ForwardsFin2 = ForwardsFin1.drop(ForwardsFin1[ForwardsFin1['playername']== i].index, inplace=True)

# %%
#### dropped all NAs, this might have dropped some players whose names were spelt differently 
#### in the excels from hockeyref and from eliteprospects like Jakub Voracek


ForwardsFin1 = ForwardsFin1.dropna()

# %%
ForwardsFin1[ForwardsFin1['PS_new'].isna()]
# Out:
# Empty DataFrame
# Columns: [playername, PS_new, height_x, weight_x, NHLeDY0, NHLGeDY0, NHLeDYn1, NHLGeDYn1, team_successDYn1, age_DY0, age_DYn1, NHLeDelta, NHLGeDelta, combine_total]
# Index: []

# %%
#ForwardsFin1['age_med'] = ForwardsFin1.age_DY0 > ForwardsFin1.age_DY0.median()
#ForwardsFin1['age_med'] = np.where(ForwardsFin1.age_med == False, "Below Median", "Above Median")
#sns.lmplot(x='NHLeDY0', y='PS_new', hue='age_med', data=ForwardsFin1, ci=None, size=5, aspect=2.5);

# %%
#ForwardsFin1['delta_med'] = ForwardsFin1.NHLeDelta > ForwardsFin1.NHLeDelta.median()
#ForwardsFin1['delta_med'] = np.where(ForwardsFin1.delta_med == False, "Below Median", "Above Median")
#sns.lmplot(x='NHLeDY0', y='PS_new', hue='delta_med', data=ForwardsFin1, ci=None, size=5, aspect=2.5);

# %%
#ForwardsFin1['g_med'] = ForwardsFin1.NHLGeDY0 > ForwardsFin1.NHLGeDY0.median()
#ForwardsFin1['g_med'] = np.where(ForwardsFin1.g_med == False, "Below Median", "Above Median")
#sns.lmplot(x='NHLeDY0', y='PS_new', hue='g_med', data=ForwardsFin1, ci=None, size=5, aspect=2.5);

# %%
#ForwardsFin1['y_med'] = ForwardsFin1.years > ForwardsFin1.years.median()
#ForwardsFin1['y_med'] = np.where(ForwardsFin1.y_med == False, "Below Median", "Above Median")
#sns.lmplot(x='NHLeDY0', y='PS_new', hue='y_med', data=ForwardsFin1, ci=None, size=5, aspect=2.5);

# %%
ForwardsFin1[ForwardsFin1['playername'] == "Kirill Kaprizov"]
# Out:
#           playername    PS_new  height_x  weight_x   NHLeDY0  NHLGeDY0  \
# 814  Kirill Kaprizov  0.141379       178       203  0.251205  0.071939
#
#      NHLeDYn1  NHLGeDYn1  team_successDYn1  age_DY0  age_DYn1  NHLeDelta  \
# 814  0.165846   0.053899          1.015545   16.696    15.696   0.085359
#
#      NHLGeDelta  combine_total
# 814     0.01804       1.312042

# %%
Final3F[Final3F['playername']=="Tomas Hertl"]
# Out:
#       height_x  weight_x   playername   NHLeDY0  NHLGeDY0  NHLeDYn1  \
# 1629       190       214  Tomas Hertl  0.560401  0.274993  0.018462
#
#       NHLGeDYn1  team_successDYn1  age_DY0  age_DYn1  NHLeDelta  NHLGeDelta  \
# 1629   0.018462          1.694349   17.148    16.148    0.54194    0.256531
#
#       combine_total
# 1629            1.5

# %%
ForwardsFin1 = ForwardsFin1.drop_duplicates()

# %%
ForwardsFin1.describe()
# Out:
#             PS_new     height_x     weight_x      NHLeDY0     NHLGeDY0  \
# count  1019.000000  1019.000000  1019.000000  1019.000000  1019.000000
# mean      0.016118   185.035329   195.614328     0.122457     0.053066
# std       0.027866     5.432632    15.104724     0.058666     0.028034
# min      -0.029412   168.000000   150.000000     0.000000     0.000000
# 25%       0.000000   181.000000   185.000000     0.084433     0.035005
# 50%       0.000000   185.000000   194.000000     0.113850     0.049016
# 75%       0.023845   188.000000   205.000000     0.151296     0.066291
# max       0.177153   205.000000   243.000000     0.557058     0.285112
#
#           NHLeDYn1    NHLGeDYn1  team_successDYn1      age_DY0     age_DYn1  \
# count  1019.000000  1019.000000       1019.000000  1019.000000  1019.000000
# mean      0.070891     0.030919          0.999551    17.138758    16.138121
# std       0.047734     0.024171          0.214823     0.685709     0.685755
# ...

# %%
ForwardsFin1.head(30)
# Out:
#              playername    PS_new  height_x  weight_x   NHLeDY0  NHLGeDY0  \
# 32          Jack Hughes  0.081148       180       170  0.079394  0.034735
# 118        Kent Johnson  0.038750       185       168  0.201403  0.067134
# 170      Wyatt Johnston  0.053659       185       185  0.068571  0.034286
# 174      Cole Sillinger  0.007692       188       203  0.174907  0.091256
# 205     Yegor Chinakhov  0.005435       185       190  0.182690  0.074512
# 213          Jack Quinn  0.035526       183       176  0.214400  0.125268
# 216      Dylan Holloway  0.003922       185       203  0.091311  0.042970
# 221       Anton Lundell  0.051449       185       185  0.196316  0.070113
# 226       Dawson Mercer  0.054878       183       181  0.126681  0.050673
# 240       Cole Perfetti  0.047826       180       176  0.271782  0.090594
# 261         Seth Jarvis  0.052667       178       174  0.206101  0.088329
# 277       Lucas Raymond  0.048718       179       183  0.179743  0.068138
# ...

# %%
ForwardsFin1.corr()
# Out:
#                     PS_new  height_x  weight_x   NHLeDY0  NHLGeDY0  NHLeDYn1  \
# PS_new            1.000000 -0.028596  0.032260  0.446465  0.368042  0.346713
# height_x         -0.028596  1.000000  0.679890 -0.223148 -0.167363 -0.222978
# weight_x          0.032260  0.679890  1.000000 -0.142282 -0.057584 -0.135211
# NHLeDY0           0.446465 -0.223148 -0.142282  1.000000  0.876830  0.599901
# NHLGeDY0          0.368042 -0.167363 -0.057584  0.876830  1.000000  0.499296
# NHLeDYn1          0.346713 -0.222978 -0.135211  0.599901  0.499296  1.000000
# NHLGeDYn1         0.288231 -0.162987 -0.077895  0.512343  0.481177  0.894489
# team_successDYn1 -0.110034  0.072320  0.000369 -0.112961 -0.094842 -0.145849
# age_DY0          -0.149679 -0.059269  0.003328  0.236707  0.260081  0.191946
# age_DYn1         -0.149637 -0.059281  0.003348  0.236674  0.260053  0.191962
# NHLeDelta         0.198467 -0.050378 -0.038962  0.618114  0.568228 -0.258123
# ...

# %%
DefenseFin1 = pd.merge(Defense3, Final3D, on ='playername', how='right')

# %%
DefenseFin1.head()
# Out:
#            playername  PS_new  height_x  weight_x   NHLeDY0  NHLGeDY0  \
# 0       Petteri Nurmi     NaN       183       187  0.044052  0.009049
# 1    MiguÃ«l Tourigny     NaN       173       170  0.243123  0.094210
# 2     Hunter McDonald     NaN       193       205  0.037905  0.010830
# 3      Victor Mancini     NaN       191       216  0.030627  0.000000
# 4  Maksymilian Szuber     NaN       191       201  0.099917  0.012369
#
#    NHLeDYn1  NHLGeDYn1  team_successDYn1  age_DY0  age_DYn1  NHLeDelta  \
# 0  0.078291   0.017398          1.012425   18.984    17.981  -0.034239
# 1  0.228155   0.095065          0.829174   18.907    17.904   0.014968
# 2  0.022932   0.009173          1.099758   18.658    17.655   0.014972
# 3  0.075214   0.029669          0.863701   18.616    17.614  -0.044587
# 4  0.000000   0.000000          0.900748   18.367    17.364   0.099917
#
#    NHLGeDelta  combine_total
# 0   -0.008349       1.312042
# 1   -0.000854       1.312042
# ...

# %%
DefenseFin1 = DefenseFin1.dropna()

# %%
DefenseFin1[DefenseFin1['PS_new'].isna()]
# Out:
# Empty DataFrame
# Columns: [playername, PS_new, height_x, weight_x, NHLeDY0, NHLGeDY0, NHLeDYn1, NHLGeDYn1, team_successDYn1, age_DY0, age_DYn1, NHLeDelta, NHLGeDelta, combine_total]
# Index: []

# %%
DefenseFin1 = DefenseFin1.drop_duplicates()

# %%
DefenseFin1.describe()
# Out:
#            PS_new    height_x    weight_x     NHLeDY0    NHLGeDY0    NHLeDYn1  \
# count  590.000000  590.000000  590.000000  590.000000  590.000000  590.000000
# mean     0.020790  187.742373  201.245763    0.096713    0.023912    0.058025
# std      0.030673    5.396478   15.423361    0.055146    0.018982    0.045919
# min     -0.012000  173.000000  161.000000    0.000000    0.000000    0.000000
# 25%      0.000000  184.000000  190.000000    0.055663    0.010845    0.025587
# 50%      0.000000  188.000000  201.000000    0.088771    0.019980    0.046522
# 75%      0.040591  191.000000  209.000000    0.124733    0.032020    0.079733
# max      0.171429  205.000000  258.000000    0.357232    0.131745    0.297286
#
#         NHLGeDYn1  team_successDYn1     age_DY0    age_DYn1   NHLeDelta  \
# count  590.000000        590.000000  590.000000  590.000000  590.000000
# mean     0.014246          1.002529   17.112095   16.111459    0.038688
# ...

# %% [markdown]
# ### Continue w forwards

# %%
F1Train = ForwardsFin1.drop(columns = ['playername','PS_new'])

# %%
F1Train.head()
# Out:
#      height_x  weight_x   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 32        180       170  0.079394  0.034735  0.090510   0.021681
# 118       185       168  0.201403  0.067134  0.127985   0.051954
# 170       185       185  0.068571  0.034286  0.084542   0.033817
# 174       188       203  0.174907  0.091256  0.134684   0.055907
# 205       185       190  0.182690  0.074512  0.061189   0.032947
#
#      team_successDYn1  age_DY0  age_DYn1  NHLeDelta  NHLGeDelta  combine_total
# 32           0.944399   17.178    16.175  -0.011116    0.013054       8.000000
# 118          0.829359   17.216    16.216   0.073418    0.015180       1.312042
# 170          0.935372   16.647    15.647  -0.015971    0.000469       1.312042
# 174          0.777437   16.641    15.641   0.040222    0.035349       1.312042
# 205          0.992469   17.926    16.926   0.121501    0.041564       1.312042

# %% [markdown]
# ## Trying different calculations of columns that were not used in the final model for now

# %%
aa = []
for i in F1Train['NHLeDelta']:
    if i >= 0:
        aa.append(1)
    else:
        aa.append(0)
F1Train['DeltaPos'] = aa

# %%
bb = []
for i in F1Train['NHLeDelta']:
    if i < 0:
        bb.append(1)
    else:
        bb.append(0)
F1Train['DeltaNeg'] = bb

# %%
F1Train.head()
# Out:
#      height_x  weight_x   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 32        180       170  0.079394  0.034735  0.090510   0.021681
# 118       185       168  0.201403  0.067134  0.127985   0.051954
# 170       185       185  0.068571  0.034286  0.084542   0.033817
# 174       188       203  0.174907  0.091256  0.134684   0.055907
# 205       185       190  0.182690  0.074512  0.061189   0.032947
#
#      team_successDYn1  age_DY0  age_DYn1  NHLeDelta  NHLGeDelta  \
# 32           0.944399   17.178    16.175  -0.011116    0.013054
# 118          0.829359   17.216    16.216   0.073418    0.015180
# 170          0.935372   16.647    15.647  -0.015971    0.000469
# 174          0.777437   16.641    15.641   0.040222    0.035349
# 205          0.992469   17.926    16.926   0.121501    0.041564
#
#      combine_total  DeltaPos  DeltaNeg
# 32        8.000000         0         1
# 118       1.312042         1         0
# 170       1.312042         0         1
# ...

# %%
F1Train.loc[F1Train['age_DY0'] >= 18.9]
# Out:
#       height_x  weight_x   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 421        193       220  0.126107  0.070935  0.033844   0.011945
# 422        193       223  0.081561  0.040780  0.043600   0.016350
# 423        183       194  0.156580  0.051059  0.043923   0.021961
# 520        177       181  0.244423  0.131613  0.062744   0.030311
# 521        182       203  0.265781  0.070757  0.229140   0.160078
# 522        191       212  0.290034  0.093393  0.210274   0.114285
# 620        189       209  0.092021  0.048561  0.238000   0.104475
# 621        172       187  0.389878  0.221522  0.283577   0.134326
# 622        193       205  0.102060  0.041657  0.200278   0.087190
# 623        183       192  0.108005  0.030523  0.129666   0.071449
# 726        180       190  0.464528  0.278717  0.222511   0.135305
# 840        178       185  0.343404  0.137362  0.158504   0.105957
# 841        185       216  0.070828  0.030795  0.045331   0.024554
# ...

# %%
AgeDY0 = 1 / (F1Train['age_DY0']) # -0.043 was the best

# %%
F1Train['age0new'] = AgeDY0

# %%
cc = []
for i in F1Train['age0new']:
    if i >= .058:  # < age 17.2
        cc.append(1)
    else:
        cc.append(0)
F1Train['lowage'] = cc

# %%
dd = []
for i in F1Train['age0new']:
    if i < .058 and i >= .0555:  # btwn 17.2 and 18
        dd.append(1)
    else:
        dd.append(0)
F1Train['medlowage'] = dd

# %%
ee = []
for i in F1Train['age0new']:
    if i < .0555 and i >= .054:  # btwn 18 and 18.5
        ee.append(1)
    else:
        ee.append(0)
F1Train['medage'] = ee

# %%
ff = []
for i in F1Train['age0new']:
    if i < .054 and i >= .0526:  # btwn 18.5 and 19
        ff.append(1)
    else:
        ff.append(0)
F1Train['highage'] = ff

# %%
agecomb = F1Train['lowage'] + F1Train['medlowage'] + F1Train['medage'] + F1Train['highage']

# %%
F1Train['agecom'] = agecomb

# %%
combine = F1Train['agecom'] * F1Train['NHLeDY0']

# %%
F1Train['combo2'] = combine

# %% [markdown]
# #### Continue with age binning

# %%
combined = F1Train['NHLeDY0'] * F1Train['age0new']

# %%
F1Train['combo'] = combined

# %%
F1Train['agexNHLe'] = F1Train['age0new'] * F1Train['NHLeDY0']

# %%
# ff = []
# for i in F1Train['years']:
#     if i < 0.25 and i >= 0:  
#         ff.append(1)
#     else:
#         ff.append(0)
# F1Train['ManyYears'] = ff

# %%
#ff = []
#for i in F1Train['years']:
#    if i == 0.250000:  
#        ff.append(1)
#    else:
#        ff.append(0)
#F1Train['medYears'] = ff

# %%
#ff = []
#for i in F1Train['years']:
#    if i == 0.333333:  
#        ff.append(1)
#    else:
#        ff.append(0)
#F1Train['FewishYears'] = ff

# %%
# ff = []
# for i in F1Train['years']:
#     if i > 0.500000:  
#         ff.append(1)
#     else:
#         ff.append(0)
# F1Train['FewYears'] = ff

# %%
ff = []
for i in F1Train['NHLeDelta']:
    if i <= 0:  
        ff.append(1)
    else:
        ff.append(0)
F1Train['NoImprove'] = ff

# %% [markdown]
# #### Height

# %%
import math as m

# %%
F1Train2 = F1Train.drop(columns = ['NoImprove','NHLGeDY0','agexNHLe','weight_x','NHLGeDYn1','NHLGeDelta','agecom','combo2','lowage','medlowage','medage','highage','age_DY0','age_DYn1','DeltaPos','combo','DeltaNeg'])

# %%
F1Train2['height_x'].max()
# Out:
# 205

# %%
F1Train2['height_x'].mean()
# Out:
# 185.0353287536801

# %%
F1Train2['height_x'].min()
# Out:
# 168

# %%
# F1Train2['height'] = F1Train2['height_x'] / 205

# %%
F1Train2['height'] = (F1Train2['height_x'] - 168) / (205-168)

# %%
a = [] 
for i in F1Train2['height_x']:
    if i < 0.9:
        a.append(1)
    else:
        a.append(0)
F1Train2['low_height'] = a

# %%
F1Train2 = F1Train2.drop(columns=['height_x','low_height'])

# %%
#F1Train2['years'].value_counts()

# %%
F1Train = F1Train.drop(columns = ['height_x','NoImprove','NHLGeDY0','agexNHLe','weight_x','NHLGeDYn1','NHLGeDelta','agecom','combo2','lowage','medlowage','medage','highage','age_DY0','age_DYn1','DeltaPos','combo','DeltaNeg'])

# %%
#F1Train2['age*NHLeDY0'] = F1Train2['NHLeDY0'] * F1Train2['age0new']

# %%
#F1Train2['age*NHLeDYn1'] = F1Train2['NHLeDYn1'] * F1Train2['age0new']

# %%
#F1Train2['years_majoryears'] = F1Train2['years'] * F1Train2['major_years']

# %%
#F1Train2['years_NHLeDY0'] = F1Train2['years'] * F1Train2['NHLeDY0']

# %%
#F1Train2['years_success0'] = F1Train2['years'] * F1Train2['team_successDY0']

# %%
#F1Train2['years_NHLeDYn1'] = F1Train2['NHLeDYn1'] * F1Train2['years']

# %%
#F1Train2['years_success1'] = F1Train2['years'] * F1Train2['team_successDYn1']

# %%
#F1Train2['years_delta'] = F1Train2['years'] * F1Train2['NHLeDelta']

# %%
#F1Train2['years_age'] = F1Train2['years'] * F1Train2['age0new']

# %%
#F1Train2['major_NHLeDY0'] = F1Train2['major_years'] * F1Train2['NHLeDY0']

# %%
#F1Train2['major_success0'] = F1Train2['major_years'] * F1Train2['team_successDY0']

# %%
#F1Train2['major_NHLeDYn1'] = F1Train2['NHLeDYn1'] * F1Train2['major_years']

# %%
#F1Train2['major_success1'] = F1Train2['major_years'] * F1Train2['team_successDYn1']

# %%
#F1Train2['major_delta'] = F1Train2['major_years'] * F1Train2['NHLeDelta']

# %%
#F1Train2['major_age'] = F1Train2['major_years'] * F1Train2['age0new']

# %%
#F1Train2['NHLeDY0_success0'] = F1Train2['NHLeDY0'] * F1Train2['team_successDY0']

# %%
#F1Train2['NHLeDY0*NHLeDYn1'] = F1Train2['NHLeDYn1'] * F1Train2['NHLeDY0']

# %%
#F1Train2['NHLeDY0_success1'] = F1Train2['NHLeDY0'] * F1Train2['team_successDYn1']

# %%
#F1Train2['NHLeDY0_Delta'] = F1Train2['NHLeDY0'] * F1Train2['NHLeDelta']

# %%
#F1Train2['success0_NHLeDYn1'] = F1Train2['NHLeDYn1'] * F1Train2['team_successDY0']

# %%
#F1Train2['success1_success0'] = F1Train2['team_successDY0'] * F1Train2['team_successDYn1']

# %%
#F1Train2['success0_delta'] = F1Train2['team_successDY0'] * F1Train2['NHLeDelta']

# %%
#F1Train2['success_age'] = F1Train2['team_successDY0'] * F1Train2['age0new']

# %%
#F1Train2['success1_NHLeDYn1'] = F1Train2['NHLeDYn1'] * F1Train2['team_successDYn1']

# %%
#F1Train2['Delta_NHLeDYn1'] = F1Train2['NHLeDYn1'] * F1Train2['NHLeDelta']

# %%
#F1Train2['success1_deta'] = F1Train2['team_successDYn1'] * F1Train2['NHLeDelta']

# %%
#F1Train2['success1_age'] = F1Train2['team_successDYn1'] * F1Train2['age0new']

# %%
#F1Train2['age_delta'] = F1Train2['NHLeDelta'] * F1Train2['age0new']

# %%
#F1Train2['age*majoryears*NHLeDY0'] = F1Train2['NHLeDY0'] * F1Train2['age0new'] * F1Train2['major_years']

# %%
#F1Train2['age*years*NHLeDY0'] = F1Train2['NHLeDY0'] * F1Train2['age0new'] * F1Train2['years']

# %%
#F1Train2['age*teamsuccessDY0*NHLeDY0'] = F1Train2['NHLeDY0'] * F1Train2['age0new'] * F1Train2['team_successDY0']

# %%
#F1Train2['delta*age*NHLeDY0'] = F1Train2['NHLeDY0'] * F1Train2['age0new'] * F1Train2['NHLeDelta']

# %%
#F1Train2['age*majoryears*NHLeDYn1'] = F1Train2['NHLeDYn1'] * F1Train2['age0new'] * F1Train2['major_years']

# %%
#F1Train2['age*teamsuccessDYn1*NHLeDYn1'] = F1Train2['NHLeDYn1'] * F1Train2['age0new'] * F1Train2['team_successDYn1']

# %%
#F1Train2['NHLe01'] = F1Train2['NHLeDY0'] * .4 + (F1Train2['NHLeDYn1'] * .6)

# %%
#F1Train2 = F1Train2.drop(columns=['years','major_years','NHLeDY0','team_successDY0','NHLeDYn1','team_successDYn1','NHLeDelta','age0new'])

# %%
#F1Train2 = F1Train2.drop(columns='combine_total')

# %%
F1Train2 = F1Train2.reset_index()

# %%
F1Train2 = F1Train2.drop(columns='index')

# %%
import math as m

# %%
# F1Train2['NHLe0sqrt'] = [m.sqrt(i) for i in F1Train2['NHLeDY0']]

# %%
# F1Train2['NHLe1sqrt'] = [m.sqrt(i) for i in F1Train2['NHLeDYn1']]

# %%
F1Train2['NHLecomb3'] = (F1Train2['NHLeDY0'] * 0.8) + (F1Train2['NHLeDY0'] * 0.2)

# %%
F1Train2['NHLecomb3'].max()
# Out:
# 0.5570582428799999

# %%
F1Train2['NHLecomb3'].min()
# Out:
# 0.0

# %%
F1Train2['NHLecomb3'] = (F1Train2['NHLecomb3'] - 0.0) / (0.5570582428799999 - 0)

# %%
F1Train2['NHLecomb3'] = [m.sqrt(i) for i in F1Train2['NHLecomb3']]

# %%
sns.distplot(F1Train2['NHLecomb3'])
# Out:
# <AxesSubplot:xlabel='NHLecomb3', ylabel='Density'>

# %%
sns.distplot(F1Train2['height'])
# Out:
# <AxesSubplot:xlabel='height', ylabel='Density'>

# %%
F1Train2['age0new'].max()
# Out:
# 0.06132335806708776

# %%
F1Train2['age0new'].min()
# Out:
# 0.05004754516790951

# %%
F1Train2['age0new'] = (F1Train2['age0new'] - 0.05004754516790951) /  (0.06132335806708776 - 0.05004754516790951)

# %%
F1Train2['age0new'] = [i**2 for i in F1Train2['age0new']]

# %%
sns.distplot(F1Train2['age0new'])
# Out:
# <AxesSubplot:xlabel='age0new', ylabel='Density'>

# %%
F1Train2['team_successDYn1'].max()
# Out:
# 4.5

# %%
F1Train2['team_successDYn1'].min()
# Out:
# 0.473333333

# %%
F1Train2['team_successDYn1'] = (F1Train2['team_successDYn1'] - 0.473333333) /  (4.5 - 0.473333333)

# %%
F1Train2['team_successDYn1'] = [m.sqrt(i) for i in F1Train2['team_successDYn1']]

# %%
sns.distplot(F1Train2['team_successDYn1'])
# Out:
# <AxesSubplot:xlabel='team_successDYn1', ylabel='Density'>

# %%
#F1Train2['NHLesqrt'] = [m.sqrt(i) for i in F1Train2['NHLe01']]

# %%
# F1Train2['successDY0log'] = [m.log(i) for i in F1Train2['team_successDY0']]

# %%
# F1Train2 = F1Train2.drop(columns=['NHLe0sqrt','NHLe1sqrt'])

# %%
F1Train2 = F1Train2.drop(columns=['NHLeDY0','NHLeDYn1','NHLeDelta'])

# %%
a = []
for i in F1Train2['combine_total']:
    if i == 1:
        a.append(1)
    elif i == 2:
        a.append(1)
    else:
        a.append(0)
F1Train2['Comb1-2'] = a

# %%
b = []
for i in F1Train2['combine_total']:
    if i == 4:
        b.append(1)
    elif i == 3:
        b.append(1)
    elif i == 5:
        b.append(1)
    elif i == 6:
        b.append(1)
    elif i >= 7:
        b.append(1)
    else:
        b.append(0)
F1Train2['Comb3+'] = b

# %%
# c = []
# for i in F1Train2['combine_total']:
#     if i >= 7:
#         c.append(1)
#     else:
#         c.append(0)
# F1Train2['Comb7+'] = c

# %%
d = []
for i in F1Train2['combine_total']:
    if i == 0:
        d.append(1)
    else:
        d.append(0)
F1Train2['Comb0'] = d

# %%
# e = []
# for i in F1Train2['combine_total']:
#     if i == 1:
#         e.append(1)
#     else:
#         e.append(0)
# F1Train2['Comb1'] = e

# %%
# e = []
# for i in F1Train2['combine_total']:
#     if i > 1 and i < 2:
#         e.append(1)
#     elif i > 2 and i < 3:
#         e.append(1)
#     else:
#         e.append(0)
# F1Train2['CombAvg'] = e

# %%
F1Train2 = F1Train2.drop(columns='combine_total')

# %%
F1Train2 = F1Train2.drop(columns=['team_successDYn1','height'])

# %%
#F1Train2['combine_total'] = F1Train2['combine_total'] / 8

# %%
### Add the combine dummy variables here

# %%
F1Train2.describe()
# Out:
#            age0new    NHLecomb3      Comb1-2       Comb3+        Comb0
# count  1019.000000  1019.000000  1019.000000  1019.000000  1019.000000
# mean      0.591858     0.455834     0.126595     0.067713     0.108930
# std       0.245210     0.109796     0.332682     0.251377     0.311705
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.487732     0.389318     0.000000     0.000000     0.000000
# 50%       0.644259     0.452081     0.000000     0.000000     0.000000
# 75%       0.760967     0.521150     0.000000     0.000000     0.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000

# %%
# F1Train2 = F1Train2.drop_duplicates()

# %%
F1Train2.describe()
# Out:
#            age0new    NHLecomb3      Comb1-2       Comb3+        Comb0
# count  1019.000000  1019.000000  1019.000000  1019.000000  1019.000000
# mean      0.591858     0.455834     0.126595     0.067713     0.108930
# std       0.245210     0.109796     0.332682     0.251377     0.311705
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.487732     0.389318     0.000000     0.000000     0.000000
# 50%       0.644259     0.452081     0.000000     0.000000     0.000000
# 75%       0.760967     0.521150     0.000000     0.000000     0.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000

# %%
F1Train2.head()
# Out:
#     age0new  NHLecomb3  Comb1-2  Comb3+  Comb0
# 0  0.524531   0.377523        0       1      0
# 1  0.508154   0.601288        0       0      0
# 2  0.790186   0.350850        0       0      0
# 3  0.793604   0.560341        0       0      0
# 4  0.258897   0.572674        0       0      0

# %%
F1Test = ForwardsFin1.drop(columns = ['height_x','team_successDYn1','combine_total','weight_x','NHLGeDY0','NHLGeDYn1','NHLGeDelta','NHLeDY0','NHLeDYn1','age_DY0','age_DYn1','NHLeDelta','playername'])

# %%
F1Test = F1Test.reset_index()

# %%
F1Test = F1Test.drop(columns = 'index')

# %%
F1Test.describe()
# Out:
#             PS_new
# count  1019.000000
# mean      0.016118
# std       0.027866
# min      -0.029412
# 25%       0.000000
# 50%       0.000000
# 75%       0.023845
# max       0.177153

# %%
# F1Test = F1Test.drop_duplicates()

# %%
F1Test.describe()
# Out:
#             PS_new
# count  1019.000000
# mean      0.016118
# std       0.027866
# min      -0.029412
# 25%       0.000000
# 50%       0.000000
# 75%       0.023845
# max       0.177153

# %%
F1Test.head()
# Out:
#      PS_new
# 0  0.081148
# 1  0.038750
# 2  0.053659
# 3  0.007692
# 4  0.005435

# %%
F1Train2.corr()
# Out:
#             age0new  NHLecomb3   Comb1-2    Comb3+     Comb0
# age0new    1.000000  -0.210584  0.113844  0.087000  0.155204
# NHLecomb3 -0.210584   1.000000  0.071486  0.071734  0.109490
# Comb1-2    0.113844   0.071486  1.000000 -0.102604 -0.133112
# Comb3+     0.087000   0.071734 -0.102604  1.000000 -0.094228
# Comb0      0.155204   0.109490 -0.133112 -0.094228  1.000000

# %%
from sklearn.linear_model import Ridge, Lasso

# %%
#sns.distplot(F1Train2['team_successDY0'])

# %%
F1Train2.head()
# Out:
#     age0new  NHLecomb3  Comb1-2  Comb3+  Comb0
# 0  0.524531   0.377523        0       1      0
# 1  0.508154   0.601288        0       0      0
# 2  0.790186   0.350850        0       0      0
# 3  0.793604   0.560341        0       0      0
# 4  0.258897   0.572674        0       0      0

# %%
F1Test.head()
# Out:
#      PS_new
# 0  0.081148
# 1  0.038750
# 2  0.053659
# 3  0.007692
# 4  0.005435

# %%
D1Train = DefenseFin1.drop(columns = ['playername','PS_new'])

# %%
D1Train.head()
# Out:
#      height_x  weight_x   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 68        197       214  0.152075  0.028514  0.153901   0.046170
# 118       191       209  0.136856  0.022809  0.083229   0.032465
# 124       188       201  0.100672  0.021194  0.093541   0.020533
# 131       188       205  0.122193  0.033603  0.054187   0.009562
# 142       180       187  0.165113  0.035670  0.106240   0.017047
#
#      team_successDYn1  age_DY0  age_DYn1  NHLeDelta  NHLGeDelta  combine_total
# 68           0.676762   17.121    16.121  -0.001826   -0.017656       1.312042
# 118          0.886543   17.293    16.293   0.053627   -0.009656       1.312042
# 124          0.784444   17.140    16.140   0.007132    0.000661       1.312042
# 131          0.722239   16.964    15.964   0.068006    0.024041       1.312042
# 142          1.004600   16.745    15.745   0.058873    0.018624       1.312042

# %%
AgeDY0 = (1 / D1Train['age_DY0']) ### best was - .0474

# %%
AgeDY1 = 1 / D1Train['age_DYn1']

# %%
D1Train['age1new'] = AgeDY1

# %%
D1Train['age0new'] = AgeDY0

# %%
D1Train.head()
# Out:
#      height_x  weight_x   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 68        197       214  0.152075  0.028514  0.153901   0.046170
# 118       191       209  0.136856  0.022809  0.083229   0.032465
# 124       188       201  0.100672  0.021194  0.093541   0.020533
# 131       188       205  0.122193  0.033603  0.054187   0.009562
# 142       180       187  0.165113  0.035670  0.106240   0.017047
#
#      team_successDYn1  age_DY0  age_DYn1  NHLeDelta  NHLGeDelta  \
# 68           0.676762   17.121    16.121  -0.001826   -0.017656
# 118          0.886543   17.293    16.293   0.053627   -0.009656
# 124          0.784444   17.140    16.140   0.007132    0.000661
# 131          0.722239   16.964    15.964   0.068006    0.024041
# 142          1.004600   16.745    15.745   0.058873    0.018624
#
#      combine_total   age1new   age0new
# 68        1.312042  0.062031  0.058408
# 118       1.312042  0.061376  0.057827
# 124       1.312042  0.061958  0.058343
# ...

# %%
D1Train2 = D1Train.drop(columns = ['age_DY0','age_DYn1','age1new'])

# %%
D1Train2.head()
# Out:
#      height_x  weight_x   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 68        197       214  0.152075  0.028514  0.153901   0.046170
# 118       191       209  0.136856  0.022809  0.083229   0.032465
# 124       188       201  0.100672  0.021194  0.093541   0.020533
# 131       188       205  0.122193  0.033603  0.054187   0.009562
# 142       180       187  0.165113  0.035670  0.106240   0.017047
#
#      team_successDYn1  NHLeDelta  NHLGeDelta  combine_total   age0new
# 68           0.676762  -0.001826   -0.017656       1.312042  0.058408
# 118          0.886543   0.053627   -0.009656       1.312042  0.057827
# 124          0.784444   0.007132    0.000661       1.312042  0.058343
# 131          0.722239   0.068006    0.024041       1.312042  0.058948
# 142          1.004600   0.058873    0.018624       1.312042  0.059719

# %%
combined = D1Train2['NHLeDY0'] * D1Train2['age0new']

# %%
D1Train2['combo'] = combined

# %%
D1Train2 = D1Train2.reset_index()

# %%
D1Train2 = D1Train2.drop(columns='index')

# %%
import math as m

# %%
# D1Train2['NHLe0sqrt'] = [m.sqrt(i) for i in D1Train2['NHLeDY0']]

# %%
# D1Train2['NHLe1sqrt'] = [m.sqrt(i) for i in D1Train2['NHLeDYn1']]

# %%
D1Train2['NHLecomb3'] = (D1Train2['NHLeDY0'] * 0.6) + (D1Train2['NHLeDYn1'] * 0.4)

# %%
D1Train2['NHLecomb3'].max()
# Out:
# 0.3097187960940857

# %%
D1Train2['NHLecomb3'].min()
# Out:
# 0.0

# %%
D1Train2['NHLecomb3'] = (D1Train2['NHLecomb3'] - 0.0) / (0.3097187960940857 - 0)

# %%
D1Train2['NHLecomb3'] = [m.sqrt(i) for i in D1Train2['NHLecomb3']]

# %%
sns.distplot(D1Train2['NHLecomb3'])
# Out:
# <AxesSubplot:xlabel='NHLecomb3', ylabel='Density'>

# %%
D1Train2['age0new'].max()
# Out:
# 0.061312078479460456

# %%
D1Train2['age0new'].min()
# Out:
# 0.050289162685441285

# %%
D1Train2['age0new'] = (D1Train2['age0new'] - 0.050289162685441285) /  (0.061312078479460456 - 0.050289162685441285)

# %%
D1Train2['age0new'] = [i**2 for i in D1Train2['age0new']]

# %%
sns.distplot(D1Train2['age0new'])
# Out:
# <AxesSubplot:xlabel='age0new', ylabel='Density'>

# %%
#F1Train2['NHLesqrt'] = [m.sqrt(i) for i in F1Train2['NHLe01']]

# %%
# D1Train2['successDY0log'] = [m.log(i) for i in D1Train2['team_successDY0']]

# %%
# D1Train2 = D1Train2.drop(columns=['NHLe0sqrt','NHLe1sqrt'])

# %%
D1Test = DefenseFin1.drop(columns = ['combine_total','team_successDYn1','height_x','weight_x','NHLGeDY0','NHLGeDYn1','NHLGeDelta','NHLeDY0','NHLeDYn1','age_DY0','age_DYn1','NHLeDelta','playername'])

# %%
D1Test = D1Test.reset_index()

# %%
D1Test = D1Test.drop(columns = 'index')

# %%
D1Test.head()
# Out:
#      PS_new
# 0  0.066250
# 1  0.053226
# 2  0.055000
# 3  0.031818
# 4  0.041509

# %%
D1Train2['height_x'].max()
# Out:
# 205

# %%
# D1Train2['height'] = D1Train2['height_x'] / 205

# %%
a = [] 
for i in D1Train2['height_x']:
    if i < 0.9:
        a.append(1)
    else:
        a.append(0)
D1Train2['low_height'] = a

# %%
D1Train2['height_x'].max()
# Out:
# 205

# %%
D1Train2['height_x'].min()
# Out:
# 173

# %%
D1Train2['height'] = (D1Train2['height_x'] - 173) /  (205 - 173)

# %%
sns.distplot(D1Train2['height'])
# Out:
# <AxesSubplot:xlabel='height', ylabel='Density'>

# %%
D1Train2 = D1Train2.drop(columns=['low_height','height_x'])

# %%
D1Train2 = D1Train2.drop(columns = ['NHLeDY0','NHLeDYn1','NHLeDelta'])

# %%
D1Train2 = D1Train2.drop(columns = ['weight_x','NHLGeDY0','NHLGeDYn1','NHLGeDelta','combo'])

# %%
#D1Train2['combine_total'] = D1Train2['combine_total'] / 8

# %%
a = []
for i in D1Train2['combine_total']:
    if i == 1:
        a.append(1)
    elif i == 2:
        a.append(1)
    else:
        a.append(0)
D1Train2['Comb1-2'] = a

# %%
b = []
for i in D1Train2['combine_total']:
    if i == 4:
        b.append(1)
    elif i == 3:
        b.append(1)
    elif i == 5:
        b.append(1)
    elif i == 6:
        b.append(1)
    elif i >= 7:
        b.append(1)
    else:
        b.append(0)
D1Train2['Comb3+'] = b

# %%
# c = []
# for i in D1Train2['combine_total']:
#     if i >= 7:
#         c.append(1)
#     else:
#         c.append(0)
# D1Train2['Comb7+'] = c

# %%
d = []
for i in D1Train2['combine_total']:
    if i == 0:
        d.append(1)
    else:
        d.append(0)
D1Train2['Comb0'] = d

# %%
D1Train2 = D1Train2.drop(columns='combine_total')

# %%
D1Train2 = D1Train2.drop(columns=['team_successDYn1','height'])

# %%
### Repeat above for 2,3,4,5,6,7,8 and mean (minus the mean maybe)

# %%
D1Train2.head()
# Out:
#     age0new  NHLecomb3  Comb1-2  Comb3+  Comb0
# 0  0.542467   0.702401        0       0      0
# 1  0.467611   0.610419        0       0      0
# 2  0.533850   0.561991        0       0      0
# 3  0.617110   0.553804        0       0      0
# 4  0.731888   0.676071        0       0      0

# %%
D1Test.head()
# Out:
#      PS_new
# 0  0.066250
# 1  0.053226
# 2  0.055000
# 3  0.031818
# 4  0.041509

# %% [markdown]
# ### Trying to Standardize variables

# %%
import statistics as s

# %%
D1Train2.describe()
# Out:
#           age0new   NHLecomb3     Comb1-2      Comb3+       Comb0
# count  590.000000  590.000000  590.000000  590.000000  590.000000
# mean     0.597172    0.491353    0.106780    0.047458    0.137288
# std      0.241637    0.144575    0.309095    0.212796    0.344443
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.491961    0.394422    0.000000    0.000000    0.000000
# 50%      0.640928    0.482776    0.000000    0.000000    0.000000
# 75%      0.765175    0.598035    0.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000

# %%
# D1Train2['successDY0std'] = [(i - (D1Train2['successDY0log'].mean()))/ s.stdev(D1Train2['successDY0log']) for i in D1Train2['successDY0log']]

# %%
# D1Train2['successDYn1std'] = [(i - (D1Train2['team_successDYn1'].mean()))/ s.stdev(D1Train2['team_successDYn1']) for i in D1Train2['team_successDYn1']]

# %%
# D1Train2['NHLestd'] = [(i - (D1Train2['NHLecomb3'].mean()))/ s.stdev(D1Train2['NHLecomb3']) for i in D1Train2['NHLecomb3']]

# %%
# D1Train2['Agestd'] = [(i - (D1Train2['age0new'].mean()))/ s.stdev(D1Train2['age0new']) for i in D1Train2['age0new']]

# %%
# D1Train2 = D1Train2.drop(columns=['age0new','NHLecomb3','successDYn1std','successDY0std'])

# %%
F1Train2.head()
# Out:
#     age0new  NHLecomb3  Comb1-2  Comb3+  Comb0
# 0  0.524531   0.377523        0       1      0
# 1  0.508154   0.601288        0       0      0
# 2  0.790186   0.350850        0       0      0
# 3  0.793604   0.560341        0       0      0
# 4  0.258897   0.572674        0       0      0

# %% [markdown]
# ## Linear Regression - Used interaction which helped a lot

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree=2,interaction_only=True,include_bias = False)
InterF1Train2 = poly.fit_transform(F1Train2)
#
#
#
#
#
#
#

# %%
poly = PolynomialFeatures(degree=2,interaction_only=True,include_bias = False)
InterD1Train2 = poly.fit_transform(D1Train2)

# %%
X_Ftrain, X_Ftest, y_Ftrain, y_Ftest = train_test_split(InterF1Train2, F1Test, test_size=0.3, shuffle=True, random_state=100)
############ need to change F1Train2 back to InterF1Train2 ###############

# %% [markdown]
# ## Meta Model

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# Assuming you have two DataFrames feature_df and target_df

# Merge the two DataFrames based on a common index or column
merged_df = pd.merge(F1Train2, F1Test, left_index=True, right_index=True)  # Adjust this based on your data structure

# Split the merged data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(merged_df[['age0new', 'NHLecomb3','height','Comb1-2','Comb3+','Comb0']], merged_df['PS_new'], test_size=0.2, random_state=100)

# Train diverse base models (Random Forest and Linear Regression, for example)
base_model1 = RandomForestRegressor(n_estimators=100, random_state=100)
base_model1.fit(X_train, y_train)

base_model2 = LinearRegression()
base_model2.fit(X_train, y_train)

# Generate predictions from base models on the test set
pred1 = base_model1.predict(X_test)
pred2 = base_model2.predict(X_test)

# Create stacking dataset
stacking_dataset = pd.DataFrame({'BaseModel1_Pred': pred1, 'BaseModel2_Pred': pred2})

# Train a meta-model (Linear Regression as an example) on the test set
meta_model = LinearRegression()
meta_model.fit(stacking_dataset, y_test)

# Make final prediction using base models and meta-model on the test set
final_pred = meta_model.predict(stacking_dataset)

# Evaluate the final prediction
mse_final = mean_squared_error(y_test, final_pred)
print(f'Mean Squared Error of Stacked Model on Test Set: {mse_final}')
# Out:
# Mean Squared Error of Stacked Model on Test Set: 0.0006956165266196238

# %% [markdown]
# ## Meta Defensemen

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# Assuming you have two DataFrames feature_df and target_df

# Merge the two DataFrames based on a common index or column
merged_df = pd.merge(D1Train2, D1Test, left_index=True, right_index=True)  # Adjust this based on your data structure

# Split the merged data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(merged_df[['age0new', 'NHLecomb3','Comb3+','Comb0','Comb1-2','height']], merged_df['PS_new'], test_size=0.2, random_state=100)

# Train diverse base models (Random Forest and Linear Regression, for example)
base_model1 = RandomForestRegressor(n_estimators=100, random_state=100)
base_model1.fit(X_train, y_train)

base_model2 = LinearRegression()
base_model2.fit(X_train, y_train)

# Generate predictions from base models on the test set
pred1 = base_model1.predict(X_test)
pred2 = base_model2.predict(X_test)

# Create stacking dataset
stacking_dataset = pd.DataFrame({'BaseModel1_Pred': pred1, 'BaseModel2_Pred': pred2})

# Train a meta-model (Linear Regression as an example) on the test set
meta_model = LinearRegression()
meta_model.fit(stacking_dataset, y_test)

# Make final prediction using base models and meta-model on the test set
final_pred = meta_model.predict(stacking_dataset)

# Evaluate the final prediction
mse_final = mean_squared_error(y_test, final_pred)
print(f'Mean Squared Error of Stacked Model on Test Set: {mse_final}')
# Out:
# Mean Squared Error of Stacked Model on Test Set: 0.0006420910014502257

# %%
# Import necessary libraries
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Assuming you have prepared and cleaned data, and split it into training and testing sets
# X_train, X_test: Training and testing feature matrices (with three continuous variables)
# y_train, y_test: Training and testing target variables (continuous)

# Create and train the gradient boosted tree model
gradient_boosted_model = GradientBoostingRegressor(n_estimators=100, random_state=42, max_depth=10,min_samples_leaf=1, min_samples_split=10)  # You can adjust n_estimators and other hyperparameters
gradient_boosted_model.fit(X_Ftrain, y_Ftrain)

# Make predictions on the test set
y_pred = gradient_boosted_model.predict(X_Ftest)

# Evaluate the model
mse = mean_squared_error(y_Ftest, y_pred)
print(f'Mean Squared Error on Test Set: {mse}')
# Out:
# Mean Squared Error on Test Set: 0.0008848883884546805

# %%
# Visualize feature importances
feature_importances = gradient_boosted_model.feature_importances_
feature_names = ['Feature1', 'Feature2']  # Replace with your actual feature names

# Plot feature importances
plt.figure(figsize=(10, 6))
plt.bar(feature_names, feature_importances, color='skyblue')
plt.xlabel('Feature Names')
plt.ylabel('Feature Importances')
plt.title('Gradient Boosted Tree Feature Importances')
plt.show()

# Scatter plot for the actual vs. predicted values (optional)
plt.scatter(y_Ftest, y_pred)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs. Predicted Values')
plt.show()

# %%
# Import necessary libraries
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Assuming you have prepared and cleaned data, and split it into training and testing sets
# X_train, X_test: Training and testing feature matrices (with three continuous variables)
# y_train, y_test: Training and testing target variables (continuous)

# Create and train the random forest model
random_forest_model = RandomForestRegressor(n_estimators=100, random_state=100, max_depth=10, min_samples_leaf=3, min_samples_split=10)  # You can adjust n_estimators and other hyperparameters
random_forest_model.fit(X_Ftrain, y_Ftrain)

# Make predictions on the test set
y_pred = random_forest_model.predict(X_Ftest)

# Evaluate the model
mse = mean_squared_error(y_Ftest, y_pred)
print(f'Mean Squared Error on Test Set: {mse}')
# Out:
# Mean Squared Error on Test Set: 0.0007146033574804252

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}

grid_search = GridSearchCV(RandomForestRegressor(random_state=42), param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_Ftrain, y_Ftrain)

# Get the best hyperparameters
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)
# Out:
# Best Hyperparameters: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100}

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}

grid_search = GridSearchCV(RandomForestRegressor(random_state=100), param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_Ftrain, y_Ftrain)

# Get the best hyperparameters
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)
# Out:
# Best Hyperparameters: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100}

# %%
# Visualize feature importances
feature_importances = random_forest_model.feature_importances_
feature_names = ['Feature1', 'Feature2','Feature3','Feature4','Feature5','Feature6']  # Replace with your actual feature names

# Plot feature importances
plt.figure(figsize=(10, 6))
plt.bar(feature_names, feature_importances, color='skyblue')
plt.xlabel('Feature Names')
plt.ylabel('Feature Importances')
plt.title('Random Forest Feature Importances')
plt.show()

# Scatter plot for the actual vs. predicted values (optional)
plt.scatter(y_Ftest, y_pred)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs. Predicted Values')
plt.show()

# %%
# Import necessary libraries
from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
# Assuming you have prepared and cleaned data, and split it into training and testing sets
# X_train, X_test: Training and testing feature matrices (with three continuous variables)
# y_train, y_test: Training and testing target variables (continuous)

# Create and train the decision tree model
decision_tree_model = DecisionTreeRegressor(max_depth=3)  # You can adjust max_depth for tree depth
decision_tree_model.fit(X_Ftrain, y_Ftrain)


# Make predictions on the test set
y_pred = decision_tree_model.predict(X_Ftest)

# Evaluate the model
mse = mean_squared_error(y_Ftest, y_pred)
print(f'Mean Squared Error on Test Set: {mse}')

# Visualize the decision tree
plt.figure(figsize=(15, 10))
plot_tree(decision_tree_model, feature_names=['Feature1', 'Feature2'], filled=True, rounded=True)
plt.show()

# Print feature importances (optional)
print('Feature Importances:', decision_tree_model.feature_importances_)

# Scatter plot for the actual vs. predicted values (optional)
plt.scatter(y_Ftest, y_pred)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs. Predicted Values')
plt.show()
# Out:
# Mean Squared Error on Test Set: 0.0006947554869463649
# Feature Importances: [0.27431877 0.72568123]

# %%
tree_model = meta_model.fit(X_train, y_train)

# %%
y_Fpred = tree_model.predict(Test17F2)

# %%
T17Merge['tree_prediction'] = y_Fpred

# %%
pd.set_option('display.max_rows', 300)

# %%
## Meta
T17Merge
# Out:
#     height_x              playername   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 0        185             Justin Gill  0.166837  0.078933  0.085702   0.037262
# 1        180            Brett Hyland  0.136053  0.075263  0.058793   0.026356
# 2        198         Milton Oscarson  0.065633  0.033680  0.102271   0.035310
# 3        180              Ty Mueller  0.134468  0.064545  0.104825   0.064508
# 4        178             Jack Harvey  0.127937  0.069155  0.090278   0.047903
# 5        180            Matt Copponi  0.143336  0.069197  0.069668   0.023223
# 6        181       Stanislav Yarovoy  0.199883  0.103321  0.082166   0.034858
# 7        180              Sam Harris  0.107191  0.057424  0.066634   0.030461
# 8        187         Michael Emerson  0.114337  0.053595  0.022211   0.012692
# 9        178            Austin Roest  0.158053  0.064842  0.067074   0.027249
# 10       193         Casper NÃ¤ssÃ©n  0.085663  0.049256  0.009624   0.000000
# ...

# %%
T17Merge
# Out:
#     height_x              playername   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 0        185             Justin Gill  0.166837  0.078933  0.085702   0.037262
# 1        180            Brett Hyland  0.136053  0.075263  0.058793   0.026356
# 2        198         Milton Oscarson  0.065633  0.033680  0.102271   0.035310
# 3        180              Ty Mueller  0.134468  0.064545  0.104825   0.064508
# 4        178             Jack Harvey  0.127937  0.069155  0.090278   0.047903
# 5        180            Matt Copponi  0.143336  0.069197  0.069668   0.023223
# 6        181       Stanislav Yarovoy  0.199883  0.103321  0.082166   0.034858
# 7        180              Sam Harris  0.107191  0.057424  0.066634   0.030461
# 8        187         Michael Emerson  0.114337  0.053595  0.022211   0.012692
# 9        178            Austin Roest  0.158053  0.064842  0.067074   0.027249
# 10       193         Casper NÃ¤ssÃ©n  0.085663  0.049256  0.009624   0.000000
# ...

# %%
T17Merge
# Out:
#     height_x              playername   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 0        185             Justin Gill  0.166837  0.078933  0.085702   0.037262
# 1        180            Brett Hyland  0.136053  0.075263  0.058793   0.026356
# 2        198         Milton Oscarson  0.065633  0.033680  0.102271   0.035310
# 3        180              Ty Mueller  0.134468  0.064545  0.104825   0.064508
# 4        178             Jack Harvey  0.127937  0.069155  0.090278   0.047903
# 5        180            Matt Copponi  0.143336  0.069197  0.069668   0.023223
# 6        181       Stanislav Yarovoy  0.199883  0.103321  0.082166   0.034858
# 7        180              Sam Harris  0.107191  0.057424  0.066634   0.030461
# 8        187         Michael Emerson  0.114337  0.053595  0.022211   0.012692
# 9        178            Austin Roest  0.158053  0.064842  0.067074   0.027249
# 10       193         Casper NÃ¤ssÃ©n  0.085663  0.049256  0.009624   0.000000
# ...

# %%
T17Merge
# Out:
#     height_x              playername   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 0        185             Justin Gill  0.166837  0.078933  0.085702   0.037262
# 1        180            Brett Hyland  0.136053  0.075263  0.058793   0.026356
# 2        198         Milton Oscarson  0.065633  0.033680  0.102271   0.035310
# 3        180              Ty Mueller  0.134468  0.064545  0.104825   0.064508
# 4        178             Jack Harvey  0.127937  0.069155  0.090278   0.047903
# 5        180            Matt Copponi  0.143336  0.069197  0.069668   0.023223
# 6        181       Stanislav Yarovoy  0.199883  0.103321  0.082166   0.034858
# 7        180              Sam Harris  0.107191  0.057424  0.066634   0.030461
# 8        187         Michael Emerson  0.114337  0.053595  0.022211   0.012692
# 9        178            Austin Roest  0.158053  0.064842  0.067074   0.027249
# 10       193         Casper NÃ¤ssÃ©n  0.085663  0.049256  0.009624   0.000000
# ...

# %%
T17Merge
# Out:
#     height_x              playername   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 0        185             Justin Gill  0.166837  0.078933  0.085702   0.037262
# 1        180            Brett Hyland  0.136053  0.075263  0.058793   0.026356
# 2        198         Milton Oscarson  0.065633  0.033680  0.102271   0.035310
# 3        180              Ty Mueller  0.134468  0.064545  0.104825   0.064508
# 4        178             Jack Harvey  0.127937  0.069155  0.090278   0.047903
# 5        180            Matt Copponi  0.143336  0.069197  0.069668   0.023223
# 6        181       Stanislav Yarovoy  0.199883  0.103321  0.082166   0.034858
# 7        180              Sam Harris  0.107191  0.057424  0.066634   0.030461
# 8        187         Michael Emerson  0.114337  0.053595  0.022211   0.012692
# 9        178            Austin Roest  0.158053  0.064842  0.067074   0.027249
# 10       193         Casper NÃ¤ssÃ©n  0.085663  0.049256  0.009624   0.000000
# ...

# %%
X_Ftrain
# Out:
# array([[0.10624964, 0.37837838, 0.45951501, 0.04020256, 0.0488233 ,
#         0.17387055],
#        [0.31090945, 0.37837838, 0.5196474 , 0.11764141, 0.16156328,
#         0.19662334],
#        [0.75985823, 0.27027027, 0.455886  , 0.20536709, 0.34640873,
#         0.12321243],
#        ...,
#        [0.74772796, 0.45945946, 0.43394205, 0.34355068, 0.3244706 ,
#         0.19937878],
#        [0.43965732, 0.67567568, 0.44999196, 0.29706576, 0.19784226,
#         0.30404862],
#        [0.7537769 , 0.45945946, 0.4848393 , 0.34632993, 0.36546067,
#         0.222764  ]])

# %%
X_Dtrain, X_Dtest, y_Dtrain, y_Dtest = train_test_split(InterD1Train2, D1Test, test_size=0.3, shuffle=True, random_state=100)

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.linear_model import Lasso

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
DregrL = Lasso(alpha=0.1) #was 0.043111 before years, major_years....
  
DregrL.fit(X_Dtrain, y_Dtrain)
print(DregrL.score(X_Dtest, y_Dtest))
# Out:
# -0.0029496628985139495

# %%
lasso = Lasso(alpha=.0000075)
lasso.fit(X_Dtrain, y_Dtrain)

y_Dtrain_pred = lasso.predict(X_Dtrain)
y_Dtest_pred =  lasso.predict(X_Dtest)

### Model evaluation
print('R2 score (train) : ',round(r2_score(y_Dtrain,y_Dtrain_pred),4))
print('R2 score (test) : ',round(r2_score(y_Dtest,y_Dtest_pred),4))
print('RMSE (train) : ', round(np.sqrt(mean_squared_error(y_Dtrain, y_Dtrain_pred)),4))
print('RMSE (test) : ', round(np.sqrt(mean_squared_error(y_Dtest, y_Dtest_pred)),4))
# Out:
# R2 score (train) :  0.1902
# R2 score (test) :  0.2131
# RMSE (train) :  0.0276
# RMSE (test) :  0.0271

# %%
featurenames = poly.get_feature_names_out()

# %%
coefficients3 = pd.concat([pd.DataFrame(featurenames),pd.DataFrame(np.transpose(lasso.coef_))], axis = 1)

# %%
pd.set_option('display.max_rows', None)

# %%
coefficients3.head(100)

### This is after standardizing variables
# Out:
#                    0         0
# 0            age0new  0.000000
# 1          NHLecomb3  0.150340
# 2             Comb3+ -0.006409
# 3  age0new NHLecomb3  0.000000
# 4     age0new Comb3+ -0.000000
# 5   NHLecomb3 Comb3+  0.070165

# %%
poly = PolynomialFeatures(degree=2,interaction_only=True,include_bias = False)
InterTest17D = poly.fit_transform(Test17D2)

# %% [markdown]
# ## Defense Test (2018) scores
# - 6/27: -0.296
# - 7/3: -15
# - 7/4: -12.78

# %%
Dregr6 = Lasso(alpha=0.0000075) #before NHLeG was 0.195367
  
Dregr4 = Dregr6.fit(InterD1Train2, D1Test)     # first was InterF1Train2
#print(Dregr3.score(InterTest17D, PS2017D2))  # commeted this out on 7/8                   first was InterTest17F
#print(regr3.score(X_Ftest, y_Ftest))

# %%
#PS2017D2 = PS2017D2.drop(columns='prediction')

# %%
y_Dpred = Dregr4.predict(InterTest17D)

# %%
y_Dpred
# Out:
# array([ 0.0343085 ,  0.03112685,  0.01271459,  0.01095093,  0.02169241,
#         0.0234906 ,  0.03316804,  0.0227379 ,  0.02759113,  0.01065313,
#         0.05606564,  0.04219159,  0.03669329,  0.01327571,  0.00508542,
#         0.01455269,  0.04704974,  0.02334622,  0.02125902,  0.01081191,
#         0.01174586,  0.00921683,  0.02309823,  0.00631188,  0.01895555,
#         0.01211549,  0.04928925,  0.02158547,  0.01794672,  0.04069157,
#         0.00974495,  0.02941993,  0.01657518,  0.00643774,  0.01536918,
#        -0.00133246,  0.02500338,  0.01809317,  0.01427253,  0.01479783,
#         0.03688448,  0.04122525,  0.01289637,  0.01826828,  0.01326853,
#         0.00267112,  0.00323191,  0.01815035,  0.00553933,  0.00664212,
#         0.02227103,  0.02700042])

# %%
#PS2017D2['prediction'] = y_Dpred

# %%
T17MergeD['prediction'] = y_Dpred

# %%
#Test17D['prediction'] = y_Dpred

# %%
tree_model = meta_model.fit(X_train, y_train)

# %%
y_Dpred = tree_model.predict(Test17D2)

# %%
T17MergeD['tree_prediction'] = y_Dpred

# %%
## meta with comb1-2, comb0, comb3+, age, and NHLe, and height

T17MergeD
# Out:
#     height_x              playername   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 0        180        Luke Mittelstadt  0.130248  0.022770  0.134020   0.046298
# 1        185           Jeremy Hanzel  0.132490  0.035883  0.094889   0.020128
# 2        191  Charles-Alexis Legault  0.053281  0.011840  0.039488   0.013163
# 3        190          Rasmus Larsson  0.118038  0.055547  0.000000   0.000000
# 4        188        Dennis Good Bogg  0.121215  0.017316  0.030074   0.007450
# 5        180           Eric Pohlkamp  0.119318  0.037433  0.043142   0.016777
# 6        187         Rodwin Dionicio  0.156616  0.053985  0.086830   0.016806
# 7        183            Kalem Parker  0.101803  0.016074  0.055042   0.009754
# 8        189        David Reinbacher  0.115416  0.012817  0.081272   0.004271
# 9        197            Konnor Smith  0.040601  0.008120  0.043307   0.014436
# 10       183      Hunter Brzustewicz  0.147479  0.015524  0.054666   0.003249
# ...

# %%
## meta with comb1-2, comb0, comb3+, age, and NHLe

T17MergeD
# Out:
#     height_x              playername   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 0        180        Luke Mittelstadt  0.130248  0.022770  0.134020   0.046298
# 1        185           Jeremy Hanzel  0.132490  0.035883  0.094889   0.020128
# 2        191  Charles-Alexis Legault  0.053281  0.011840  0.039488   0.013163
# 3        190          Rasmus Larsson  0.118038  0.055547  0.000000   0.000000
# 4        188        Dennis Good Bogg  0.121215  0.017316  0.030074   0.007450
# 5        180           Eric Pohlkamp  0.119318  0.037433  0.043142   0.016777
# 6        187         Rodwin Dionicio  0.156616  0.053985  0.086830   0.016806
# 7        183            Kalem Parker  0.101803  0.016074  0.055042   0.009754
# 8        189        David Reinbacher  0.115416  0.012817  0.081272   0.004271
# 9        197            Konnor Smith  0.040601  0.008120  0.043307   0.014436
# 10       183      Hunter Brzustewicz  0.147479  0.015524  0.054666   0.003249
# ...

# %%
## Meta

T17MergeD
# Out:
#     height_x              playername   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 0        180        Luke Mittelstadt  0.130248  0.022770  0.134020   0.046298
# 1        185           Jeremy Hanzel  0.132490  0.035883  0.094889   0.020128
# 2        191  Charles-Alexis Legault  0.053281  0.011840  0.039488   0.013163
# 3        190          Rasmus Larsson  0.118038  0.055547  0.000000   0.000000
# 4        188        Dennis Good Bogg  0.121215  0.017316  0.030074   0.007450
# 5        180           Eric Pohlkamp  0.119318  0.037433  0.043142   0.016777
# 6        187         Rodwin Dionicio  0.156616  0.053985  0.086830   0.016806
# 7        183            Kalem Parker  0.101803  0.016074  0.055042   0.009754
# 8        189        David Reinbacher  0.115416  0.012817  0.081272   0.004271
# 9        197            Konnor Smith  0.040601  0.008120  0.043307   0.014436
# 10       183      Hunter Brzustewicz  0.147479  0.015524  0.054666   0.003249
# ...

# %%
T17MergeD.head(150)
# Out:
#     height_x              playername   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 0        180        Luke Mittelstadt  0.130248  0.022770  0.134020   0.046298
# 1        185           Jeremy Hanzel  0.132490  0.035883  0.094889   0.020128
# 2        191  Charles-Alexis Legault  0.053281  0.011840  0.039488   0.013163
# 3        190          Rasmus Larsson  0.118038  0.055547  0.000000   0.000000
# 4        188        Dennis Good Bogg  0.121215  0.017316  0.030074   0.007450
# 5        180           Eric Pohlkamp  0.119318  0.037433  0.043142   0.016777
# 6        187         Rodwin Dionicio  0.156616  0.053985  0.086830   0.016806
# 7        183            Kalem Parker  0.101803  0.016074  0.055042   0.009754
# 8        189        David Reinbacher  0.115416  0.012817  0.081272   0.004271
# 9        197            Konnor Smith  0.040601  0.008120  0.043307   0.014436
# 10       183      Hunter Brzustewicz  0.147479  0.015524  0.054666   0.003249
# ...

# %% [markdown]
# ## Defense Regression Scores
# - 8/20: 0.134, using comb3+
# - 8/20: 0.10, using comb2+
# - 1/2/24: 0.213, after fixing the training set and adjusted equivalencies

# %%
Dregr = Lasso(alpha=0.00001) #was 0.043111 before years, major_years....
  
Dregr.fit(X_Dtrain, y_Dtrain)
print(Dregr.score(X_Dtest, y_Dtest))
# Out:
# 0.19963173876039697

# %%
featurenames = poly.get_feature_names_out()

# %%
coefficients2 = pd.concat([pd.DataFrame(featurenames),pd.DataFrame(np.transpose(Dregr.coef_))], axis = 1)

# %%
pd.set_option('display.max_rows', None)

# %%
coefficients2.head(100)

### This is after standardizing variables
# Out:
#                     0         0
# 0             age0new -0.029025
# 1           NHLecomb3  0.035456
# 2             Comb1-2 -0.004375
# 3              Comb3+ -0.015355
# 4               Comb0  0.022649
# 5   age0new NHLecomb3  0.090174
# 6     age0new Comb1-2  0.004299
# 7      age0new Comb3+ -0.000000
# 8       age0new Comb0 -0.054798
# 9   NHLecomb3 Comb1-2  0.000000
# 10   NHLecomb3 Comb3+  0.051993
# 11    NHLecomb3 Comb0  0.021833
# 12     Comb1-2 Comb3+  0.000000
# 13      Comb1-2 Comb0  0.000000
# 14       Comb3+ Comb0  0.000000

# %%
poly = PolynomialFeatures(degree=2,interaction_only=True,include_bias = False)
InterTest17D = poly.fit_transform(Test17D2)

# %% [markdown]
# ## Defense Test (2018) scores
# - 6/27: -0.296
# - 7/3: -15
# - 7/4: -12.78

# %%
Dregr5 = Lasso(alpha=0.00001) #before NHLeG was 0.195367
  
Dregr3 = Dregr5.fit(InterD1Train2, D1Test)     # first was InterF1Train2
#print(Dregr3.score(InterTest17D, PS2017D2))  # commeted this out on 7/8                   first was InterTest17F
#print(regr3.score(X_Ftest, y_Ftest))

# %%
#PS2017D2 = PS2017D2.drop(columns='prediction')

# %%
y_Dpred = Dregr3.predict(InterTest17D)

# %%
#PS2017D2['prediction'] = y_Dpred

# %%
T17MergeD['prediction2'] = y_Dpred

# %%
#Test17D['prediction'] = y_Dpred

# %%
T17MergeD.head(150)
# Out:
#     height_x              playername   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 0        180        Luke Mittelstadt  0.130248  0.022770  0.134020   0.046298
# 1        185           Jeremy Hanzel  0.132490  0.035883  0.094889   0.020128
# 2        191  Charles-Alexis Legault  0.053281  0.011840  0.039488   0.013163
# 3        190          Rasmus Larsson  0.118038  0.055547  0.000000   0.000000
# 4        188        Dennis Good Bogg  0.121215  0.017316  0.030074   0.007450
# 5        180           Eric Pohlkamp  0.119318  0.037433  0.043142   0.016777
# 6        187         Rodwin Dionicio  0.156616  0.053985  0.086830   0.016806
# 7        183            Kalem Parker  0.101803  0.016074  0.055042   0.009754
# 8        189        David Reinbacher  0.115416  0.012817  0.081272   0.004271
# 9        197            Konnor Smith  0.040601  0.008120  0.043307   0.014436
# 10       183      Hunter Brzustewicz  0.147479  0.015524  0.054666   0.003249
# ...

# %%
poly = PolynomialFeatures(degree=2,interaction_only=True, include_bias = False)
InterTest17F = poly.fit_transform(Test17F2)

# %% [markdown]
# ## Scores
# - 8/20: 0.259
# - 1/2/24: 0.3
# - 1/2/224: 0.293, after adding in team successDYn1 (went down)

# %%
regr = Lasso(alpha=0.00001) #before NHLeG was 0.471985269788
  
regr2 = regr.fit(X_Ftrain, y_Ftrain)
print(regr2.score(X_Ftest, y_Ftest))
# Out:
# 0.2875217021778036

# %%
featurenames = poly.get_feature_names_out()

# %%
coefficients2 = pd.concat([pd.DataFrame(featurenames),pd.DataFrame(np.transpose(regr.coef_))], axis = 1)

# %%
pd.set_option('display.max_rows', None)

# %%
coefficients2.head(50)
# Out:
#                     0         0
# 0             age0new -0.022664
# 1           NHLecomb3  0.018202
# 2             Comb1-2 -0.062894
# 3              Comb3+ -0.036640
# 4               Comb0 -0.036287
# 5   age0new NHLecomb3  0.099936
# 6     age0new Comb1-2  0.006208
# 7      age0new Comb3+ -0.015311
# 8       age0new Comb0  0.011889
# 9   NHLecomb3 Comb1-2  0.129133
# 10   NHLecomb3 Comb3+  0.107340
# 11    NHLecomb3 Comb0  0.056851
# 12     Comb1-2 Comb3+  0.000000
# 13      Comb1-2 Comb0  0.000000
# 14       Comb3+ Comb0  0.000000

# %% [markdown]
# ## scores
# - 6/27: 0.027

# %%
regr5 = Lasso(alpha=0.00001) #before NHLeG was 0.195367
  
regr3 = regr5.fit(InterF1Train2, F1Test)     # first was InterF1Train2
#print(regr3.score(InterTest17F, PS2017F2))  #commented out on 7/8           first was InterTest17F
#print(regr3.score(X_Ftest, y_Ftest))

# %%
y_Fpred = regr3.predict(InterTest17F)

# %%
#PS2017F2['prediction'] = y_Fpred

# %%
T17Merge['prediction'] = y_Fpred

# %%
#Test17F['prediction'] = y_Fpred

# %% [markdown]
# ## Comparing how the model predicted (prediction) to how well the player is actually playing in the NHL so far (PS_new)
# - I put this chart below into excel and sorted by the top players that the model predicted vs. how the draft actually went

# %%
T17Merge.head(150)
# Out:
#     height_x              playername   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 0        185             Justin Gill  0.166837  0.078933  0.085702   0.037262
# 1        180            Brett Hyland  0.136053  0.075263  0.058793   0.026356
# 2        198         Milton Oscarson  0.065633  0.033680  0.102271   0.035310
# 3        180              Ty Mueller  0.134468  0.064545  0.104825   0.064508
# 4        178             Jack Harvey  0.127937  0.069155  0.090278   0.047903
# 5        180            Matt Copponi  0.143336  0.069197  0.069668   0.023223
# 6        181       Stanislav Yarovoy  0.199883  0.103321  0.082166   0.034858
# 7        180              Sam Harris  0.107191  0.057424  0.066634   0.030461
# 8        187         Michael Emerson  0.114337  0.053595  0.022211   0.012692
# 9        178            Austin Roest  0.158053  0.064842  0.067074   0.027249
# 10       193         Casper NÃ¤ssÃ©n  0.085663  0.049256  0.009624   0.000000
# ...

# %%
lasso = Lasso(alpha=.00000075)
lasso.fit(X_Ftrain, y_Ftrain)

y_Ftrain_pred = lasso.predict(X_Ftrain)
y_Ftest_pred =  lasso.predict(X_Ftest)

### Model evaluation
print('R2 score (train) : ',round(r2_score(y_Ftrain,y_Ftrain_pred),4))
print('R2 score (test) : ',round(r2_score(y_Ftest,y_Ftest_pred),4))
print('RMSE (train) : ', round(np.sqrt(mean_squared_error(y_Ftrain, y_Ftrain_pred)),4))
print('RMSE (test) : ', round(np.sqrt(mean_squared_error(y_Ftest, y_Ftest_pred)),4))
# Out:
# R2 score (train) :  0.2361
# R2 score (test) :  0.2764
# RMSE (train) :  0.0233
# RMSE (test) :  0.0259

# %%
featurenames = poly.get_feature_names_out()

# %%
coefficients3 = pd.concat([pd.DataFrame(featurenames),pd.DataFrame(np.transpose(lasso.coef_))], axis = 1)

# %%
pd.set_option('display.max_rows', None)

# %%
coefficients3.head(100)

### This is after standardizing variables
# Out:
#                    0         0
# 0            age0new -0.049175
# 1          NHLecomb3 -0.019210
# 2             height  0.007845
# 3  age0new NHLecomb3  0.021107
# 4     age0new height  0.141491
# 5   NHLecomb3 height  0.041304

# %%
poly = PolynomialFeatures(degree=2,interaction_only=True,include_bias = False)
InterTest17F = poly.fit_transform(Test17F2)

# %% [markdown]
# ## Defense Test (2018) scores
# - 6/27: -0.296
# - 7/3: -15
# - 7/4: -12.78

# %%
Fregr6 = Lasso(alpha=0.00000075) #before NHLeG was 0.195367
  
Fregr4 = Fregr6.fit(InterF1Train2, F1Test)     # first was InterF1Train2
#print(Dregr3.score(InterTest17D, PS2017D2))  # commeted this out on 7/8                   first was InterTest17F
#print(regr3.score(X_Ftest, y_Ftest))

# %%
#PS2017D2 = PS2017D2.drop(columns='prediction')

# %%
y_Fpred = Fregr4.predict(InterTest17F)

# %%
y_Fpred
# Out:
# array([ 0.00212767, -0.00766071,  0.02308536, -0.00743483, -0.01129357,
#        -0.00742949, -0.00423666, -0.00834937,  0.00746391, -0.01179894,
#         0.02498156,  0.03025031,  0.00163477, -0.00067273, -0.00773927,
#         0.05517383,  0.00202905, -0.0205236 ,  0.00078716,  0.02126974,
#         0.01861607, -0.02466752,  0.01358863,  0.01382477, -0.01090287,
#         0.02513523,  0.03109612,  0.01112097,  0.04260289,  0.02288071,
#        -0.01733968,  0.00345826,  0.02324214,  0.04253335,  0.00539848,
#        -0.01140214,  0.01351952,  0.03648786,  0.00140982,  0.03645824,
#         0.02624654, -0.02905355,  0.01101163, -0.02622066, -0.00792011,
#         0.00703903,  0.02805861, -0.00738447,  0.00976512,  0.00549006,
#         0.01249331,  0.03197363, -0.01447603,  0.05276417,  0.01672787,
#         0.0097679 ,  0.06106336,  0.00497804,  0.03812325,  0.02582374,
#        -0.00734791,  0.0136592 , -0.00794749,  0.03177821,  0.01478877,
# ...

# %%
#PS2017D2['prediction'] = y_Dpred

# %%
T17Merge['prediction2'] = y_Fpred

# %%
T17Merge
# Out:
#     height_x              playername   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 0        185             Justin Gill  0.166837  0.078933  0.085702   0.037262
# 1        180            Brett Hyland  0.136053  0.075263  0.058793   0.026356
# 2        198         Milton Oscarson  0.065633  0.033680  0.102271   0.035310
# 3        180              Ty Mueller  0.134468  0.064545  0.104825   0.064508
# 4        178             Jack Harvey  0.127937  0.069155  0.090278   0.047903
# 5        180            Matt Copponi  0.143336  0.069197  0.069668   0.023223
# 6        181       Stanislav Yarovoy  0.199883  0.103321  0.082166   0.034858
# 7        180              Sam Harris  0.107191  0.057424  0.066634   0.030461
# 8        187         Michael Emerson  0.114337  0.053595  0.022211   0.012692
# 9        178            Austin Roest  0.158053  0.064842  0.067074   0.027249
# 10       193         Casper NÃ¤ssÃ©n  0.085663  0.049256  0.009624   0.000000
# ...

# %%
### After lowering weight for USDP
T17Merge
# Out:
#     height_x              playername   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 0        185             Justin Gill  0.166706  0.078872  0.082457   0.035851
# 1        180            Brett Hyland  0.135947  0.075205  0.057755   0.025890
# 2        198         Milton Oscarson  0.070148  0.038019  0.091518   0.031452
# 3        180              Ty Mueller  0.134363  0.064494  0.098981   0.060911
# 4        178             Jack Harvey  0.128023  0.069202  0.084772   0.044981
# 5        180            Matt Copponi  0.143224  0.069143  0.065784   0.021928
# 6        181       Stanislav Yarovoy  0.199674  0.103221  0.076886   0.032618
# 7        180              Sam Harris  0.107263  0.057462  0.062570   0.028603
# 8        187         Michael Emerson  0.114414  0.053631  0.020857   0.011918
# 9        178            Austin Roest  0.157930  0.064792  0.065890   0.026768
# 10       193         Casper NÃ¤ssÃ©n  0.085725  0.049292  0.008572   0.000000
# ...

# %%
###This is after adding the new league equivalencies on 12/21/23 for every league


T17Merge
# Out:
#     height_x              playername   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 0        185             Justin Gill  0.166706  0.078872  0.082457   0.035851
# 1        180            Brett Hyland  0.135947  0.075205  0.057755   0.025890
# 2        198         Milton Oscarson  0.070148  0.038019  0.091518   0.031452
# 3        180              Ty Mueller  0.134363  0.064494  0.098981   0.060911
# 4        178             Jack Harvey  0.128023  0.069202  0.084772   0.044981
# 5        180            Matt Copponi  0.143224  0.069143  0.065784   0.021928
# 6        181       Stanislav Yarovoy  0.199674  0.103221  0.076886   0.032618
# 7        180              Sam Harris  0.107263  0.057462  0.062570   0.028603
# 8        187         Michael Emerson  0.114414  0.053631  0.020857   0.011918
# 9        178            Austin Roest  0.157930  0.064792  0.065890   0.026768
# 10       193         Casper NÃ¤ssÃ©n  0.085725  0.049292  0.008572   0.000000
# ...

# %%
### had some of  the new league equivalencies

T17Merge
# Out:
#     height_x              playername   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 0        185             Justin Gill  0.166706  0.078872  0.082457   0.035851
# 1        180            Brett Hyland  0.135947  0.075205  0.057755   0.025890
# 2        198         Milton Oscarson  0.065586  0.035143  0.082219   0.027823
# 3        180              Ty Mueller  0.134363  0.064494  0.098981   0.060911
# 4        178             Jack Harvey  0.128023  0.069202  0.084772   0.044981
# 5        180            Matt Copponi  0.143224  0.069143  0.065784   0.021928
# 6        181       Stanislav Yarovoy  0.204657  0.104764  0.084268   0.035750
# 7        180              Sam Harris  0.107263  0.057462  0.062570   0.028603
# 8        187         Michael Emerson  0.114414  0.053631  0.020857   0.011918
# 9        178            Austin Roest  0.157930  0.064792  0.065890   0.026768
# 10       193         Casper NÃ¤ssÃ©n  0.075833  0.043604  0.007583   0.000000
# ...

# %%
T17Merge
# Out:
#     height_x              playername   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 0        185             Justin Gill  0.382394  0.180918  0.189141   0.082235
# 1        180            Brett Hyland  0.250906  0.138799  0.106594   0.047783
# 2        198         Milton Oscarson  0.069804  0.036549  0.083973   0.027823
# 3        180              Ty Mueller  0.238077  0.114277  0.175383   0.107928
# 4        178             Jack Harvey  0.225965  0.122143  0.149625   0.079393
# 5        180            Matt Copponi  0.253777  0.122513  0.116562   0.038854
# 6        181       Stanislav Yarovoy  0.254365  0.132724  0.084268   0.035750
# 7        180              Sam Harris  0.189322  0.101422  0.110438   0.050486
# 8        187         Michael Emerson  0.201943  0.094661  0.036813   0.021036
# 9        178            Austin Roest  0.291479  0.119581  0.121608   0.049403
# 10       193         Casper NÃ¤ssÃ©n  0.075833  0.043604  0.007583   0.000000
# ...

# %%
T17Merge
# Out:
#     height_x              playername   NHLeDY0  NHLGeDY0  NHLeDYn1  NHLGeDYn1  \
# 0        185             Justin Gill  0.154544  0.073118  0.076441   0.033235
# 1        180            Brett Hyland  0.157786  0.087286  0.067033   0.030049
# 2        198         Milton Oscarson  0.075409  0.038418  0.086303   0.027823
# 3        180              Ty Mueller  0.142647  0.068471  0.105083   0.064667
# 4        178             Jack Harvey  0.170677  0.092258  0.113016   0.059968
# 5        180            Matt Copponi  0.152054  0.073405  0.069840   0.023280
# 6        181       Stanislav Yarovoy  0.336950  0.179179  0.084268   0.035750
# 7        180              Sam Harris  0.143000  0.076607  0.083417   0.038133
# 8        187         Michael Emerson  0.152533  0.071500  0.027806   0.015889
# 9        178            Austin Roest  0.183300  0.075200  0.076475   0.031068
# 10       193         Casper NÃ¤ssÃ©n  0.075833  0.043604  0.007583   0.000000
# ...

# %%
F1Train2.describe()
# Out:
#            age0new    NHLecomb3       Comb3+        Comb0        Comb1
# count  1120.000000  1120.000000  1120.000000  1120.000000  1120.000000
# mean      0.058412     0.330118     0.108036     0.112500     0.083036
# std       0.002225     0.083653     0.310564     0.316122     0.276059
# min       0.050048     0.083849     0.000000     0.000000     0.000000
# 25%       0.057898     0.278646     0.000000     0.000000     0.000000
# 50%       0.059075     0.325900     0.000000     0.000000     0.000000
# 75%       0.059895     0.382045     0.000000     0.000000     0.000000
# max       0.061323     0.720307     1.000000     1.000000     1.000000

# %%
D1Train2.describe()
# Out:
#           age0new   NHLecomb3      Comb3+
# count  597.000000  597.000000  597.000000
# mean     0.058522    0.221511    0.046901
# std      0.002174    0.071257    0.211604
# min      0.050289    0.000000    0.000000
# 25%      0.058018    0.171718    0.000000
# 50%      0.059109    0.219147    0.000000
# 75%      0.059923    0.271099    0.000000
# max      0.061312    0.491773    1.000000
